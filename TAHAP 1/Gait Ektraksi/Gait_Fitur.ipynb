# %% [markdown]
# 🟦 CELL 1 – Setup folder & import (boleh taruh di atas / lanjutkan saja)

# %%
import os
import numpy as np
import pandas as pd

# Folder input: hasil Tahap 3 (gait + steps)
FOLDER_GAITFRAME_STEPS = r"E:\1.Clustering_TA\dataset\gaitframe_steps"

# Folder output: fitur gait per trial
FOLDER_GAIT_FEATURES = r"E:\1.Clustering_TA\dataset\gait_features"
os.makedirs(FOLDER_GAIT_FEATURES, exist_ok=True)

# %% [markdown]
# 🟦 CELL 2 – Fungsi hitung gait fitur dari satu df gait_with_steps

# %%
def compute_gait_features_from_gait_df(
    df_gait_steps,
    min_step_time=0.3,
    max_step_time=1.5
):
    """
    Menghitung fitur gait dasar dari satu trial, berdasarkan kolom:
    - timestamp_sec
    - step_event (0/1)

    Menghasilkan dict dengan:
    - step_count
    - duration_sec
    - n_valid_intervals
    - mean_step_time
    - std_step_time
    - min_step_time_used
    - max_step_time_used
    - cadence_spm
    """

    df = df_gait_steps.copy()

    # Pastikan kolom penting ada
    required_cols = ["timestamp_sec", "step_event"]
    for c in required_cols:
        if c not in df.columns:
            raise ValueError(f"Kolom '{c}' tidak ditemukan di DataFrame gait_with_steps")

    # Ambil semua indeks step
    step_mask = df["step_event"] == 1
    step_times = df.loc[step_mask, "timestamp_sec"].values

    features = {
        "step_count": int(step_mask.sum()),
        "duration_sec": np.nan,
        "n_valid_intervals": 0,
        "mean_step_time": np.nan,
        "std_step_time": np.nan,
        "min_step_time_used": np.nan,
        "max_step_time_used": np.nan,
        "cadence_spm": np.nan,
    }

    # Durasi trial: dari frame valid pertama sampai terakhir
    if df["timestamp_sec"].notna().sum() > 1:
        t_valid = df["timestamp_sec"].dropna()
        features["duration_sec"] = float(t_valid.max() - t_valid.min())

    # Tidak ada atau hanya 1 step → tidak bisa hitung interval
    if len(step_times) < 2:
        return features

    # Hitung interval antar step
    step_intervals = np.diff(step_times)  # detik

    # Terapkan filter fisiologis (buang interval terlalu kecil/besar)
    valid_int_mask = (step_intervals >= min_step_time) & (step_intervals <= max_step_time)
    valid_intervals = step_intervals[valid_int_mask]

    if len(valid_intervals) == 0:
        # Tidak ada interval yang lolos filter → fitur waktu tetap NaN
        return features

    features["n_valid_intervals"] = int(len(valid_intervals))
    features["mean_step_time"] = float(np.mean(valid_intervals))
    features["std_step_time"] = float(np.std(valid_intervals, ddof=1)) if len(valid_intervals) > 1 else 0.0
    features["min_step_time_used"] = float(valid_intervals.min())
    features["max_step_time_used"] = float(valid_intervals.max())

    # Cadence: pakai step_count dan durasi trial (kalau ada)
    if features["duration_sec"] is not None and features["duration_sec"] > 0 and not np.isnan(features["duration_sec"]):
        # steps per minute
        features["cadence_spm"] = float(features["step_count"] * 60.0 / features["duration_sec"])

    return features

# %% [markdown]
# 🟦 CELL 3 – Fungsi proses satu file

# %%
def process_single_gait_with_steps_file(
    file_path,
    min_step_time=0.3,
    max_step_time=1.5
):
    """
    Membaca satu file gait_with_steps dan menghitung fitur gait.
    Mengembalikan (trial_name, dict_fitur).
    """

    base_name = os.path.basename(file_path)
    trial_name = base_name.replace("_gait_with_steps.csv", "")

    print(f"\n=== Hitung gait fitur: {trial_name} ===")
    print("Load:", file_path)

    df = pd.read_csv(file_path)

    # Pastikan timestamp_sec ada, kalau belum buat dari timestamp
    if "timestamp_sec" not in df.columns and "timestamp" in df.columns:
        from math import isnan

        def convert_timestamp_to_seconds(ts):
            try:
                h, m, s = ts.split(":")
                return int(h) * 3600 + int(m) * 60 + float(s)
            except:
                return np.nan

        df["timestamp_sec"] = df["timestamp"].apply(convert_timestamp_to_seconds)

    feats = compute_gait_features_from_gait_df(
        df,
        min_step_time=min_step_time,
        max_step_time=max_step_time
    )

    return trial_name, feats

# %% [markdown]
# 🟦 CELL 4 – Proses semua trial & simpan summary fitur

# %%
def process_all_gait_features(
    folder_steps=FOLDER_GAITFRAME_STEPS,
    folder_out=FOLDER_GAIT_FEATURES,
    min_step_time=0.3,
    max_step_time=1.5
):
    rows = []

    files = sorted(os.listdir(folder_steps))
    for fname in files:
        if not fname.endswith("_gait_with_steps.csv"):
            continue

        path = os.path.join(folder_steps, fname)

        try:
            trial_name, feats = process_single_gait_with_steps_file(
                path,
                min_step_time=min_step_time,
                max_step_time=max_step_time
            )

            row = {"trial": trial_name}
            row.update(feats)
            rows.append(row)

        except Exception as e:
            print(f"ERROR pada file {fname}: {e}")

    if not rows:
        print("Tidak ada file gait_with_steps yang diproses.")
        return pd.DataFrame()

    df_features = pd.DataFrame(rows)

    # Simpan summary ke CSV
    summary_path = os.path.join(folder_out, "gait_features_summary.csv")
    df_features.to_csv(summary_path, index=False)
    print("\n=== Gait features summary saved ===")
    print(summary_path)

    return df_features

# %% [markdown]
# 🟦 CELL 5 – Jalankan & lihat hasil

# %%
df_gait_feats = process_all_gait_features()
df_gait_feats
# Out:
# === Hitung gait fitur: Afi_Jalan10 ===
# Load: E:\1.Clustering_TA\dataset\gaitframe_steps\Afi_Jalan10_gait_with_steps.csv
#
# === Hitung gait fitur: Afi_Jalan11 ===
# Load: E:\1.Clustering_TA\dataset\gaitframe_steps\Afi_Jalan11_gait_with_steps.csv
#
# === Hitung gait fitur: Afi_Jalan12 ===
# Load: E:\1.Clustering_TA\dataset\gaitframe_steps\Afi_Jalan12_gait_with_steps.csv
#
# === Hitung gait fitur: Afi_Jalan13 ===
# Load: E:\1.Clustering_TA\dataset\gaitframe_steps\Afi_Jalan13_gait_with_steps.csv
#
# === Hitung gait fitur: Afi_Jalan14 ===
# Load: E:\1.Clustering_TA\dataset\gaitframe_steps\Afi_Jalan14_gait_with_steps.csv
#
# === Hitung gait fitur: Afi_Jalan15 ===
# Load: E:\1.Clustering_TA\dataset\gaitframe_steps\Afi_Jalan15_gait_with_steps.csv
#
# === Hitung gait fitur: Afi_Jalan16 ===
# Load: E:\1.Clustering_TA\dataset\gaitframe_steps\Afi_Jalan16_gait_with_steps.csv
#
# === Hitung gait fitur: Afi_Jalan17 ===
# Load: E:\1.Clustering_TA\dataset\gaitframe_steps\Afi_Jalan17_gait_with_steps.csv
#
# === Hitung gait fitur: Afi_Jalan18 ===
# Load: E:\1.Clustering_TA\dataset\gaitframe_steps\Afi_Jalan18_gait_with_steps.csv
#
# === Hitung gait fitur: Afi_Jalan19 ===
# Load: E:\1.Clustering_TA\dataset\gaitframe_steps\Afi_Jalan19_gait_with_steps.csv
#
# === Hitung gait fitur: Afi_Jalan1 ===
# Load: E:\1.Clustering_TA\dataset\gaitframe_steps\Afi_Jalan1_gait_with_steps.csv
#
# === Hitung gait fitur: Afi_Jalan20 ===
# Load: E:\1.Clustering_TA\dataset\gaitframe_steps\Afi_Jalan20_gait_with_steps.csv
#
# === Hitung gait fitur: Afi_Jalan21 ===
# Load: E:\1.Clustering_TA\dataset\gaitframe_steps\Afi_Jalan21_gait_with_steps.csv
#
# === Hitung gait fitur: Afi_Jalan22 ===
# Load: E:\1.Clustering_TA\dataset\gaitframe_steps\Afi_Jalan22_gait_with_steps.csv
#
# === Hitung gait fitur: Afi_Jalan23 ===
# Load: E:\1.Clustering_TA\dataset\gaitframe_steps\Afi_Jalan23_gait_with_steps.csv
#
# === Hitung gait fitur: Afi_Jalan24 ===
# Load: E:\1.Clustering_TA\dataset\gaitframe_steps\Afi_Jalan24_gait_with_steps.csv
#
# === Hitung gait fitur: Afi_Jalan25 ===
# Load: E:\1.Clustering_TA\dataset\gaitframe_steps\Afi_Jalan25_gait_with_steps.csv
#
# === Hitung gait fitur: Afi_Jalan26 ===
# Load: E:\1.Clustering_TA\dataset\gaitframe_steps\Afi_Jalan26_gait_with_steps.csv
#
# === Hitung gait fitur: Afi_Jalan27 ===
# Load: E:\1.Clustering_TA\dataset\gaitframe_steps\Afi_Jalan27_gait_with_steps.csv
#
# === Hitung gait fitur: Afi_Jalan28 ===
# Load: E:\1.Clustering_TA\dataset\gaitframe_steps\Afi_Jalan28_gait_with_steps.csv
#
# === Hitung gait fitur: Afi_Jalan29 ===
# Load: E:\1.Clustering_TA\dataset\gaitframe_steps\Afi_Jalan29_gait_with_steps.csv
#
# === Hitung gait fitur: Afi_Jalan2 ===
# Load: E:\1.Clustering_TA\dataset\gaitframe_steps\Afi_Jalan2_gait_with_steps.csv
#
# === Hitung gait fitur: Afi_Jalan30 ===
# Load: E:\1.Clustering_TA\dataset\gaitframe_steps\Afi_Jalan30_gait_with_steps.csv
#
# === Hitung gait fitur: Afi_Jalan31 ===
# Load: E:\1.Clustering_TA\dataset\gaitframe_steps\Afi_Jalan31_gait_with_steps.csv
#
# === Hitung gait fitur: Afi_Jalan32 ===
# Load: E:\1.Clustering_TA\dataset\gaitframe_steps\Afi_Jalan32_gait_with_steps.csv
#
# === Hitung gait fitur: Afi_Jalan33 ===
# Load: E:\1.Clustering_TA\dataset\gaitframe_steps\Afi_Jalan33_gait_with_steps.csv
#
# === Hitung gait fitur: Afi_Jalan34 ===
# Load: E:\1.Clustering_TA\dataset\gaitframe_steps\Afi_Jalan34_gait_with_steps.csv
#
# === Hitung gait fitur: Afi_Jalan35 ===
# Load: E:\1.Clustering_TA\dataset\gaitframe_steps\Afi_Jalan35_gait_with_steps.csv
#
# === Hitung gait fitur: Afi_Jalan36 ===
# Load: E:\1.Clustering_TA\dataset\gaitframe_steps\Afi_Jalan36_gait_with_steps.csv
#
# === Hitung gait fitur: Afi_Jalan37 ===
# Load: E:\1.Clustering_TA\dataset\gaitframe_steps\Afi_Jalan37_gait_with_steps.csv
#
# === Hitung gait fitur: Afi_Jalan38 ===
# Load: E:\1.Clustering_TA\dataset\gaitframe_steps\Afi_Jalan38_gait_with_steps.csv
#
# === Hitung gait fitur: Afi_Jalan39 ===
# Load: E:\1.Clustering_TA\dataset\gaitframe_steps\Afi_Jalan39_gait_with_steps.csv
#
# === Hitung gait fitur: Afi_Jalan3 ===
# Load: E:\1.Clustering_TA\dataset\gaitframe_steps\Afi_Jalan3_gait_with_steps.csv
#
# === Hitung gait fitur: Afi_Jalan40 ===
# Load: E:\1.Clustering_TA\dataset\gaitframe_steps\Afi_Jalan40_gait_with_steps.csv
#
# === Hitung gait fitur: Afi_Jalan41 ===
# Load: E:\1.Clustering_TA\dataset\gaitframe_steps\Afi_Jalan41_gait_with_steps.csv
#
# === Hitung gait fitur: Afi_Jalan42 ===
# Load: E:\1.Clustering_TA\dataset\gaitframe_steps\Afi_Jalan42_gait_with_steps.csv
#
# === Hitung gait fitur: Afi_Jalan43 ===
# Load: E:\1.Clustering_TA\dataset\gaitframe_steps\Afi_Jalan43_gait_with_steps.csv
#
# === Hitung gait fitur: Afi_Jalan44 ===
# Load: E:\1.Clustering_TA\dataset\gaitframe_steps\Afi_Jalan44_gait_with_steps.csv
#
# === Hitung gait fitur: Afi_Jalan45 ===
# Load: E:\1.Clustering_TA\dataset\gaitframe_steps\Afi_Jalan45_gait_with_steps.csv
#
# === Hitung gait fitur: Afi_Jalan46 ===
# Load: E:\1.Clustering_TA\dataset\gaitframe_steps\Afi_Jalan46_gait_with_steps.csv
#
# === Hitung gait fitur: Afi_Jalan47 ===
# Load: E:\1.Clustering_TA\dataset\gaitframe_steps\Afi_Jalan47_gait_with_steps.csv
#
# === Hitung gait fitur: Afi_Jalan48 ===
# Load: E:\1.Clustering_TA\dataset\gaitframe_steps\Afi_Jalan48_gait_with_steps.csv
#
# === Hitung gait fitur: Afi_Jalan49 ===
# Load: E:\1.Clustering_TA\dataset\gaitframe_steps\Afi_Jalan49_gait_with_steps.csv
#
# === Hitung gait fitur: Afi_Jalan4 ===
# Load: E:\1.Clustering_TA\dataset\gaitframe_steps\Afi_Jalan4_gait_with_steps.csv
#
# === Hitung gait fitur: Afi_Jalan50 ===
# Load: E:\1.Clustering_TA\dataset\gaitframe_steps\Afi_Jalan50_gait_with_steps.csv
#
# === Hitung gait fitur: Afi_Jalan51 ===
# Load: E:\1.Clustering_TA\dataset\gaitframe_steps\Afi_Jalan51_gait_with_steps.csv
#
# === Hitung gait fitur: Afi_Jalan52 ===
# Load: E:\1.Clustering_TA\dataset\gaitframe_steps\Afi_Jalan52_gait_with_steps.csv
#
# === Hitung gait fitur: Afi_Jalan53 ===
# Load: E:\1.Clustering_TA\dataset\gaitframe_steps\Afi_Jalan53_gait_with_steps.csv
#
# === Hitung gait fitur: Afi_Jalan54 ===
# Load: E:\1.Clustering_TA\dataset\gaitframe_steps\Afi_Jalan54_gait_with_steps.csv
#
# === Hitung gait fitur: Afi_Jalan55 ===
# Load: E:\1.Clustering_TA\dataset\gaitframe_steps\Afi_Jalan55_gait_with_steps.csv
#
# === Hitung gait fitur: Afi_Jalan56 ===
# Load: E:\1.Clustering_TA\dataset\gaitframe_steps\Afi_Jalan56_gait_with_steps.csv
#
# === Hitung gait fitur: Afi_Jalan57 ===
# Load: E:\1.Clustering_TA\dataset\gaitframe_steps\Afi_Jalan57_gait_with_steps.csv
#
# === Hitung gait fitur: Afi_Jalan58 ===
# Load: E:\1.Clustering_TA\dataset\gaitframe_steps\Afi_Jalan58_gait_with_steps.csv
#
# === Hitung gait fitur: Afi_Jalan59 ===
# Load: E:\1.Clustering_TA\dataset\gaitframe_steps\Afi_Jalan59_gait_with_steps.csv
#
# === Hitung gait fitur: Afi_Jalan5 ===
# Load: E:\1.Clustering_TA\dataset\gaitframe_steps\Afi_Jalan5_gait_with_steps.csv
#
# === Hitung gait fitur: Afi_Jalan60 ===
# Load: E:\1.Clustering_TA\dataset\gaitframe_steps\Afi_Jalan60_gait_with_steps.csv
#
# === Hitung gait fitur: Afi_Jalan61 ===
# Load: E:\1.Clustering_TA\dataset\gaitframe_steps\Afi_Jalan61_gait_with_steps.csv
#
# === Hitung gait fitur: Afi_Jalan62 ===
# Load: E:\1.Clustering_TA\dataset\gaitframe_steps\Afi_Jalan62_gait_with_steps.csv
#
# === Hitung gait fitur: Afi_Jalan63 ===
# Load: E:\1.Clustering_TA\dataset\gaitframe_steps\Afi_Jalan63_gait_with_steps.csv
#
# === Hitung gait fitur: Afi_Jalan64 ===
# Load: E:\1.Clustering_TA\dataset\gaitframe_steps\Afi_Jalan64_gait_with_steps.csv
#
# === Hitung gait fitur: Afi_Jalan65 ===
# Load: E:\1.Clustering_TA\dataset\gaitframe_steps\Afi_Jalan65_gait_with_steps.csv
#
# === Hitung gait fitur: Afi_Jalan66 ===
# Load: E:\1.Clustering_TA\dataset\gaitframe_steps\Afi_Jalan66_gait_with_steps.csv
#
# === Hitung gait fitur: Afi_Jalan67 ===
# Load: E:\1.Clustering_TA\dataset\gaitframe_steps\Afi_Jalan67_gait_with_steps.csv
#
# === Hitung gait fitur: Afi_Jalan68 ===
# Load: E:\1.Clustering_TA\dataset\gaitframe_steps\Afi_Jalan68_gait_with_steps.csv
#
# === Hitung gait fitur: Afi_Jalan69 ===
# Load: E:\1.Clustering_TA\dataset\gaitframe_steps\Afi_Jalan69_gait_with_steps.csv
#
# === Hitung gait fitur: Afi_Jalan6 ===
# Load: E:\1.Clustering_TA\dataset\gaitframe_steps\Afi_Jalan6_gait_with_steps.csv
#
# === Hitung gait fitur: Afi_Jalan70 ===
# Load: E:\1.Clustering_TA\dataset\gaitframe_steps\Afi_Jalan70_gait_with_steps.csv
#
# === Hitung gait fitur: Afi_Jalan71 ===
# Load: E:\1.Clustering_TA\dataset\gaitframe_steps\Afi_Jalan71_gait_with_steps.csv
#
# === Hitung gait fitur: Afi_Jalan72 ===
# Load: E:\1.Clustering_TA\dataset\gaitframe_steps\Afi_Jalan72_gait_with_steps.csv
#
# === Hitung gait fitur: Afi_Jalan7 ===
# Load: E:\1.Clustering_TA\dataset\gaitframe_steps\Afi_Jalan7_gait_with_steps.csv
#
# === Hitung gait fitur: Afi_Jalan8 ===
# Load: E:\1.Clustering_TA\dataset\gaitframe_steps\Afi_Jalan8_gait_with_steps.csv
#
# === Hitung gait fitur: Afi_Jalan9 ===
# Load: E:\1.Clustering_TA\dataset\gaitframe_steps\Afi_Jalan9_gait_with_steps.csv
#
# === Hitung gait fitur: Kinan_Jalan10 ===
# Load: E:\1.Clustering_TA\dataset\gaitframe_steps\Kinan_Jalan10_gait_with_steps.csv
#
# === Hitung gait fitur: Kinan_Jalan11 ===
# Load: E:\1.Clustering_TA\dataset\gaitframe_steps\Kinan_Jalan11_gait_with_steps.csv
#
# === Hitung gait fitur: Kinan_Jalan12 ===
# Load: E:\1.Clustering_TA\dataset\gaitframe_steps\Kinan_Jalan12_gait_with_steps.csv
#
# === Hitung gait fitur: Kinan_Jalan13 ===
# Load: E:\1.Clustering_TA\dataset\gaitframe_steps\Kinan_Jalan13_gait_with_steps.csv
#
# === Hitung gait fitur: Kinan_Jalan14 ===
# Load: E:\1.Clustering_TA\dataset\gaitframe_steps\Kinan_Jalan14_gait_with_steps.csv
#
# === Hitung gait fitur: Kinan_Jalan15 ===
# Load: E:\1.Clustering_TA\dataset\gaitframe_steps\Kinan_Jalan15_gait_with_steps.csv
#
# === Hitung gait fitur: Kinan_Jalan16 ===
# Load: E:\1.Clustering_TA\dataset\gaitframe_steps\Kinan_Jalan16_gait_with_steps.csv
#
# === Hitung gait fitur: Kinan_Jalan17 ===
# Load: E:\1.Clustering_TA\dataset\gaitframe_steps\Kinan_Jalan17_gait_with_steps.csv
#
# === Hitung gait fitur: Kinan_Jalan18 ===
# Load: E:\1.Clustering_TA\dataset\gaitframe_steps\Kinan_Jalan18_gait_with_steps.csv
#
# === Hitung gait fitur: Kinan_Jalan19 ===
# Load: E:\1.Clustering_TA\dataset\gaitframe_steps\Kinan_Jalan19_gait_with_steps.csv
#
# === Hitung gait fitur: Kinan_Jalan1 ===
# Load: E:\1.Clustering_TA\dataset\gaitframe_steps\Kinan_Jalan1_gait_with_steps.csv
#
# === Hitung gait fitur: Kinan_Jalan20 ===
# Load: E:\1.Clustering_TA\dataset\gaitframe_steps\Kinan_Jalan20_gait_with_steps.csv
#
# === Hitung gait fitur: Kinan_Jalan21 ===
# Load: E:\1.Clustering_TA\dataset\gaitframe_steps\Kinan_Jalan21_gait_with_steps.csv
#
# === Hitung gait fitur: Kinan_Jalan22 ===
# Load: E:\1.Clustering_TA\dataset\gaitframe_steps\Kinan_Jalan22_gait_with_steps.csv
#
# === Hitung gait fitur: Kinan_Jalan23 ===
# Load: E:\1.Clustering_TA\dataset\gaitframe_steps\Kinan_Jalan23_gait_with_steps.csv
#
# === Hitung gait fitur: Kinan_Jalan24 ===
# Load: E:\1.Clustering_TA\dataset\gaitframe_steps\Kinan_Jalan24_gait_with_steps.csv
#
# === Hitung gait fitur: Kinan_Jalan25 ===
# Load: E:\1.Clustering_TA\dataset\gaitframe_steps\Kinan_Jalan25_gait_with_steps.csv
#
# === Hitung gait fitur: Kinan_Jalan26 ===
# Load: E:\1.Clustering_TA\dataset\gaitframe_steps\Kinan_Jalan26_gait_with_steps.csv
#
# === Hitung gait fitur: Kinan_Jalan27 ===
# Load: E:\1.Clustering_TA\dataset\gaitframe_steps\Kinan_Jalan27_gait_with_steps.csv
#
# === Hitung gait fitur: Kinan_Jalan28 ===
# Load: E:\1.Clustering_TA\dataset\gaitframe_steps\Kinan_Jalan28_gait_with_steps.csv
#
# === Hitung gait fitur: Kinan_Jalan29 ===
# Load: E:\1.Clustering_TA\dataset\gaitframe_steps\Kinan_Jalan29_gait_with_steps.csv
#
# === Hitung gait fitur: Kinan_Jalan2 ===
# Load: E:\1.Clustering_TA\dataset\gaitframe_steps\Kinan_Jalan2_gait_with_steps.csv
#
# === Hitung gait fitur: Kinan_Jalan30 ===
# Load: E:\1.Clustering_TA\dataset\gaitframe_steps\Kinan_Jalan30_gait_with_steps.csv
#
# === Hitung gait fitur: Kinan_Jalan31 ===
# Load: E:\1.Clustering_TA\dataset\gaitframe_steps\Kinan_Jalan31_gait_with_steps.csv
#
# === Hitung gait fitur: Kinan_Jalan32 ===
# Load: E:\1.Clustering_TA\dataset\gaitframe_steps\Kinan_Jalan32_gait_with_steps.csv
#
# === Hitung gait fitur: Kinan_Jalan33 ===
# Load: E:\1.Clustering_TA\dataset\gaitframe_steps\Kinan_Jalan33_gait_with_steps.csv
#
# === Hitung gait fitur: Kinan_Jalan34 ===
# Load: E:\1.Clustering_TA\dataset\gaitframe_steps\Kinan_Jalan34_gait_with_steps.csv
#
# === Hitung gait fitur: Kinan_Jalan35 ===
# Load: E:\1.Clustering_TA\dataset\gaitframe_steps\Kinan_Jalan35_gait_with_steps.csv
#
# === Hitung gait fitur: Kinan_Jalan36 ===
# Load: E:\1.Clustering_TA\dataset\gaitframe_steps\Kinan_Jalan36_gait_with_steps.csv
#
# === Hitung gait fitur: Kinan_Jalan37 ===
# Load: E:\1.Clustering_TA\dataset\gaitframe_steps\Kinan_Jalan37_gait_with_steps.csv
#
# === Hitung gait fitur: Kinan_Jalan38 ===
# Load: E:\1.Clustering_TA\dataset\gaitframe_steps\Kinan_Jalan38_gait_with_steps.csv
#
# === Hitung gait fitur: Kinan_Jalan39 ===
# Load: E:\1.Clustering_TA\dataset\gaitframe_steps\Kinan_Jalan39_gait_with_steps.csv
#
# === Hitung gait fitur: Kinan_Jalan3 ===
# Load: E:\1.Clustering_TA\dataset\gaitframe_steps\Kinan_Jalan3_gait_with_steps.csv
#
# === Hitung gait fitur: Kinan_Jalan40 ===
# Load: E:\1.Clustering_TA\dataset\gaitframe_steps\Kinan_Jalan40_gait_with_steps.csv
#
# === Hitung gait fitur: Kinan_Jalan41 ===
# Load: E:\1.Clustering_TA\dataset\gaitframe_steps\Kinan_Jalan41_gait_with_steps.csv
#
# === Hitung gait fitur: Kinan_Jalan42 ===
# Load: E:\1.Clustering_TA\dataset\gaitframe_steps\Kinan_Jalan42_gait_with_steps.csv
#
# === Hitung gait fitur: Kinan_Jalan43 ===
# Load: E:\1.Clustering_TA\dataset\gaitframe_steps\Kinan_Jalan43_gait_with_steps.csv
#
# === Hitung gait fitur: Kinan_Jalan44 ===
# Load: E:\1.Clustering_TA\dataset\gaitframe_steps\Kinan_Jalan44_gait_with_steps.csv
#
# === Hitung gait fitur: Kinan_Jalan45 ===
# Load: E:\1.Clustering_TA\dataset\gaitframe_steps\Kinan_Jalan45_gait_with_steps.csv
#
# === Hitung gait fitur: Kinan_Jalan46 ===
# Load: E:\1.Clustering_TA\dataset\gaitframe_steps\Kinan_Jalan46_gait_with_steps.csv
#
# === Hitung gait fitur: Kinan_Jalan47 ===
# Load: E:\1.Clustering_TA\dataset\gaitframe_steps\Kinan_Jalan47_gait_with_steps.csv
#
# === Hitung gait fitur: Kinan_Jalan48 ===
# Load: E:\1.Clustering_TA\dataset\gaitframe_steps\Kinan_Jalan48_gait_with_steps.csv
#
# === Hitung gait fitur: Kinan_Jalan49 ===
# Load: E:\1.Clustering_TA\dataset\gaitframe_steps\Kinan_Jalan49_gait_with_steps.csv
#
# === Hitung gait fitur: Kinan_Jalan4 ===
# Load: E:\1.Clustering_TA\dataset\gaitframe_steps\Kinan_Jalan4_gait_with_steps.csv
#
# === Hitung gait fitur: Kinan_Jalan50 ===
# Load: E:\1.Clustering_TA\dataset\gaitframe_steps\Kinan_Jalan50_gait_with_steps.csv
#
# === Hitung gait fitur: Kinan_Jalan51 ===
# Load: E:\1.Clustering_TA\dataset\gaitframe_steps\Kinan_Jalan51_gait_with_steps.csv
#
# === Hitung gait fitur: Kinan_Jalan52 ===
# Load: E:\1.Clustering_TA\dataset\gaitframe_steps\Kinan_Jalan52_gait_with_steps.csv
#
# === Hitung gait fitur: Kinan_Jalan53 ===
# Load: E:\1.Clustering_TA\dataset\gaitframe_steps\Kinan_Jalan53_gait_with_steps.csv
#
# === Hitung gait fitur: Kinan_Jalan54 ===
# Load: E:\1.Clustering_TA\dataset\gaitframe_steps\Kinan_Jalan54_gait_with_steps.csv
#
# === Hitung gait fitur: Kinan_Jalan55 ===
# Load: E:\1.Clustering_TA\dataset\gaitframe_steps\Kinan_Jalan55_gait_with_steps.csv
#
# === Hitung gait fitur: Kinan_Jalan56 ===
# Load: E:\1.Clustering_TA\dataset\gaitframe_steps\Kinan_Jalan56_gait_with_steps.csv
#
# === Hitung gait fitur: Kinan_Jalan57 ===
# Load: E:\1.Clustering_TA\dataset\gaitframe_steps\Kinan_Jalan57_gait_with_steps.csv
#
# === Hitung gait fitur: Kinan_Jalan58 ===
# Load: E:\1.Clustering_TA\dataset\gaitframe_steps\Kinan_Jalan58_gait_with_steps.csv
#
# === Hitung gait fitur: Kinan_Jalan59 ===
# Load: E:\1.Clustering_TA\dataset\gaitframe_steps\Kinan_Jalan59_gait_with_steps.csv
#
# === Hitung gait fitur: Kinan_Jalan5 ===
# Load: E:\1.Clustering_TA\dataset\gaitframe_steps\Kinan_Jalan5_gait_with_steps.csv
#
# === Hitung gait fitur: Kinan_Jalan60 ===
# Load: E:\1.Clustering_TA\dataset\gaitframe_steps\Kinan_Jalan60_gait_with_steps.csv
#
# === Hitung gait fitur: Kinan_Jalan61 ===
# Load: E:\1.Clustering_TA\dataset\gaitframe_steps\Kinan_Jalan61_gait_with_steps.csv
#
# === Hitung gait fitur: Kinan_Jalan62 ===
# Load: E:\1.Clustering_TA\dataset\gaitframe_steps\Kinan_Jalan62_gait_with_steps.csv
#
# === Hitung gait fitur: Kinan_Jalan63 ===
# Load: E:\1.Clustering_TA\dataset\gaitframe_steps\Kinan_Jalan63_gait_with_steps.csv
#
# === Hitung gait fitur: Kinan_Jalan64 ===
# Load: E:\1.Clustering_TA\dataset\gaitframe_steps\Kinan_Jalan64_gait_with_steps.csv
#
# === Hitung gait fitur: Kinan_Jalan65 ===
# Load: E:\1.Clustering_TA\dataset\gaitframe_steps\Kinan_Jalan65_gait_with_steps.csv
#
# === Hitung gait fitur: Kinan_Jalan66 ===
# Load: E:\1.Clustering_TA\dataset\gaitframe_steps\Kinan_Jalan66_gait_with_steps.csv
#
# === Hitung gait fitur: Kinan_Jalan67 ===
# Load: E:\1.Clustering_TA\dataset\gaitframe_steps\Kinan_Jalan67_gait_with_steps.csv
#
# === Hitung gait fitur: Kinan_Jalan68 ===
# Load: E:\1.Clustering_TA\dataset\gaitframe_steps\Kinan_Jalan68_gait_with_steps.csv
#
# === Hitung gait fitur: Kinan_Jalan69 ===
# Load: E:\1.Clustering_TA\dataset\gaitframe_steps\Kinan_Jalan69_gait_with_steps.csv
#
# === Hitung gait fitur: Kinan_Jalan6 ===
# Load: E:\1.Clustering_TA\dataset\gaitframe_steps\Kinan_Jalan6_gait_with_steps.csv
#
# === Hitung gait fitur: Kinan_Jalan70 ===
# Load: E:\1.Clustering_TA\dataset\gaitframe_steps\Kinan_Jalan70_gait_with_steps.csv
#
# === Hitung gait fitur: Kinan_Jalan71 ===
# Load: E:\1.Clustering_TA\dataset\gaitframe_steps\Kinan_Jalan71_gait_with_steps.csv
#
# === Hitung gait fitur: Kinan_Jalan72 ===
# Load: E:\1.Clustering_TA\dataset\gaitframe_steps\Kinan_Jalan72_gait_with_steps.csv
#
# === Hitung gait fitur: Kinan_Jalan7 ===
# Load: E:\1.Clustering_TA\dataset\gaitframe_steps\Kinan_Jalan7_gait_with_steps.csv
#
# === Hitung gait fitur: Kinan_Jalan8 ===
# Load: E:\1.Clustering_TA\dataset\gaitframe_steps\Kinan_Jalan8_gait_with_steps.csv
#
# === Hitung gait fitur: Kinan_Jalan9 ===
# Load: E:\1.Clustering_TA\dataset\gaitframe_steps\Kinan_Jalan9_gait_with_steps.csv
#
# === Hitung gait fitur: Miftah_Jalan10 ===
# Load: E:\1.Clustering_TA\dataset\gaitframe_steps\Miftah_Jalan10_gait_with_steps.csv
#
# === Hitung gait fitur: Miftah_Jalan11 ===
# Load: E:\1.Clustering_TA\dataset\gaitframe_steps\Miftah_Jalan11_gait_with_steps.csv
#
# === Hitung gait fitur: Miftah_Jalan12 ===
# Load: E:\1.Clustering_TA\dataset\gaitframe_steps\Miftah_Jalan12_gait_with_steps.csv
#
# === Hitung gait fitur: Miftah_Jalan13 ===
# Load: E:\1.Clustering_TA\dataset\gaitframe_steps\Miftah_Jalan13_gait_with_steps.csv
#
# === Hitung gait fitur: Miftah_Jalan14 ===
# Load: E:\1.Clustering_TA\dataset\gaitframe_steps\Miftah_Jalan14_gait_with_steps.csv
#
# === Hitung gait fitur: Miftah_Jalan15 ===
# Load: E:\1.Clustering_TA\dataset\gaitframe_steps\Miftah_Jalan15_gait_with_steps.csv
#
# === Hitung gait fitur: Miftah_Jalan16 ===
# Load: E:\1.Clustering_TA\dataset\gaitframe_steps\Miftah_Jalan16_gait_with_steps.csv
#
# === Hitung gait fitur: Miftah_Jalan17 ===
# Load: E:\1.Clustering_TA\dataset\gaitframe_steps\Miftah_Jalan17_gait_with_steps.csv
#
# === Hitung gait fitur: Miftah_Jalan18 ===
# Load: E:\1.Clustering_TA\dataset\gaitframe_steps\Miftah_Jalan18_gait_with_steps.csv
#
# === Hitung gait fitur: Miftah_Jalan19 ===
# Load: E:\1.Clustering_TA\dataset\gaitframe_steps\Miftah_Jalan19_gait_with_steps.csv
#
# === Hitung gait fitur: Miftah_Jalan1 ===
# Load: E:\1.Clustering_TA\dataset\gaitframe_steps\Miftah_Jalan1_gait_with_steps.csv
#
# === Hitung gait fitur: Miftah_Jalan20 ===
# Load: E:\1.Clustering_TA\dataset\gaitframe_steps\Miftah_Jalan20_gait_with_steps.csv
#
# === Hitung gait fitur: Miftah_Jalan21 ===
# Load: E:\1.Clustering_TA\dataset\gaitframe_steps\Miftah_Jalan21_gait_with_steps.csv
#
# === Hitung gait fitur: Miftah_Jalan22 ===
# Load: E:\1.Clustering_TA\dataset\gaitframe_steps\Miftah_Jalan22_gait_with_steps.csv
#
# === Hitung gait fitur: Miftah_Jalan23 ===
# Load: E:\1.Clustering_TA\dataset\gaitframe_steps\Miftah_Jalan23_gait_with_steps.csv
#
# === Hitung gait fitur: Miftah_Jalan24 ===
# Load: E:\1.Clustering_TA\dataset\gaitframe_steps\Miftah_Jalan24_gait_with_steps.csv
#
# === Hitung gait fitur: Miftah_Jalan25 ===
# Load: E:\1.Clustering_TA\dataset\gaitframe_steps\Miftah_Jalan25_gait_with_steps.csv
#
# === Hitung gait fitur: Miftah_Jalan26 ===
# Load: E:\1.Clustering_TA\dataset\gaitframe_steps\Miftah_Jalan26_gait_with_steps.csv
#
# === Hitung gait fitur: Miftah_Jalan27 ===
# Load: E:\1.Clustering_TA\dataset\gaitframe_steps\Miftah_Jalan27_gait_with_steps.csv
#
# === Hitung gait fitur: Miftah_Jalan28 ===
# Load: E:\1.Clustering_TA\dataset\gaitframe_steps\Miftah_Jalan28_gait_with_steps.csv
#
# === Hitung gait fitur: Miftah_Jalan29 ===
# Load: E:\1.Clustering_TA\dataset\gaitframe_steps\Miftah_Jalan29_gait_with_steps.csv
#
# === Hitung gait fitur: Miftah_Jalan2 ===
# Load: E:\1.Clustering_TA\dataset\gaitframe_steps\Miftah_Jalan2_gait_with_steps.csv
#
# === Hitung gait fitur: Miftah_Jalan30 ===
# Load: E:\1.Clustering_TA\dataset\gaitframe_steps\Miftah_Jalan30_gait_with_steps.csv
#
# === Hitung gait fitur: Miftah_Jalan31 ===
# Load: E:\1.Clustering_TA\dataset\gaitframe_steps\Miftah_Jalan31_gait_with_steps.csv
#
# === Hitung gait fitur: Miftah_Jalan32 ===
# Load: E:\1.Clustering_TA\dataset\gaitframe_steps\Miftah_Jalan32_gait_with_steps.csv
#
# === Hitung gait fitur: Miftah_Jalan33 ===
# Load: E:\1.Clustering_TA\dataset\gaitframe_steps\Miftah_Jalan33_gait_with_steps.csv
#
# === Hitung gait fitur: Miftah_Jalan34 ===
# Load: E:\1.Clustering_TA\dataset\gaitframe_steps\Miftah_Jalan34_gait_with_steps.csv
#
# === Hitung gait fitur: Miftah_Jalan35 ===
# Load: E:\1.Clustering_TA\dataset\gaitframe_steps\Miftah_Jalan35_gait_with_steps.csv
#
# === Hitung gait fitur: Miftah_Jalan36 ===
# Load: E:\1.Clustering_TA\dataset\gaitframe_steps\Miftah_Jalan36_gait_with_steps.csv
#
# === Hitung gait fitur: Miftah_Jalan37 ===
# Load: E:\1.Clustering_TA\dataset\gaitframe_steps\Miftah_Jalan37_gait_with_steps.csv
#
# === Hitung gait fitur: Miftah_Jalan38 ===
# Load: E:\1.Clustering_TA\dataset\gaitframe_steps\Miftah_Jalan38_gait_with_steps.csv
#
# === Hitung gait fitur: Miftah_Jalan39 ===
# Load: E:\1.Clustering_TA\dataset\gaitframe_steps\Miftah_Jalan39_gait_with_steps.csv
#
# === Hitung gait fitur: Miftah_Jalan3 ===
# Load: E:\1.Clustering_TA\dataset\gaitframe_steps\Miftah_Jalan3_gait_with_steps.csv
#
# === Hitung gait fitur: Miftah_Jalan40 ===
# Load: E:\1.Clustering_TA\dataset\gaitframe_steps\Miftah_Jalan40_gait_with_steps.csv
#
# === Hitung gait fitur: Miftah_Jalan41 ===
# Load: E:\1.Clustering_TA\dataset\gaitframe_steps\Miftah_Jalan41_gait_with_steps.csv
#
# === Hitung gait fitur: Miftah_Jalan42 ===
# Load: E:\1.Clustering_TA\dataset\gaitframe_steps\Miftah_Jalan42_gait_with_steps.csv
#
# === Hitung gait fitur: Miftah_Jalan43 ===
# Load: E:\1.Clustering_TA\dataset\gaitframe_steps\Miftah_Jalan43_gait_with_steps.csv
#
# === Hitung gait fitur: Miftah_Jalan44 ===
# Load: E:\1.Clustering_TA\dataset\gaitframe_steps\Miftah_Jalan44_gait_with_steps.csv
#
# === Hitung gait fitur: Miftah_Jalan45 ===
# Load: E:\1.Clustering_TA\dataset\gaitframe_steps\Miftah_Jalan45_gait_with_steps.csv
#
# === Hitung gait fitur: Miftah_Jalan46 ===
# Load: E:\1.Clustering_TA\dataset\gaitframe_steps\Miftah_Jalan46_gait_with_steps.csv
#
# === Hitung gait fitur: Miftah_Jalan47 ===
# Load: E:\1.Clustering_TA\dataset\gaitframe_steps\Miftah_Jalan47_gait_with_steps.csv
#
# === Hitung gait fitur: Miftah_Jalan48 ===
# Load: E:\1.Clustering_TA\dataset\gaitframe_steps\Miftah_Jalan48_gait_with_steps.csv
#
# === Hitung gait fitur: Miftah_Jalan49 ===
# Load: E:\1.Clustering_TA\dataset\gaitframe_steps\Miftah_Jalan49_gait_with_steps.csv
#
# === Hitung gait fitur: Miftah_Jalan4 ===
# Load: E:\1.Clustering_TA\dataset\gaitframe_steps\Miftah_Jalan4_gait_with_steps.csv
#
# === Hitung gait fitur: Miftah_Jalan50 ===
# Load: E:\1.Clustering_TA\dataset\gaitframe_steps\Miftah_Jalan50_gait_with_steps.csv
#
# === Hitung gait fitur: Miftah_Jalan51 ===
# Load: E:\1.Clustering_TA\dataset\gaitframe_steps\Miftah_Jalan51_gait_with_steps.csv
#
# === Hitung gait fitur: Miftah_Jalan52 ===
# Load: E:\1.Clustering_TA\dataset\gaitframe_steps\Miftah_Jalan52_gait_with_steps.csv
#
# === Hitung gait fitur: Miftah_Jalan53 ===
# Load: E:\1.Clustering_TA\dataset\gaitframe_steps\Miftah_Jalan53_gait_with_steps.csv
#
# === Hitung gait fitur: Miftah_Jalan54 ===
# Load: E:\1.Clustering_TA\dataset\gaitframe_steps\Miftah_Jalan54_gait_with_steps.csv
#
# === Hitung gait fitur: Miftah_Jalan55 ===
# Load: E:\1.Clustering_TA\dataset\gaitframe_steps\Miftah_Jalan55_gait_with_steps.csv
#
# === Hitung gait fitur: Miftah_Jalan56 ===
# Load: E:\1.Clustering_TA\dataset\gaitframe_steps\Miftah_Jalan56_gait_with_steps.csv
#
# === Hitung gait fitur: Miftah_Jalan57 ===
# Load: E:\1.Clustering_TA\dataset\gaitframe_steps\Miftah_Jalan57_gait_with_steps.csv
#
# === Hitung gait fitur: Miftah_Jalan58 ===
# Load: E:\1.Clustering_TA\dataset\gaitframe_steps\Miftah_Jalan58_gait_with_steps.csv
#
# === Hitung gait fitur: Miftah_Jalan59 ===
# Load: E:\1.Clustering_TA\dataset\gaitframe_steps\Miftah_Jalan59_gait_with_steps.csv
#
# === Hitung gait fitur: Miftah_Jalan5 ===
# Load: E:\1.Clustering_TA\dataset\gaitframe_steps\Miftah_Jalan5_gait_with_steps.csv
#
# === Hitung gait fitur: Miftah_Jalan60 ===
# Load: E:\1.Clustering_TA\dataset\gaitframe_steps\Miftah_Jalan60_gait_with_steps.csv
#
# === Hitung gait fitur: Miftah_Jalan61 ===
# Load: E:\1.Clustering_TA\dataset\gaitframe_steps\Miftah_Jalan61_gait_with_steps.csv
#
# === Hitung gait fitur: Miftah_Jalan62 ===
# Load: E:\1.Clustering_TA\dataset\gaitframe_steps\Miftah_Jalan62_gait_with_steps.csv
#
# === Hitung gait fitur: Miftah_Jalan63 ===
# Load: E:\1.Clustering_TA\dataset\gaitframe_steps\Miftah_Jalan63_gait_with_steps.csv
#
# === Hitung gait fitur: Miftah_Jalan64 ===
# Load: E:\1.Clustering_TA\dataset\gaitframe_steps\Miftah_Jalan64_gait_with_steps.csv
#
# === Hitung gait fitur: Miftah_Jalan65 ===
# Load: E:\1.Clustering_TA\dataset\gaitframe_steps\Miftah_Jalan65_gait_with_steps.csv
#
# === Hitung gait fitur: Miftah_Jalan66 ===
# Load: E:\1.Clustering_TA\dataset\gaitframe_steps\Miftah_Jalan66_gait_with_steps.csv
#
# === Hitung gait fitur: Miftah_Jalan67 ===
# Load: E:\1.Clustering_TA\dataset\gaitframe_steps\Miftah_Jalan67_gait_with_steps.csv
#
# === Hitung gait fitur: Miftah_Jalan68 ===
# Load: E:\1.Clustering_TA\dataset\gaitframe_steps\Miftah_Jalan68_gait_with_steps.csv
#
# === Hitung gait fitur: Miftah_Jalan69 ===
# Load: E:\1.Clustering_TA\dataset\gaitframe_steps\Miftah_Jalan69_gait_with_steps.csv
#
# === Hitung gait fitur: Miftah_Jalan6 ===
# Load: E:\1.Clustering_TA\dataset\gaitframe_steps\Miftah_Jalan6_gait_with_steps.csv
#
# === Hitung gait fitur: Miftah_Jalan70 ===
# Load: E:\1.Clustering_TA\dataset\gaitframe_steps\Miftah_Jalan70_gait_with_steps.csv
#
# === Hitung gait fitur: Miftah_Jalan71 ===
# Load: E:\1.Clustering_TA\dataset\gaitframe_steps\Miftah_Jalan71_gait_with_steps.csv
#
# === Hitung gait fitur: Miftah_Jalan72 ===
# Load: E:\1.Clustering_TA\dataset\gaitframe_steps\Miftah_Jalan72_gait_with_steps.csv
#
# === Hitung gait fitur: Miftah_Jalan7 ===
# Load: E:\1.Clustering_TA\dataset\gaitframe_steps\Miftah_Jalan7_gait_with_steps.csv
#
# === Hitung gait fitur: Miftah_Jalan8 ===
# Load: E:\1.Clustering_TA\dataset\gaitframe_steps\Miftah_Jalan8_gait_with_steps.csv
#
# === Hitung gait fitur: Miftah_Jalan9 ===
# Load: E:\1.Clustering_TA\dataset\gaitframe_steps\Miftah_Jalan9_gait_with_steps.csv
#
# === Gait features summary saved ===
# E:\1.Clustering_TA\dataset\gait_features\gait_features_summary.csv
#               trial  step_count  duration_sec  n_valid_intervals  \
# 0       Afi_Jalan10           6      4.465575                  3
# 1       Afi_Jalan11           6      4.521947                  3
# 2       Afi_Jalan12           7      6.152356                  2
# 3       Afi_Jalan13           4      3.348574                  2
# 4       Afi_Jalan14           2      4.402647                  0
# ..              ...         ...           ...                ...
# 211  Miftah_Jalan71          14     14.640848                  3
# 212  Miftah_Jalan72          26     20.260822                  7
# 213   Miftah_Jalan7           8      5.742082                  1
# 214   Miftah_Jalan8           9      5.752037                  4
# 215   Miftah_Jalan9           4      6.978845                  2
#
#      mean_step_time  std_step_time  min_step_time_used  max_step_time_used  \
# 0          0.385905       0.002022            0.383628            0.387490
# 1          0.674581       0.378025            0.333739            1.081165
# 2          0.906615       0.825006            0.323248            1.489982
# 3          0.802744       0.662668            0.334167            1.271321
# 4               NaN            NaN                 NaN                 NaN
# ..              ...            ...                 ...                 ...
# 211        0.403999       0.082463            0.333469            0.494666
# 212        0.495260       0.315790            0.328740            1.209755
# 213        0.329996       0.000000            0.329996            0.329996
# 214        0.520381       0.342960            0.327791            1.033535
# 215        0.356903       0.036575            0.331040            0.382765
#
#      cadence_spm
# 0      80.616718
# 1      79.611725
# 2      68.266531
# 3      71.672300
# 4            NaN
# ..           ...
# 211    57.373726
# 212    76.995889
# 213    83.593373
# 214    93.879786
# 215    34.389645
#
# [216 rows x 9 columns]
