# %% [markdown]
# 🟦 CELL 1 – IMPORT + PATH CONFIG (Letakkan di awal file)

# %%
import os
import pandas as pd
import numpy as np

# Set folder input/output
FOLDER_CLUSTERED = r"E:\1.Clustering_TA\3output_clustering\01_clustered_point_cloud"
FOLDER_TORSO = r"E:\1.Clustering_TA\3output_clustering\02_torso_per_frame"
FOLDER_GAITFRAME = r"E:\1.Clustering_TA\dataset\gaitframe"

# Pastikan folder output ada
os.makedirs(FOLDER_GAITFRAME, exist_ok=True)

# %% [markdown]
# 🟦 CELL 2 – Helper untuk konversi timestamp ke detik

# %%
def convert_timestamp_to_seconds(ts):
    """
    Konversi string timestamp 'HH:MM:SS.microsec' ke detik float.
    """
    try:
        h, m, s = ts.split(":")
        return int(h) * 3600 + int(m) * 60 + float(s)
    except:
        return np.nan

# %% [markdown]
# 🟦 CELL 3 – Fungsi utama build_gait_frame()

# %%
def build_gait_frame(df_clustered, df_torso):
    """
    Membangun gait frame ala Fig. 6 jurnal in-home:
    - menggabungkan torso per frame
    - menghitung doppler torso dari point cloud torso cluster
    - mengambil timestamp per frame dari df_clustered
    """

    # Precompute mapping frame -> timestamp (ambil yang pertama per frame)
    frame_to_ts = (
        df_clustered
        .sort_values(["frame", "timestamp"])
        .groupby("frame")["timestamp"]
        .first()
        .to_dict()
    )

    rows = []

    for idx, row in df_torso.iterrows():
        frame = int(row["frame"])
        torso_id = int(row["torso_cluster_id"])

        # skip frame gap → doppler_torso = NaN
        if torso_id == -1:
            doppler_torso = np.nan
        else:
            pts = df_clustered[
                (df_clustered["frame"] == frame) &
                (df_clustered["cluster_id"] == torso_id)
            ]
            if len(pts) > 0:
                doppler_torso = pts["doppler"].median()
            else:
                doppler_torso = np.nan

        # timestamp diambil dari clustered (kalau ada)
        ts_raw = frame_to_ts.get(frame, None)
        ts_sec = convert_timestamp_to_seconds(ts_raw) if ts_raw is not None else np.nan

        rows.append({
            "frame": frame,
            "timestamp": ts_raw,
            "timestamp_sec": ts_sec,
            "torso_x": row["torso_x"],
            "torso_y": row["torso_y"],
            "torso_z": row["torso_z"],
            "doppler_torso": doppler_torso,
            "is_gap": 1 if torso_id == -1 else 0,
        })

    df_gait = pd.DataFrame(rows)
    return df_gait

# %% [markdown]
# 🟦 CELL 4 – Fungsi pemrosesan otomatis untuk semua trial

# %%
def process_all_gait_frames(
    folder_cluster=FOLDER_CLUSTERED, 
    folder_torso=FOLDER_TORSO, 
    folder_out=FOLDER_GAITFRAME
):
    files = sorted(os.listdir(folder_torso))
    results = []

    for fname in files:
        if not fname.endswith("_torso.csv"):
            continue

        torso_path = os.path.join(folder_torso, fname)
        base = fname.replace("_clustered_torso.csv", "")

        cluster_file = base + "_clustered.csv"
        cluster_path = os.path.join(folder_cluster, cluster_file)

        if not os.path.exists(cluster_path):
            print(f"SKIP (cluster file not found): {cluster_path}")
            continue

        print(f"\n=== PROSES GAIT FRAME: {base} ===")

        df_torso = pd.read_csv(torso_path)
        df_cluster = pd.read_csv(cluster_path)

        df_gait = build_gait_frame(df_cluster, df_torso)

        out_csv = os.path.join(folder_out, f"{base}_gait_frame.csv")
        df_gait.to_csv(out_csv, index=False)

        print(f"Saved gait frame → {out_csv}")

        results.append({
            "trial": base,
            "frames": len(df_gait),
            "gap_frames": df_gait["is_gap"].sum()
        })

    return pd.DataFrame(results)

# %% [markdown]
# 🟦 CELL 5 – Jalankan pipeline otomatis

# %%
df_summary = process_all_gait_frames()
df_summary
# Out:
# === PROSES GAIT FRAME: Afi_Jalan10 ===
# Saved gait frame → E:\1.Clustering_TA\dataset\gaitframe\Afi_Jalan10_gait_frame.csv
#
# === PROSES GAIT FRAME: Afi_Jalan11 ===
# Saved gait frame → E:\1.Clustering_TA\dataset\gaitframe\Afi_Jalan11_gait_frame.csv
#
# === PROSES GAIT FRAME: Afi_Jalan12 ===
# Saved gait frame → E:\1.Clustering_TA\dataset\gaitframe\Afi_Jalan12_gait_frame.csv
#
# === PROSES GAIT FRAME: Afi_Jalan13 ===
# Saved gait frame → E:\1.Clustering_TA\dataset\gaitframe\Afi_Jalan13_gait_frame.csv
#
# === PROSES GAIT FRAME: Afi_Jalan14 ===
# Saved gait frame → E:\1.Clustering_TA\dataset\gaitframe\Afi_Jalan14_gait_frame.csv
#
# === PROSES GAIT FRAME: Afi_Jalan15 ===
# Saved gait frame → E:\1.Clustering_TA\dataset\gaitframe\Afi_Jalan15_gait_frame.csv
#
# === PROSES GAIT FRAME: Afi_Jalan16 ===
# Saved gait frame → E:\1.Clustering_TA\dataset\gaitframe\Afi_Jalan16_gait_frame.csv
#
# === PROSES GAIT FRAME: Afi_Jalan17 ===
# Saved gait frame → E:\1.Clustering_TA\dataset\gaitframe\Afi_Jalan17_gait_frame.csv
#
# === PROSES GAIT FRAME: Afi_Jalan18 ===
# Saved gait frame → E:\1.Clustering_TA\dataset\gaitframe\Afi_Jalan18_gait_frame.csv
#
# === PROSES GAIT FRAME: Afi_Jalan19 ===
# Saved gait frame → E:\1.Clustering_TA\dataset\gaitframe\Afi_Jalan19_gait_frame.csv
#
# === PROSES GAIT FRAME: Afi_Jalan1 ===
# Saved gait frame → E:\1.Clustering_TA\dataset\gaitframe\Afi_Jalan1_gait_frame.csv
#
# === PROSES GAIT FRAME: Afi_Jalan20 ===
# Saved gait frame → E:\1.Clustering_TA\dataset\gaitframe\Afi_Jalan20_gait_frame.csv
#
# === PROSES GAIT FRAME: Afi_Jalan21 ===
# Saved gait frame → E:\1.Clustering_TA\dataset\gaitframe\Afi_Jalan21_gait_frame.csv
#
# === PROSES GAIT FRAME: Afi_Jalan22 ===
# Saved gait frame → E:\1.Clustering_TA\dataset\gaitframe\Afi_Jalan22_gait_frame.csv
#
# === PROSES GAIT FRAME: Afi_Jalan23 ===
# Saved gait frame → E:\1.Clustering_TA\dataset\gaitframe\Afi_Jalan23_gait_frame.csv
#
# === PROSES GAIT FRAME: Afi_Jalan24 ===
# Saved gait frame → E:\1.Clustering_TA\dataset\gaitframe\Afi_Jalan24_gait_frame.csv
#
# === PROSES GAIT FRAME: Afi_Jalan25 ===
# Saved gait frame → E:\1.Clustering_TA\dataset\gaitframe\Afi_Jalan25_gait_frame.csv
#
# === PROSES GAIT FRAME: Afi_Jalan26 ===
# Saved gait frame → E:\1.Clustering_TA\dataset\gaitframe\Afi_Jalan26_gait_frame.csv
#
# === PROSES GAIT FRAME: Afi_Jalan27 ===
# Saved gait frame → E:\1.Clustering_TA\dataset\gaitframe\Afi_Jalan27_gait_frame.csv
#
# === PROSES GAIT FRAME: Afi_Jalan28 ===
# Saved gait frame → E:\1.Clustering_TA\dataset\gaitframe\Afi_Jalan28_gait_frame.csv
#
# === PROSES GAIT FRAME: Afi_Jalan29 ===
# Saved gait frame → E:\1.Clustering_TA\dataset\gaitframe\Afi_Jalan29_gait_frame.csv
#
# === PROSES GAIT FRAME: Afi_Jalan2 ===
# Saved gait frame → E:\1.Clustering_TA\dataset\gaitframe\Afi_Jalan2_gait_frame.csv
#
# === PROSES GAIT FRAME: Afi_Jalan30 ===
# Saved gait frame → E:\1.Clustering_TA\dataset\gaitframe\Afi_Jalan30_gait_frame.csv
#
# === PROSES GAIT FRAME: Afi_Jalan31 ===
# Saved gait frame → E:\1.Clustering_TA\dataset\gaitframe\Afi_Jalan31_gait_frame.csv
#
# === PROSES GAIT FRAME: Afi_Jalan32 ===
# Saved gait frame → E:\1.Clustering_TA\dataset\gaitframe\Afi_Jalan32_gait_frame.csv
#
# === PROSES GAIT FRAME: Afi_Jalan33 ===
# Saved gait frame → E:\1.Clustering_TA\dataset\gaitframe\Afi_Jalan33_gait_frame.csv
#
# === PROSES GAIT FRAME: Afi_Jalan34 ===
# Saved gait frame → E:\1.Clustering_TA\dataset\gaitframe\Afi_Jalan34_gait_frame.csv
#
# === PROSES GAIT FRAME: Afi_Jalan35 ===
# Saved gait frame → E:\1.Clustering_TA\dataset\gaitframe\Afi_Jalan35_gait_frame.csv
#
# === PROSES GAIT FRAME: Afi_Jalan36 ===
# Saved gait frame → E:\1.Clustering_TA\dataset\gaitframe\Afi_Jalan36_gait_frame.csv
#
# === PROSES GAIT FRAME: Afi_Jalan37 ===
# Saved gait frame → E:\1.Clustering_TA\dataset\gaitframe\Afi_Jalan37_gait_frame.csv
#
# === PROSES GAIT FRAME: Afi_Jalan38 ===
# Saved gait frame → E:\1.Clustering_TA\dataset\gaitframe\Afi_Jalan38_gait_frame.csv
#
# === PROSES GAIT FRAME: Afi_Jalan39 ===
# Saved gait frame → E:\1.Clustering_TA\dataset\gaitframe\Afi_Jalan39_gait_frame.csv
#
# === PROSES GAIT FRAME: Afi_Jalan3 ===
# Saved gait frame → E:\1.Clustering_TA\dataset\gaitframe\Afi_Jalan3_gait_frame.csv
#
# === PROSES GAIT FRAME: Afi_Jalan40 ===
# Saved gait frame → E:\1.Clustering_TA\dataset\gaitframe\Afi_Jalan40_gait_frame.csv
#
# === PROSES GAIT FRAME: Afi_Jalan41 ===
# Saved gait frame → E:\1.Clustering_TA\dataset\gaitframe\Afi_Jalan41_gait_frame.csv
#
# === PROSES GAIT FRAME: Afi_Jalan42 ===
# Saved gait frame → E:\1.Clustering_TA\dataset\gaitframe\Afi_Jalan42_gait_frame.csv
#
# === PROSES GAIT FRAME: Afi_Jalan43 ===
# Saved gait frame → E:\1.Clustering_TA\dataset\gaitframe\Afi_Jalan43_gait_frame.csv
#
# === PROSES GAIT FRAME: Afi_Jalan44 ===
# Saved gait frame → E:\1.Clustering_TA\dataset\gaitframe\Afi_Jalan44_gait_frame.csv
#
# === PROSES GAIT FRAME: Afi_Jalan45 ===
# Saved gait frame → E:\1.Clustering_TA\dataset\gaitframe\Afi_Jalan45_gait_frame.csv
#
# === PROSES GAIT FRAME: Afi_Jalan46 ===
# Saved gait frame → E:\1.Clustering_TA\dataset\gaitframe\Afi_Jalan46_gait_frame.csv
#
# === PROSES GAIT FRAME: Afi_Jalan47 ===
# Saved gait frame → E:\1.Clustering_TA\dataset\gaitframe\Afi_Jalan47_gait_frame.csv
#
# === PROSES GAIT FRAME: Afi_Jalan48 ===
# Saved gait frame → E:\1.Clustering_TA\dataset\gaitframe\Afi_Jalan48_gait_frame.csv
#
# === PROSES GAIT FRAME: Afi_Jalan49 ===
# Saved gait frame → E:\1.Clustering_TA\dataset\gaitframe\Afi_Jalan49_gait_frame.csv
#
# === PROSES GAIT FRAME: Afi_Jalan4 ===
# Saved gait frame → E:\1.Clustering_TA\dataset\gaitframe\Afi_Jalan4_gait_frame.csv
#
# === PROSES GAIT FRAME: Afi_Jalan50 ===
# Saved gait frame → E:\1.Clustering_TA\dataset\gaitframe\Afi_Jalan50_gait_frame.csv
#
# === PROSES GAIT FRAME: Afi_Jalan51 ===
# Saved gait frame → E:\1.Clustering_TA\dataset\gaitframe\Afi_Jalan51_gait_frame.csv
#
# === PROSES GAIT FRAME: Afi_Jalan52 ===
# Saved gait frame → E:\1.Clustering_TA\dataset\gaitframe\Afi_Jalan52_gait_frame.csv
#
# === PROSES GAIT FRAME: Afi_Jalan53 ===
# Saved gait frame → E:\1.Clustering_TA\dataset\gaitframe\Afi_Jalan53_gait_frame.csv
#
# === PROSES GAIT FRAME: Afi_Jalan54 ===
# Saved gait frame → E:\1.Clustering_TA\dataset\gaitframe\Afi_Jalan54_gait_frame.csv
#
# === PROSES GAIT FRAME: Afi_Jalan55 ===
# Saved gait frame → E:\1.Clustering_TA\dataset\gaitframe\Afi_Jalan55_gait_frame.csv
#
# === PROSES GAIT FRAME: Afi_Jalan56 ===
# Saved gait frame → E:\1.Clustering_TA\dataset\gaitframe\Afi_Jalan56_gait_frame.csv
#
# === PROSES GAIT FRAME: Afi_Jalan57 ===
# Saved gait frame → E:\1.Clustering_TA\dataset\gaitframe\Afi_Jalan57_gait_frame.csv
#
# === PROSES GAIT FRAME: Afi_Jalan58 ===
# Saved gait frame → E:\1.Clustering_TA\dataset\gaitframe\Afi_Jalan58_gait_frame.csv
#
# === PROSES GAIT FRAME: Afi_Jalan59 ===
# Saved gait frame → E:\1.Clustering_TA\dataset\gaitframe\Afi_Jalan59_gait_frame.csv
#
# === PROSES GAIT FRAME: Afi_Jalan5 ===
# Saved gait frame → E:\1.Clustering_TA\dataset\gaitframe\Afi_Jalan5_gait_frame.csv
#
# === PROSES GAIT FRAME: Afi_Jalan60 ===
# Saved gait frame → E:\1.Clustering_TA\dataset\gaitframe\Afi_Jalan60_gait_frame.csv
#
# === PROSES GAIT FRAME: Afi_Jalan61 ===
# Saved gait frame → E:\1.Clustering_TA\dataset\gaitframe\Afi_Jalan61_gait_frame.csv
#
# === PROSES GAIT FRAME: Afi_Jalan62 ===
# Saved gait frame → E:\1.Clustering_TA\dataset\gaitframe\Afi_Jalan62_gait_frame.csv
#
# === PROSES GAIT FRAME: Afi_Jalan63 ===
# Saved gait frame → E:\1.Clustering_TA\dataset\gaitframe\Afi_Jalan63_gait_frame.csv
#
# === PROSES GAIT FRAME: Afi_Jalan64 ===
# Saved gait frame → E:\1.Clustering_TA\dataset\gaitframe\Afi_Jalan64_gait_frame.csv
#
# === PROSES GAIT FRAME: Afi_Jalan65 ===
# Saved gait frame → E:\1.Clustering_TA\dataset\gaitframe\Afi_Jalan65_gait_frame.csv
#
# === PROSES GAIT FRAME: Afi_Jalan66 ===
# Saved gait frame → E:\1.Clustering_TA\dataset\gaitframe\Afi_Jalan66_gait_frame.csv
#
# === PROSES GAIT FRAME: Afi_Jalan67 ===
# Saved gait frame → E:\1.Clustering_TA\dataset\gaitframe\Afi_Jalan67_gait_frame.csv
#
# === PROSES GAIT FRAME: Afi_Jalan68 ===
# Saved gait frame → E:\1.Clustering_TA\dataset\gaitframe\Afi_Jalan68_gait_frame.csv
#
# === PROSES GAIT FRAME: Afi_Jalan69 ===
# Saved gait frame → E:\1.Clustering_TA\dataset\gaitframe\Afi_Jalan69_gait_frame.csv
#
# === PROSES GAIT FRAME: Afi_Jalan6 ===
# Saved gait frame → E:\1.Clustering_TA\dataset\gaitframe\Afi_Jalan6_gait_frame.csv
#
# === PROSES GAIT FRAME: Afi_Jalan70 ===
# Saved gait frame → E:\1.Clustering_TA\dataset\gaitframe\Afi_Jalan70_gait_frame.csv
#
# === PROSES GAIT FRAME: Afi_Jalan71 ===
# Saved gait frame → E:\1.Clustering_TA\dataset\gaitframe\Afi_Jalan71_gait_frame.csv
#
# === PROSES GAIT FRAME: Afi_Jalan72 ===
# Saved gait frame → E:\1.Clustering_TA\dataset\gaitframe\Afi_Jalan72_gait_frame.csv
#
# === PROSES GAIT FRAME: Afi_Jalan7 ===
# Saved gait frame → E:\1.Clustering_TA\dataset\gaitframe\Afi_Jalan7_gait_frame.csv
#
# === PROSES GAIT FRAME: Afi_Jalan8 ===
# Saved gait frame → E:\1.Clustering_TA\dataset\gaitframe\Afi_Jalan8_gait_frame.csv
#
# === PROSES GAIT FRAME: Afi_Jalan9 ===
# Saved gait frame → E:\1.Clustering_TA\dataset\gaitframe\Afi_Jalan9_gait_frame.csv
#
# === PROSES GAIT FRAME: Kinan_Jalan10 ===
# Saved gait frame → E:\1.Clustering_TA\dataset\gaitframe\Kinan_Jalan10_gait_frame.csv
#
# === PROSES GAIT FRAME: Kinan_Jalan11 ===
# Saved gait frame → E:\1.Clustering_TA\dataset\gaitframe\Kinan_Jalan11_gait_frame.csv
#
# === PROSES GAIT FRAME: Kinan_Jalan12 ===
# Saved gait frame → E:\1.Clustering_TA\dataset\gaitframe\Kinan_Jalan12_gait_frame.csv
#
# === PROSES GAIT FRAME: Kinan_Jalan13 ===
# Saved gait frame → E:\1.Clustering_TA\dataset\gaitframe\Kinan_Jalan13_gait_frame.csv
#
# === PROSES GAIT FRAME: Kinan_Jalan14 ===
# Saved gait frame → E:\1.Clustering_TA\dataset\gaitframe\Kinan_Jalan14_gait_frame.csv
#
# === PROSES GAIT FRAME: Kinan_Jalan15 ===
# Saved gait frame → E:\1.Clustering_TA\dataset\gaitframe\Kinan_Jalan15_gait_frame.csv
#
# === PROSES GAIT FRAME: Kinan_Jalan16 ===
# Saved gait frame → E:\1.Clustering_TA\dataset\gaitframe\Kinan_Jalan16_gait_frame.csv
#
# === PROSES GAIT FRAME: Kinan_Jalan17 ===
# Saved gait frame → E:\1.Clustering_TA\dataset\gaitframe\Kinan_Jalan17_gait_frame.csv
#
# === PROSES GAIT FRAME: Kinan_Jalan18 ===
# Saved gait frame → E:\1.Clustering_TA\dataset\gaitframe\Kinan_Jalan18_gait_frame.csv
#
# === PROSES GAIT FRAME: Kinan_Jalan19 ===
# Saved gait frame → E:\1.Clustering_TA\dataset\gaitframe\Kinan_Jalan19_gait_frame.csv
#
# === PROSES GAIT FRAME: Kinan_Jalan1 ===
# Saved gait frame → E:\1.Clustering_TA\dataset\gaitframe\Kinan_Jalan1_gait_frame.csv
#
# === PROSES GAIT FRAME: Kinan_Jalan20 ===
# Saved gait frame → E:\1.Clustering_TA\dataset\gaitframe\Kinan_Jalan20_gait_frame.csv
#
# === PROSES GAIT FRAME: Kinan_Jalan21 ===
# Saved gait frame → E:\1.Clustering_TA\dataset\gaitframe\Kinan_Jalan21_gait_frame.csv
#
# === PROSES GAIT FRAME: Kinan_Jalan22 ===
# Saved gait frame → E:\1.Clustering_TA\dataset\gaitframe\Kinan_Jalan22_gait_frame.csv
#
# === PROSES GAIT FRAME: Kinan_Jalan23 ===
# Saved gait frame → E:\1.Clustering_TA\dataset\gaitframe\Kinan_Jalan23_gait_frame.csv
#
# === PROSES GAIT FRAME: Kinan_Jalan24 ===
# Saved gait frame → E:\1.Clustering_TA\dataset\gaitframe\Kinan_Jalan24_gait_frame.csv
#
# === PROSES GAIT FRAME: Kinan_Jalan25 ===
# Saved gait frame → E:\1.Clustering_TA\dataset\gaitframe\Kinan_Jalan25_gait_frame.csv
#
# === PROSES GAIT FRAME: Kinan_Jalan26 ===
# Saved gait frame → E:\1.Clustering_TA\dataset\gaitframe\Kinan_Jalan26_gait_frame.csv
#
# === PROSES GAIT FRAME: Kinan_Jalan27 ===
# Saved gait frame → E:\1.Clustering_TA\dataset\gaitframe\Kinan_Jalan27_gait_frame.csv
#
# === PROSES GAIT FRAME: Kinan_Jalan28 ===
# Saved gait frame → E:\1.Clustering_TA\dataset\gaitframe\Kinan_Jalan28_gait_frame.csv
#
# === PROSES GAIT FRAME: Kinan_Jalan29 ===
# Saved gait frame → E:\1.Clustering_TA\dataset\gaitframe\Kinan_Jalan29_gait_frame.csv
#
# === PROSES GAIT FRAME: Kinan_Jalan2 ===
# Saved gait frame → E:\1.Clustering_TA\dataset\gaitframe\Kinan_Jalan2_gait_frame.csv
#
# === PROSES GAIT FRAME: Kinan_Jalan30 ===
# Saved gait frame → E:\1.Clustering_TA\dataset\gaitframe\Kinan_Jalan30_gait_frame.csv
#
# === PROSES GAIT FRAME: Kinan_Jalan31 ===
# Saved gait frame → E:\1.Clustering_TA\dataset\gaitframe\Kinan_Jalan31_gait_frame.csv
#
# === PROSES GAIT FRAME: Kinan_Jalan32 ===
# Saved gait frame → E:\1.Clustering_TA\dataset\gaitframe\Kinan_Jalan32_gait_frame.csv
#
# === PROSES GAIT FRAME: Kinan_Jalan33 ===
# Saved gait frame → E:\1.Clustering_TA\dataset\gaitframe\Kinan_Jalan33_gait_frame.csv
#
# === PROSES GAIT FRAME: Kinan_Jalan34 ===
# Saved gait frame → E:\1.Clustering_TA\dataset\gaitframe\Kinan_Jalan34_gait_frame.csv
#
# === PROSES GAIT FRAME: Kinan_Jalan35 ===
# Saved gait frame → E:\1.Clustering_TA\dataset\gaitframe\Kinan_Jalan35_gait_frame.csv
#
# === PROSES GAIT FRAME: Kinan_Jalan36 ===
# Saved gait frame → E:\1.Clustering_TA\dataset\gaitframe\Kinan_Jalan36_gait_frame.csv
#
# === PROSES GAIT FRAME: Kinan_Jalan37 ===
# Saved gait frame → E:\1.Clustering_TA\dataset\gaitframe\Kinan_Jalan37_gait_frame.csv
#
# === PROSES GAIT FRAME: Kinan_Jalan38 ===
# Saved gait frame → E:\1.Clustering_TA\dataset\gaitframe\Kinan_Jalan38_gait_frame.csv
#
# === PROSES GAIT FRAME: Kinan_Jalan39 ===
# Saved gait frame → E:\1.Clustering_TA\dataset\gaitframe\Kinan_Jalan39_gait_frame.csv
#
# === PROSES GAIT FRAME: Kinan_Jalan3 ===
# Saved gait frame → E:\1.Clustering_TA\dataset\gaitframe\Kinan_Jalan3_gait_frame.csv
#
# === PROSES GAIT FRAME: Kinan_Jalan40 ===
# Saved gait frame → E:\1.Clustering_TA\dataset\gaitframe\Kinan_Jalan40_gait_frame.csv
#
# === PROSES GAIT FRAME: Kinan_Jalan41 ===
# Saved gait frame → E:\1.Clustering_TA\dataset\gaitframe\Kinan_Jalan41_gait_frame.csv
#
# === PROSES GAIT FRAME: Kinan_Jalan42 ===
# Saved gait frame → E:\1.Clustering_TA\dataset\gaitframe\Kinan_Jalan42_gait_frame.csv
#
# === PROSES GAIT FRAME: Kinan_Jalan43 ===
# Saved gait frame → E:\1.Clustering_TA\dataset\gaitframe\Kinan_Jalan43_gait_frame.csv
#
# === PROSES GAIT FRAME: Kinan_Jalan44 ===
# Saved gait frame → E:\1.Clustering_TA\dataset\gaitframe\Kinan_Jalan44_gait_frame.csv
#
# === PROSES GAIT FRAME: Kinan_Jalan45 ===
# Saved gait frame → E:\1.Clustering_TA\dataset\gaitframe\Kinan_Jalan45_gait_frame.csv
#
# === PROSES GAIT FRAME: Kinan_Jalan46 ===
# Saved gait frame → E:\1.Clustering_TA\dataset\gaitframe\Kinan_Jalan46_gait_frame.csv
#
# === PROSES GAIT FRAME: Kinan_Jalan47 ===
# Saved gait frame → E:\1.Clustering_TA\dataset\gaitframe\Kinan_Jalan47_gait_frame.csv
#
# === PROSES GAIT FRAME: Kinan_Jalan48 ===
# Saved gait frame → E:\1.Clustering_TA\dataset\gaitframe\Kinan_Jalan48_gait_frame.csv
#
# === PROSES GAIT FRAME: Kinan_Jalan49 ===
# Saved gait frame → E:\1.Clustering_TA\dataset\gaitframe\Kinan_Jalan49_gait_frame.csv
#
# === PROSES GAIT FRAME: Kinan_Jalan4 ===
# Saved gait frame → E:\1.Clustering_TA\dataset\gaitframe\Kinan_Jalan4_gait_frame.csv
#
# === PROSES GAIT FRAME: Kinan_Jalan50 ===
# Saved gait frame → E:\1.Clustering_TA\dataset\gaitframe\Kinan_Jalan50_gait_frame.csv
#
# === PROSES GAIT FRAME: Kinan_Jalan51 ===
# Saved gait frame → E:\1.Clustering_TA\dataset\gaitframe\Kinan_Jalan51_gait_frame.csv
#
# === PROSES GAIT FRAME: Kinan_Jalan52 ===
# Saved gait frame → E:\1.Clustering_TA\dataset\gaitframe\Kinan_Jalan52_gait_frame.csv
#
# === PROSES GAIT FRAME: Kinan_Jalan53 ===
# Saved gait frame → E:\1.Clustering_TA\dataset\gaitframe\Kinan_Jalan53_gait_frame.csv
#
# === PROSES GAIT FRAME: Kinan_Jalan54 ===
# Saved gait frame → E:\1.Clustering_TA\dataset\gaitframe\Kinan_Jalan54_gait_frame.csv
#
# === PROSES GAIT FRAME: Kinan_Jalan55 ===
# Saved gait frame → E:\1.Clustering_TA\dataset\gaitframe\Kinan_Jalan55_gait_frame.csv
#
# === PROSES GAIT FRAME: Kinan_Jalan56 ===
# Saved gait frame → E:\1.Clustering_TA\dataset\gaitframe\Kinan_Jalan56_gait_frame.csv
#
# === PROSES GAIT FRAME: Kinan_Jalan57 ===
# Saved gait frame → E:\1.Clustering_TA\dataset\gaitframe\Kinan_Jalan57_gait_frame.csv
#
# === PROSES GAIT FRAME: Kinan_Jalan58 ===
# Saved gait frame → E:\1.Clustering_TA\dataset\gaitframe\Kinan_Jalan58_gait_frame.csv
#
# === PROSES GAIT FRAME: Kinan_Jalan59 ===
# Saved gait frame → E:\1.Clustering_TA\dataset\gaitframe\Kinan_Jalan59_gait_frame.csv
#
# === PROSES GAIT FRAME: Kinan_Jalan5 ===
# Saved gait frame → E:\1.Clustering_TA\dataset\gaitframe\Kinan_Jalan5_gait_frame.csv
#
# === PROSES GAIT FRAME: Kinan_Jalan60 ===
# Saved gait frame → E:\1.Clustering_TA\dataset\gaitframe\Kinan_Jalan60_gait_frame.csv
#
# === PROSES GAIT FRAME: Kinan_Jalan61 ===
# Saved gait frame → E:\1.Clustering_TA\dataset\gaitframe\Kinan_Jalan61_gait_frame.csv
#
# === PROSES GAIT FRAME: Kinan_Jalan62 ===
# Saved gait frame → E:\1.Clustering_TA\dataset\gaitframe\Kinan_Jalan62_gait_frame.csv
#
# === PROSES GAIT FRAME: Kinan_Jalan63 ===
# Saved gait frame → E:\1.Clustering_TA\dataset\gaitframe\Kinan_Jalan63_gait_frame.csv
#
# === PROSES GAIT FRAME: Kinan_Jalan64 ===
# Saved gait frame → E:\1.Clustering_TA\dataset\gaitframe\Kinan_Jalan64_gait_frame.csv
#
# === PROSES GAIT FRAME: Kinan_Jalan65 ===
# Saved gait frame → E:\1.Clustering_TA\dataset\gaitframe\Kinan_Jalan65_gait_frame.csv
#
# === PROSES GAIT FRAME: Kinan_Jalan66 ===
# Saved gait frame → E:\1.Clustering_TA\dataset\gaitframe\Kinan_Jalan66_gait_frame.csv
#
# === PROSES GAIT FRAME: Kinan_Jalan67 ===
# Saved gait frame → E:\1.Clustering_TA\dataset\gaitframe\Kinan_Jalan67_gait_frame.csv
#
# === PROSES GAIT FRAME: Kinan_Jalan68 ===
# Saved gait frame → E:\1.Clustering_TA\dataset\gaitframe\Kinan_Jalan68_gait_frame.csv
#
# === PROSES GAIT FRAME: Kinan_Jalan69 ===
# Saved gait frame → E:\1.Clustering_TA\dataset\gaitframe\Kinan_Jalan69_gait_frame.csv
#
# === PROSES GAIT FRAME: Kinan_Jalan6 ===
# Saved gait frame → E:\1.Clustering_TA\dataset\gaitframe\Kinan_Jalan6_gait_frame.csv
#
# === PROSES GAIT FRAME: Kinan_Jalan70 ===
# Saved gait frame → E:\1.Clustering_TA\dataset\gaitframe\Kinan_Jalan70_gait_frame.csv
#
# === PROSES GAIT FRAME: Kinan_Jalan71 ===
# Saved gait frame → E:\1.Clustering_TA\dataset\gaitframe\Kinan_Jalan71_gait_frame.csv
#
# === PROSES GAIT FRAME: Kinan_Jalan72 ===
# Saved gait frame → E:\1.Clustering_TA\dataset\gaitframe\Kinan_Jalan72_gait_frame.csv
#
# === PROSES GAIT FRAME: Kinan_Jalan7 ===
# Saved gait frame → E:\1.Clustering_TA\dataset\gaitframe\Kinan_Jalan7_gait_frame.csv
#
# === PROSES GAIT FRAME: Kinan_Jalan8 ===
# Saved gait frame → E:\1.Clustering_TA\dataset\gaitframe\Kinan_Jalan8_gait_frame.csv
#
# === PROSES GAIT FRAME: Kinan_Jalan9 ===
# Saved gait frame → E:\1.Clustering_TA\dataset\gaitframe\Kinan_Jalan9_gait_frame.csv
#
# === PROSES GAIT FRAME: Miftah_Jalan10 ===
# Saved gait frame → E:\1.Clustering_TA\dataset\gaitframe\Miftah_Jalan10_gait_frame.csv
#
# === PROSES GAIT FRAME: Miftah_Jalan11 ===
# Saved gait frame → E:\1.Clustering_TA\dataset\gaitframe\Miftah_Jalan11_gait_frame.csv
#
# === PROSES GAIT FRAME: Miftah_Jalan12 ===
# Saved gait frame → E:\1.Clustering_TA\dataset\gaitframe\Miftah_Jalan12_gait_frame.csv
#
# === PROSES GAIT FRAME: Miftah_Jalan13 ===
# Saved gait frame → E:\1.Clustering_TA\dataset\gaitframe\Miftah_Jalan13_gait_frame.csv
#
# === PROSES GAIT FRAME: Miftah_Jalan14 ===
# Saved gait frame → E:\1.Clustering_TA\dataset\gaitframe\Miftah_Jalan14_gait_frame.csv
#
# === PROSES GAIT FRAME: Miftah_Jalan15 ===
# Saved gait frame → E:\1.Clustering_TA\dataset\gaitframe\Miftah_Jalan15_gait_frame.csv
#
# === PROSES GAIT FRAME: Miftah_Jalan16 ===
# Saved gait frame → E:\1.Clustering_TA\dataset\gaitframe\Miftah_Jalan16_gait_frame.csv
#
# === PROSES GAIT FRAME: Miftah_Jalan17 ===
# Saved gait frame → E:\1.Clustering_TA\dataset\gaitframe\Miftah_Jalan17_gait_frame.csv
#
# === PROSES GAIT FRAME: Miftah_Jalan18 ===
# Saved gait frame → E:\1.Clustering_TA\dataset\gaitframe\Miftah_Jalan18_gait_frame.csv
#
# === PROSES GAIT FRAME: Miftah_Jalan19 ===
# Saved gait frame → E:\1.Clustering_TA\dataset\gaitframe\Miftah_Jalan19_gait_frame.csv
#
# === PROSES GAIT FRAME: Miftah_Jalan1 ===
# Saved gait frame → E:\1.Clustering_TA\dataset\gaitframe\Miftah_Jalan1_gait_frame.csv
#
# === PROSES GAIT FRAME: Miftah_Jalan20 ===
# Saved gait frame → E:\1.Clustering_TA\dataset\gaitframe\Miftah_Jalan20_gait_frame.csv
#
# === PROSES GAIT FRAME: Miftah_Jalan21 ===
# Saved gait frame → E:\1.Clustering_TA\dataset\gaitframe\Miftah_Jalan21_gait_frame.csv
#
# === PROSES GAIT FRAME: Miftah_Jalan22 ===
# Saved gait frame → E:\1.Clustering_TA\dataset\gaitframe\Miftah_Jalan22_gait_frame.csv
#
# === PROSES GAIT FRAME: Miftah_Jalan23 ===
# Saved gait frame → E:\1.Clustering_TA\dataset\gaitframe\Miftah_Jalan23_gait_frame.csv
#
# === PROSES GAIT FRAME: Miftah_Jalan24 ===
# Saved gait frame → E:\1.Clustering_TA\dataset\gaitframe\Miftah_Jalan24_gait_frame.csv
#
# === PROSES GAIT FRAME: Miftah_Jalan25 ===
# Saved gait frame → E:\1.Clustering_TA\dataset\gaitframe\Miftah_Jalan25_gait_frame.csv
#
# === PROSES GAIT FRAME: Miftah_Jalan26 ===
# Saved gait frame → E:\1.Clustering_TA\dataset\gaitframe\Miftah_Jalan26_gait_frame.csv
#
# === PROSES GAIT FRAME: Miftah_Jalan27 ===
# Saved gait frame → E:\1.Clustering_TA\dataset\gaitframe\Miftah_Jalan27_gait_frame.csv
#
# === PROSES GAIT FRAME: Miftah_Jalan28 ===
# Saved gait frame → E:\1.Clustering_TA\dataset\gaitframe\Miftah_Jalan28_gait_frame.csv
#
# === PROSES GAIT FRAME: Miftah_Jalan29 ===
# Saved gait frame → E:\1.Clustering_TA\dataset\gaitframe\Miftah_Jalan29_gait_frame.csv
#
# === PROSES GAIT FRAME: Miftah_Jalan2 ===
# Saved gait frame → E:\1.Clustering_TA\dataset\gaitframe\Miftah_Jalan2_gait_frame.csv
#
# === PROSES GAIT FRAME: Miftah_Jalan30 ===
# Saved gait frame → E:\1.Clustering_TA\dataset\gaitframe\Miftah_Jalan30_gait_frame.csv
#
# === PROSES GAIT FRAME: Miftah_Jalan31 ===
# Saved gait frame → E:\1.Clustering_TA\dataset\gaitframe\Miftah_Jalan31_gait_frame.csv
#
# === PROSES GAIT FRAME: Miftah_Jalan32 ===
# Saved gait frame → E:\1.Clustering_TA\dataset\gaitframe\Miftah_Jalan32_gait_frame.csv
#
# === PROSES GAIT FRAME: Miftah_Jalan33 ===
# Saved gait frame → E:\1.Clustering_TA\dataset\gaitframe\Miftah_Jalan33_gait_frame.csv
#
# === PROSES GAIT FRAME: Miftah_Jalan34 ===
# Saved gait frame → E:\1.Clustering_TA\dataset\gaitframe\Miftah_Jalan34_gait_frame.csv
#
# === PROSES GAIT FRAME: Miftah_Jalan35 ===
# Saved gait frame → E:\1.Clustering_TA\dataset\gaitframe\Miftah_Jalan35_gait_frame.csv
#
# === PROSES GAIT FRAME: Miftah_Jalan36 ===
# Saved gait frame → E:\1.Clustering_TA\dataset\gaitframe\Miftah_Jalan36_gait_frame.csv
#
# === PROSES GAIT FRAME: Miftah_Jalan37 ===
# Saved gait frame → E:\1.Clustering_TA\dataset\gaitframe\Miftah_Jalan37_gait_frame.csv
#
# === PROSES GAIT FRAME: Miftah_Jalan38 ===
# Saved gait frame → E:\1.Clustering_TA\dataset\gaitframe\Miftah_Jalan38_gait_frame.csv
#
# === PROSES GAIT FRAME: Miftah_Jalan39 ===
# Saved gait frame → E:\1.Clustering_TA\dataset\gaitframe\Miftah_Jalan39_gait_frame.csv
#
# === PROSES GAIT FRAME: Miftah_Jalan3 ===
# Saved gait frame → E:\1.Clustering_TA\dataset\gaitframe\Miftah_Jalan3_gait_frame.csv
#
# === PROSES GAIT FRAME: Miftah_Jalan40 ===
# Saved gait frame → E:\1.Clustering_TA\dataset\gaitframe\Miftah_Jalan40_gait_frame.csv
#
# === PROSES GAIT FRAME: Miftah_Jalan41 ===
# Saved gait frame → E:\1.Clustering_TA\dataset\gaitframe\Miftah_Jalan41_gait_frame.csv
#
# === PROSES GAIT FRAME: Miftah_Jalan42 ===
# Saved gait frame → E:\1.Clustering_TA\dataset\gaitframe\Miftah_Jalan42_gait_frame.csv
#
# === PROSES GAIT FRAME: Miftah_Jalan43 ===
# Saved gait frame → E:\1.Clustering_TA\dataset\gaitframe\Miftah_Jalan43_gait_frame.csv
#
# === PROSES GAIT FRAME: Miftah_Jalan44 ===
# Saved gait frame → E:\1.Clustering_TA\dataset\gaitframe\Miftah_Jalan44_gait_frame.csv
#
# === PROSES GAIT FRAME: Miftah_Jalan45 ===
# Saved gait frame → E:\1.Clustering_TA\dataset\gaitframe\Miftah_Jalan45_gait_frame.csv
#
# === PROSES GAIT FRAME: Miftah_Jalan46 ===
# Saved gait frame → E:\1.Clustering_TA\dataset\gaitframe\Miftah_Jalan46_gait_frame.csv
#
# === PROSES GAIT FRAME: Miftah_Jalan47 ===
# Saved gait frame → E:\1.Clustering_TA\dataset\gaitframe\Miftah_Jalan47_gait_frame.csv
#
# === PROSES GAIT FRAME: Miftah_Jalan48 ===
# Saved gait frame → E:\1.Clustering_TA\dataset\gaitframe\Miftah_Jalan48_gait_frame.csv
#
# === PROSES GAIT FRAME: Miftah_Jalan49 ===
# Saved gait frame → E:\1.Clustering_TA\dataset\gaitframe\Miftah_Jalan49_gait_frame.csv
#
# === PROSES GAIT FRAME: Miftah_Jalan4 ===
# Saved gait frame → E:\1.Clustering_TA\dataset\gaitframe\Miftah_Jalan4_gait_frame.csv
#
# === PROSES GAIT FRAME: Miftah_Jalan50 ===
# Saved gait frame → E:\1.Clustering_TA\dataset\gaitframe\Miftah_Jalan50_gait_frame.csv
#
# === PROSES GAIT FRAME: Miftah_Jalan51 ===
# Saved gait frame → E:\1.Clustering_TA\dataset\gaitframe\Miftah_Jalan51_gait_frame.csv
#
# === PROSES GAIT FRAME: Miftah_Jalan52 ===
# Saved gait frame → E:\1.Clustering_TA\dataset\gaitframe\Miftah_Jalan52_gait_frame.csv
#
# === PROSES GAIT FRAME: Miftah_Jalan53 ===
# Saved gait frame → E:\1.Clustering_TA\dataset\gaitframe\Miftah_Jalan53_gait_frame.csv
#
# === PROSES GAIT FRAME: Miftah_Jalan54 ===
# Saved gait frame → E:\1.Clustering_TA\dataset\gaitframe\Miftah_Jalan54_gait_frame.csv
#
# === PROSES GAIT FRAME: Miftah_Jalan55 ===
# Saved gait frame → E:\1.Clustering_TA\dataset\gaitframe\Miftah_Jalan55_gait_frame.csv
#
# === PROSES GAIT FRAME: Miftah_Jalan56 ===
# Saved gait frame → E:\1.Clustering_TA\dataset\gaitframe\Miftah_Jalan56_gait_frame.csv
#
# === PROSES GAIT FRAME: Miftah_Jalan57 ===
# Saved gait frame → E:\1.Clustering_TA\dataset\gaitframe\Miftah_Jalan57_gait_frame.csv
#
# === PROSES GAIT FRAME: Miftah_Jalan58 ===
# Saved gait frame → E:\1.Clustering_TA\dataset\gaitframe\Miftah_Jalan58_gait_frame.csv
#
# === PROSES GAIT FRAME: Miftah_Jalan59 ===
# Saved gait frame → E:\1.Clustering_TA\dataset\gaitframe\Miftah_Jalan59_gait_frame.csv
#
# === PROSES GAIT FRAME: Miftah_Jalan5 ===
# Saved gait frame → E:\1.Clustering_TA\dataset\gaitframe\Miftah_Jalan5_gait_frame.csv
#
# === PROSES GAIT FRAME: Miftah_Jalan60 ===
# Saved gait frame → E:\1.Clustering_TA\dataset\gaitframe\Miftah_Jalan60_gait_frame.csv
#
# === PROSES GAIT FRAME: Miftah_Jalan61 ===
# Saved gait frame → E:\1.Clustering_TA\dataset\gaitframe\Miftah_Jalan61_gait_frame.csv
#
# === PROSES GAIT FRAME: Miftah_Jalan62 ===
# Saved gait frame → E:\1.Clustering_TA\dataset\gaitframe\Miftah_Jalan62_gait_frame.csv
#
# === PROSES GAIT FRAME: Miftah_Jalan63 ===
# Saved gait frame → E:\1.Clustering_TA\dataset\gaitframe\Miftah_Jalan63_gait_frame.csv
#
# === PROSES GAIT FRAME: Miftah_Jalan64 ===
# Saved gait frame → E:\1.Clustering_TA\dataset\gaitframe\Miftah_Jalan64_gait_frame.csv
#
# === PROSES GAIT FRAME: Miftah_Jalan65 ===
# Saved gait frame → E:\1.Clustering_TA\dataset\gaitframe\Miftah_Jalan65_gait_frame.csv
#
# === PROSES GAIT FRAME: Miftah_Jalan66 ===
# Saved gait frame → E:\1.Clustering_TA\dataset\gaitframe\Miftah_Jalan66_gait_frame.csv
#
# === PROSES GAIT FRAME: Miftah_Jalan67 ===
# Saved gait frame → E:\1.Clustering_TA\dataset\gaitframe\Miftah_Jalan67_gait_frame.csv
#
# === PROSES GAIT FRAME: Miftah_Jalan68 ===
# Saved gait frame → E:\1.Clustering_TA\dataset\gaitframe\Miftah_Jalan68_gait_frame.csv
#
# === PROSES GAIT FRAME: Miftah_Jalan69 ===
# Saved gait frame → E:\1.Clustering_TA\dataset\gaitframe\Miftah_Jalan69_gait_frame.csv
#
# === PROSES GAIT FRAME: Miftah_Jalan6 ===
# Saved gait frame → E:\1.Clustering_TA\dataset\gaitframe\Miftah_Jalan6_gait_frame.csv
#
# === PROSES GAIT FRAME: Miftah_Jalan70 ===
# Saved gait frame → E:\1.Clustering_TA\dataset\gaitframe\Miftah_Jalan70_gait_frame.csv
#
# === PROSES GAIT FRAME: Miftah_Jalan71 ===
# Saved gait frame → E:\1.Clustering_TA\dataset\gaitframe\Miftah_Jalan71_gait_frame.csv
#
# === PROSES GAIT FRAME: Miftah_Jalan72 ===
# Saved gait frame → E:\1.Clustering_TA\dataset\gaitframe\Miftah_Jalan72_gait_frame.csv
#
# === PROSES GAIT FRAME: Miftah_Jalan7 ===
# Saved gait frame → E:\1.Clustering_TA\dataset\gaitframe\Miftah_Jalan7_gait_frame.csv
#
# === PROSES GAIT FRAME: Miftah_Jalan8 ===
# Saved gait frame → E:\1.Clustering_TA\dataset\gaitframe\Miftah_Jalan8_gait_frame.csv
#
# === PROSES GAIT FRAME: Miftah_Jalan9 ===
# Saved gait frame → E:\1.Clustering_TA\dataset\gaitframe\Miftah_Jalan9_gait_frame.csv
#               trial  frames  gap_frames
# 0       Afi_Jalan10      79           2
# 1       Afi_Jalan11      82           6
# 2       Afi_Jalan12     110          16
# 3       Afi_Jalan13      59           0
# 4       Afi_Jalan14      78          11
# ..              ...     ...         ...
# 211  Miftah_Jalan71     265          12
# 212  Miftah_Jalan72     366           9
# 213   Miftah_Jalan7     102           0
# 214   Miftah_Jalan8     101           4
# 215   Miftah_Jalan9     126           1
#
# [216 rows x 3 columns]
