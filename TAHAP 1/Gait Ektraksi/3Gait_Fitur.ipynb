# %% [markdown]
# 🟦 Cell 1 – Import & konfigurasi folder

# %%
import os
import numpy as np
import pandas as pd

# Folder input: hasil Tahap 3 (gait + steps) – SAMA seperti V1
FOLDER_GAITFRAME_STEPS = r"E:\1.Clustering_TA\dataset\gaitframe_steps"

# Folder output untuk V2 (baru)
FOLDER_GAIT_FEATURES_FINAL_ROOT_V2 = r"E:\1.Clustering_TA\dataset\gait_features_final_v2_filtered"
os.makedirs(FOLDER_GAIT_FEATURES_FINAL_ROOT_V2, exist_ok=True)

print("Input gait_with_steps  :", FOLDER_GAITFRAME_STEPS)
print("Output root V2         :", FOLDER_GAIT_FEATURES_FINAL_ROOT_V2)
# Out:
# Input gait_with_steps  : E:\1.Clustering_TA\dataset\gaitframe_steps
# Output root V2         : E:\1.Clustering_TA\dataset\gait_features_final_v2_filtered

# %% [markdown]
# 🟦 Cell 2 – Helper: konversi timestamp (pakai lagi)

# %%
def timestamp_to_seconds(ts):
    """
    Mengubah string timestamp "HH:MM:SS.micro" menjadi detik (float).
    Kalau gagal parse → np.nan
    """
    if pd.isna(ts):
        return np.nan
    try:
        hms = str(ts).split(":")
        if len(hms) != 3:
            return np.nan
        h = int(hms[0])
        m = int(hms[1])
        s = float(hms[2])
        return h * 3600 + m * 60 + s
    except Exception:
        return np.nan

# %% [markdown]
# 🟦 Cell 3 – Fungsi helper filter interval (MAD)

# %%
def _filter_intervals_mad(intervals,
                          min_step=0.25,
                          max_step=2.0,
                          k_mad=3.0):
    """
    Filter interval langkah dengan 2 tahap:
    1) Hard range [min_step, max_step]
    2) MAD (Median Absolute Deviation) di sekitar median interval
    """
    intervals = np.asarray(intervals, dtype=float)

    # Hard range
    base_mask = (intervals >= min_step) & (intervals <= max_step)
    if base_mask.sum() < 2:
        # terlalu sedikit, pakai hard range saja
        return base_mask

    valid_vals = intervals[base_mask]
    median = np.median(valid_vals)
    mad = np.median(np.abs(valid_vals - median))

    if mad == 0:
        return base_mask

    robust_z = np.abs(valid_vals - median) / (mad + 1e-8)
    keep_valid = robust_z <= k_mad

    final_mask = np.zeros_like(intervals, dtype=bool)
    final_mask[base_mask] = keep_valid

    return final_mask

# %% [markdown]
# 🟦 Cell 4 – Fungsi inti V2

# %%
def compute_final_gait_features_v2(df_gait):
    """
    V2: fitur gait dengan filtering interval + validasi trial.
    Menghasilkan:
    - step_count_raw
    - step_count_valid
    - duration_walk_sec
    - mean_step_time
    - step_time_std
    - cadence_spm
    - distance_2d_m
    - walking_speed_ms
    - step_length_m
    - is_valid_trial
    """

    df = df_gait.copy()

    # Pastikan timestamp_sec ada
    if "timestamp_sec" not in df.columns:
        if "timestamp" not in df.columns:
            raise ValueError("DataFrame tidak punya 'timestamp_sec' maupun 'timestamp'")
        df["timestamp_sec"] = df["timestamp"].apply(timestamp_to_seconds)

    REQUIRED_COLS = ["timestamp_sec", "step_event", "torso_x", "torso_y"]
    for c in REQUIRED_COLS:
        if c not in df.columns:
            raise ValueError(f"Kolom wajib '{c}' tidak ada di DataFrame: {c}")

    # Ambil step times
    step_mask = df["step_event"] == 1
    ts_steps = df.loc[step_mask, "timestamp_sec"].dropna().values
    idx_steps = df.index[step_mask].values

    step_count_raw = int(len(ts_steps))

    if step_count_raw < 2:
        return {
            "step_count_raw": step_count_raw,
            "step_count_valid": step_count_raw,
            "duration_walk_sec": np.nan,
            "mean_step_time": np.nan,
            "step_time_std": np.nan,
            "cadence_spm": np.nan,
            "distance_2d_m": np.nan,
            "walking_speed_ms": np.nan,
            "step_length_m": np.nan,
            "is_valid_trial": 0,
        }

    intervals = np.diff(ts_steps)

    mask_valid_int = _filter_intervals_mad(intervals,
                                           min_step=0.25,
                                           max_step=2.0,
                                           k_mad=3.0)

    if mask_valid_int.sum() == 0:
        return {
            "step_count_raw": step_count_raw,
            "step_count_valid": 0,
            "duration_walk_sec": np.nan,
            "mean_step_time": np.nan,
            "step_time_std": np.nan,
            "cadence_spm": np.nan,
            "distance_2d_m": np.nan,
            "walking_speed_ms": np.nan,
            "step_length_m": np.nan,
            "is_valid_trial": 0,
        }

    valid_idx_pairs = np.where(mask_valid_int)[0]
    first_valid_step_idx = valid_idx_pairs[0]
    last_valid_step_idx = valid_idx_pairs[-1] + 1

    ts_steps_valid = ts_steps[first_valid_step_idx:last_valid_step_idx+1]
    idx_steps_valid = idx_steps[first_valid_step_idx:last_valid_step_idx+1]

    step_count_valid = int(len(ts_steps_valid))

    if step_count_valid < 2:
        return {
            "step_count_raw": step_count_raw,
            "step_count_valid": step_count_valid,
            "duration_walk_sec": np.nan,
            "mean_step_time": np.nan,
            "step_time_std": np.nan,
            "cadence_spm": np.nan,
            "distance_2d_m": np.nan,
            "walking_speed_ms": np.nan,
            "step_length_m": np.nan,
            "is_valid_trial": 0,
        }

    intervals_valid = np.diff(ts_steps_valid)

    mean_step_time = float(np.mean(intervals_valid))
    step_time_std = float(np.std(intervals_valid, ddof=1)) if len(intervals_valid) > 1 else 0.0

    t_start = float(ts_steps_valid[0])
    t_end = float(ts_steps_valid[-1])
    duration_walk_sec = t_end - t_start if t_end > t_start else np.nan

    if duration_walk_sec is not None and duration_walk_sec > 0 and not np.isnan(duration_walk_sec):
        cadence_spm = step_count_valid * 60.0 / duration_walk_sec
    else:
        cadence_spm = np.nan

    x_steps_valid = df.loc[idx_steps_valid, "torso_x"].values
    y_steps_valid = df.loc[idx_steps_valid, "torso_y"].values

    if len(x_steps_valid) < 2 or len(y_steps_valid) < 2:
        distance_2d_m = np.nan
        walking_speed_ms = np.nan
        step_length_m = np.nan
    else:
        x_start, x_end = float(x_steps_valid[0]), float(x_steps_valid[-1])
        y_start, y_end = float(y_steps_valid[0]), float(y_steps_valid[-1])

        dx = x_end - x_start
        dy = y_end - y_start
        distance_2d_m = float(np.sqrt(dx**2 + dy**2))

        if duration_walk_sec is not None and duration_walk_sec > 0 and not np.isnan(duration_walk_sec):
            walking_speed_ms = distance_2d_m / duration_walk_sec
        else:
            walking_speed_ms = np.nan

        if step_count_valid > 1 and not np.isnan(distance_2d_m):
            step_length_m = distance_2d_m / (step_count_valid - 1)
        else:
            step_length_m = np.nan

    # Validasi trial
    is_valid = 1
    if step_count_valid < 4:
        is_valid = 0
    if (duration_walk_sec is np.nan) or (duration_walk_sec is None) or (duration_walk_sec < 1.5):
        is_valid = 0
    if (distance_2d_m is np.nan) or (distance_2d_m < 0.5):
        is_valid = 0
    if (mean_step_time < 0.25) or (mean_step_time > 1.8):
        is_valid = 0
    if not np.isnan(walking_speed_ms):
        if (walking_speed_ms < 0.2) or (walking_speed_ms > 3.0):
            is_valid = 0

    return {
        "step_count_raw": step_count_raw,
        "step_count_valid": step_count_valid,
        "duration_walk_sec": duration_walk_sec,
        "mean_step_time": mean_step_time,
        "step_time_std": step_time_std,
        "cadence_spm": cadence_spm,
        "distance_2d_m": distance_2d_m,
        "walking_speed_ms": walking_speed_ms,
        "step_length_m": step_length_m,
        "is_valid_trial": int(is_valid),
    }

# %% [markdown]
# 🟦 Cell 5 – Proses 1 file (V2)

# %%
def process_single_gaitfile_final_v2(file_path):
    """
    Membaca satu file *_gait_with_steps.csv dan menghitung
    fitur gait final V2 (dengan filtering interval + validasi).
    """

    base_name = os.path.basename(file_path)
    trial_name = base_name.replace("_gait_with_steps.csv", "")

    parts = trial_name.split("_")
    subject = parts[0] if len(parts) > 0 else "UNKNOWN"
    trial_id = "_".join(parts[1:]) if len(parts) > 1 else ""

    print(f"\n=== [V2] Proses trial: {trial_name} ===")
    print("File:", file_path)

    df = pd.read_csv(file_path)

    feats = compute_final_gait_features_v2(df)

    row = {
        "subject": subject,
        "trial": trial_name,
        "trial_id": trial_id,
    }
    row.update(feats)

    return row

# %% [markdown]
# 🟦 Cell 6 – Proses semua file + autosort + simpan

# %%
def process_all_final_gait_features_v2(
    folder_steps=FOLDER_GAITFRAME_STEPS,
    root_out=FOLDER_GAIT_FEATURES_FINAL_ROOT_V2
):
    rows = []
    files = sorted(os.listdir(folder_steps))

    for fname in files:
        if not fname.endswith("_gait_with_steps.csv"):
            continue

        fpath = os.path.join(folder_steps, fname)

        try:
            row = process_single_gaitfile_final_v2(fpath)
            rows.append(row)
        except Exception as e:
            print(f"ERROR pada file {fname}: {e}")

    if not rows:
        print("Tidak ada file *_gait_with_steps.csv yang berhasil diproses (V2).")
        return pd.DataFrame()

    df_all = pd.DataFrame(rows)

    df_all["trial_num"] = (
        df_all["trial_id"]
        .str.extract(r"(\d+)", expand=False)
        .astype(float)
    )

    df_all_sorted = (
        df_all
        .sort_values(["subject", "trial_num"], na_position="last")
        .reset_index(drop=True)
    )

    global_out_path = os.path.join(root_out, "gait_features_final_all_v2_filtered_sorted.csv")
    df_all_sorted.to_csv(global_out_path, index=False)
    print("\n=== [V2] Global summary (sorted) disimpan ===")
    print(global_out_path)

    subjects = df_all_sorted["subject"].unique()
    for subj in subjects:
        df_subj = df_all_sorted[df_all_sorted["subject"] == subj].copy()

        subj_folder = os.path.join(root_out, subj)
        os.makedirs(subj_folder, exist_ok=True)

        subj_out_path = os.path.join(subj_folder, f"{subj}_gait_features_5_v2_filtered_sorted.csv")
        df_subj.to_csv(subj_out_path, index=False)

        print(f"  -> [V2] Simpan fitur final untuk subject {subj}:")
        print(f"     {subj_out_path}")

    return df_all_sorted

# %% [markdown]
# 🟦 Cell 7 – Jalankan V2

# %%
df_final_v2 = process_all_final_gait_features_v2()
df_final_v2.head()
# Out:
# === [V2] Proses trial: Afi_Jalan10 ===
# File: E:\1.Clustering_TA\dataset\gaitframe_steps\Afi_Jalan10_gait_with_steps.csv
#
# === [V2] Proses trial: Afi_Jalan11 ===
# File: E:\1.Clustering_TA\dataset\gaitframe_steps\Afi_Jalan11_gait_with_steps.csv
#
# === [V2] Proses trial: Afi_Jalan12 ===
# File: E:\1.Clustering_TA\dataset\gaitframe_steps\Afi_Jalan12_gait_with_steps.csv
#
# === [V2] Proses trial: Afi_Jalan13 ===
# File: E:\1.Clustering_TA\dataset\gaitframe_steps\Afi_Jalan13_gait_with_steps.csv
#
# === [V2] Proses trial: Afi_Jalan14 ===
# File: E:\1.Clustering_TA\dataset\gaitframe_steps\Afi_Jalan14_gait_with_steps.csv
#
# === [V2] Proses trial: Afi_Jalan15 ===
# File: E:\1.Clustering_TA\dataset\gaitframe_steps\Afi_Jalan15_gait_with_steps.csv
#
# === [V2] Proses trial: Afi_Jalan16 ===
# File: E:\1.Clustering_TA\dataset\gaitframe_steps\Afi_Jalan16_gait_with_steps.csv
#
# === [V2] Proses trial: Afi_Jalan17 ===
# File: E:\1.Clustering_TA\dataset\gaitframe_steps\Afi_Jalan17_gait_with_steps.csv
#
# === [V2] Proses trial: Afi_Jalan18 ===
# File: E:\1.Clustering_TA\dataset\gaitframe_steps\Afi_Jalan18_gait_with_steps.csv
#
# === [V2] Proses trial: Afi_Jalan19 ===
# File: E:\1.Clustering_TA\dataset\gaitframe_steps\Afi_Jalan19_gait_with_steps.csv
#
# === [V2] Proses trial: Afi_Jalan1 ===
# File: E:\1.Clustering_TA\dataset\gaitframe_steps\Afi_Jalan1_gait_with_steps.csv
#
# === [V2] Proses trial: Afi_Jalan20 ===
# File: E:\1.Clustering_TA\dataset\gaitframe_steps\Afi_Jalan20_gait_with_steps.csv
#
# === [V2] Proses trial: Afi_Jalan21 ===
# File: E:\1.Clustering_TA\dataset\gaitframe_steps\Afi_Jalan21_gait_with_steps.csv
#
# === [V2] Proses trial: Afi_Jalan22 ===
# File: E:\1.Clustering_TA\dataset\gaitframe_steps\Afi_Jalan22_gait_with_steps.csv
#
# === [V2] Proses trial: Afi_Jalan23 ===
# File: E:\1.Clustering_TA\dataset\gaitframe_steps\Afi_Jalan23_gait_with_steps.csv
#
# === [V2] Proses trial: Afi_Jalan24 ===
# File: E:\1.Clustering_TA\dataset\gaitframe_steps\Afi_Jalan24_gait_with_steps.csv
#
# === [V2] Proses trial: Afi_Jalan25 ===
# File: E:\1.Clustering_TA\dataset\gaitframe_steps\Afi_Jalan25_gait_with_steps.csv
#
# === [V2] Proses trial: Afi_Jalan26 ===
# File: E:\1.Clustering_TA\dataset\gaitframe_steps\Afi_Jalan26_gait_with_steps.csv
#
# === [V2] Proses trial: Afi_Jalan27 ===
# File: E:\1.Clustering_TA\dataset\gaitframe_steps\Afi_Jalan27_gait_with_steps.csv
#
# === [V2] Proses trial: Afi_Jalan28 ===
# File: E:\1.Clustering_TA\dataset\gaitframe_steps\Afi_Jalan28_gait_with_steps.csv
#
# === [V2] Proses trial: Afi_Jalan29 ===
# File: E:\1.Clustering_TA\dataset\gaitframe_steps\Afi_Jalan29_gait_with_steps.csv
#
# === [V2] Proses trial: Afi_Jalan2 ===
# File: E:\1.Clustering_TA\dataset\gaitframe_steps\Afi_Jalan2_gait_with_steps.csv
#
# === [V2] Proses trial: Afi_Jalan30 ===
# File: E:\1.Clustering_TA\dataset\gaitframe_steps\Afi_Jalan30_gait_with_steps.csv
#
# === [V2] Proses trial: Afi_Jalan31 ===
# File: E:\1.Clustering_TA\dataset\gaitframe_steps\Afi_Jalan31_gait_with_steps.csv
#
# === [V2] Proses trial: Afi_Jalan32 ===
# File: E:\1.Clustering_TA\dataset\gaitframe_steps\Afi_Jalan32_gait_with_steps.csv
#
# === [V2] Proses trial: Afi_Jalan33 ===
# File: E:\1.Clustering_TA\dataset\gaitframe_steps\Afi_Jalan33_gait_with_steps.csv
#
# === [V2] Proses trial: Afi_Jalan34 ===
# File: E:\1.Clustering_TA\dataset\gaitframe_steps\Afi_Jalan34_gait_with_steps.csv
#
# === [V2] Proses trial: Afi_Jalan35 ===
# File: E:\1.Clustering_TA\dataset\gaitframe_steps\Afi_Jalan35_gait_with_steps.csv
#
# === [V2] Proses trial: Afi_Jalan36 ===
# File: E:\1.Clustering_TA\dataset\gaitframe_steps\Afi_Jalan36_gait_with_steps.csv
#
# === [V2] Proses trial: Afi_Jalan37 ===
# File: E:\1.Clustering_TA\dataset\gaitframe_steps\Afi_Jalan37_gait_with_steps.csv
#
# === [V2] Proses trial: Afi_Jalan38 ===
# File: E:\1.Clustering_TA\dataset\gaitframe_steps\Afi_Jalan38_gait_with_steps.csv
#
# === [V2] Proses trial: Afi_Jalan39 ===
# File: E:\1.Clustering_TA\dataset\gaitframe_steps\Afi_Jalan39_gait_with_steps.csv
#
# === [V2] Proses trial: Afi_Jalan3 ===
# File: E:\1.Clustering_TA\dataset\gaitframe_steps\Afi_Jalan3_gait_with_steps.csv
#
# === [V2] Proses trial: Afi_Jalan40 ===
# File: E:\1.Clustering_TA\dataset\gaitframe_steps\Afi_Jalan40_gait_with_steps.csv
#
# === [V2] Proses trial: Afi_Jalan41 ===
# File: E:\1.Clustering_TA\dataset\gaitframe_steps\Afi_Jalan41_gait_with_steps.csv
#
# === [V2] Proses trial: Afi_Jalan42 ===
# File: E:\1.Clustering_TA\dataset\gaitframe_steps\Afi_Jalan42_gait_with_steps.csv
#
# === [V2] Proses trial: Afi_Jalan43 ===
# File: E:\1.Clustering_TA\dataset\gaitframe_steps\Afi_Jalan43_gait_with_steps.csv
#
# === [V2] Proses trial: Afi_Jalan44 ===
# File: E:\1.Clustering_TA\dataset\gaitframe_steps\Afi_Jalan44_gait_with_steps.csv
#
# === [V2] Proses trial: Afi_Jalan45 ===
# File: E:\1.Clustering_TA\dataset\gaitframe_steps\Afi_Jalan45_gait_with_steps.csv
#
# === [V2] Proses trial: Afi_Jalan46 ===
# File: E:\1.Clustering_TA\dataset\gaitframe_steps\Afi_Jalan46_gait_with_steps.csv
#
# === [V2] Proses trial: Afi_Jalan47 ===
# File: E:\1.Clustering_TA\dataset\gaitframe_steps\Afi_Jalan47_gait_with_steps.csv
#
# === [V2] Proses trial: Afi_Jalan48 ===
# File: E:\1.Clustering_TA\dataset\gaitframe_steps\Afi_Jalan48_gait_with_steps.csv
#
# === [V2] Proses trial: Afi_Jalan49 ===
# File: E:\1.Clustering_TA\dataset\gaitframe_steps\Afi_Jalan49_gait_with_steps.csv
#
# === [V2] Proses trial: Afi_Jalan4 ===
# File: E:\1.Clustering_TA\dataset\gaitframe_steps\Afi_Jalan4_gait_with_steps.csv
#
# === [V2] Proses trial: Afi_Jalan50 ===
# File: E:\1.Clustering_TA\dataset\gaitframe_steps\Afi_Jalan50_gait_with_steps.csv
#
# === [V2] Proses trial: Afi_Jalan51 ===
# File: E:\1.Clustering_TA\dataset\gaitframe_steps\Afi_Jalan51_gait_with_steps.csv
#
# === [V2] Proses trial: Afi_Jalan52 ===
# File: E:\1.Clustering_TA\dataset\gaitframe_steps\Afi_Jalan52_gait_with_steps.csv
#
# === [V2] Proses trial: Afi_Jalan53 ===
# File: E:\1.Clustering_TA\dataset\gaitframe_steps\Afi_Jalan53_gait_with_steps.csv
#
# === [V2] Proses trial: Afi_Jalan54 ===
# File: E:\1.Clustering_TA\dataset\gaitframe_steps\Afi_Jalan54_gait_with_steps.csv
#
# === [V2] Proses trial: Afi_Jalan55 ===
# File: E:\1.Clustering_TA\dataset\gaitframe_steps\Afi_Jalan55_gait_with_steps.csv
#
# === [V2] Proses trial: Afi_Jalan56 ===
# File: E:\1.Clustering_TA\dataset\gaitframe_steps\Afi_Jalan56_gait_with_steps.csv
#
# === [V2] Proses trial: Afi_Jalan57 ===
# File: E:\1.Clustering_TA\dataset\gaitframe_steps\Afi_Jalan57_gait_with_steps.csv
#
# === [V2] Proses trial: Afi_Jalan58 ===
# File: E:\1.Clustering_TA\dataset\gaitframe_steps\Afi_Jalan58_gait_with_steps.csv
#
# === [V2] Proses trial: Afi_Jalan59 ===
# File: E:\1.Clustering_TA\dataset\gaitframe_steps\Afi_Jalan59_gait_with_steps.csv
#
# === [V2] Proses trial: Afi_Jalan5 ===
# File: E:\1.Clustering_TA\dataset\gaitframe_steps\Afi_Jalan5_gait_with_steps.csv
#
# === [V2] Proses trial: Afi_Jalan60 ===
# File: E:\1.Clustering_TA\dataset\gaitframe_steps\Afi_Jalan60_gait_with_steps.csv
#
# === [V2] Proses trial: Afi_Jalan61 ===
# File: E:\1.Clustering_TA\dataset\gaitframe_steps\Afi_Jalan61_gait_with_steps.csv
#
# === [V2] Proses trial: Afi_Jalan62 ===
# File: E:\1.Clustering_TA\dataset\gaitframe_steps\Afi_Jalan62_gait_with_steps.csv
#
# === [V2] Proses trial: Afi_Jalan63 ===
# File: E:\1.Clustering_TA\dataset\gaitframe_steps\Afi_Jalan63_gait_with_steps.csv
#
# === [V2] Proses trial: Afi_Jalan64 ===
# File: E:\1.Clustering_TA\dataset\gaitframe_steps\Afi_Jalan64_gait_with_steps.csv
#
# === [V2] Proses trial: Afi_Jalan65 ===
# File: E:\1.Clustering_TA\dataset\gaitframe_steps\Afi_Jalan65_gait_with_steps.csv
#
# === [V2] Proses trial: Afi_Jalan66 ===
# File: E:\1.Clustering_TA\dataset\gaitframe_steps\Afi_Jalan66_gait_with_steps.csv
#
# === [V2] Proses trial: Afi_Jalan67 ===
# File: E:\1.Clustering_TA\dataset\gaitframe_steps\Afi_Jalan67_gait_with_steps.csv
#
# === [V2] Proses trial: Afi_Jalan68 ===
# File: E:\1.Clustering_TA\dataset\gaitframe_steps\Afi_Jalan68_gait_with_steps.csv
#
# === [V2] Proses trial: Afi_Jalan69 ===
# File: E:\1.Clustering_TA\dataset\gaitframe_steps\Afi_Jalan69_gait_with_steps.csv
#
# === [V2] Proses trial: Afi_Jalan6 ===
# File: E:\1.Clustering_TA\dataset\gaitframe_steps\Afi_Jalan6_gait_with_steps.csv
#
# === [V2] Proses trial: Afi_Jalan70 ===
# File: E:\1.Clustering_TA\dataset\gaitframe_steps\Afi_Jalan70_gait_with_steps.csv
#
# === [V2] Proses trial: Afi_Jalan71 ===
# File: E:\1.Clustering_TA\dataset\gaitframe_steps\Afi_Jalan71_gait_with_steps.csv
#
# === [V2] Proses trial: Afi_Jalan72 ===
# File: E:\1.Clustering_TA\dataset\gaitframe_steps\Afi_Jalan72_gait_with_steps.csv
#
# === [V2] Proses trial: Afi_Jalan7 ===
# File: E:\1.Clustering_TA\dataset\gaitframe_steps\Afi_Jalan7_gait_with_steps.csv
#
# === [V2] Proses trial: Afi_Jalan8 ===
# File: E:\1.Clustering_TA\dataset\gaitframe_steps\Afi_Jalan8_gait_with_steps.csv
#
# === [V2] Proses trial: Afi_Jalan9 ===
# File: E:\1.Clustering_TA\dataset\gaitframe_steps\Afi_Jalan9_gait_with_steps.csv
#
# === [V2] Proses trial: Kinan_Jalan10 ===
# File: E:\1.Clustering_TA\dataset\gaitframe_steps\Kinan_Jalan10_gait_with_steps.csv
#
# === [V2] Proses trial: Kinan_Jalan11 ===
# File: E:\1.Clustering_TA\dataset\gaitframe_steps\Kinan_Jalan11_gait_with_steps.csv
#
# === [V2] Proses trial: Kinan_Jalan12 ===
# File: E:\1.Clustering_TA\dataset\gaitframe_steps\Kinan_Jalan12_gait_with_steps.csv
#
# === [V2] Proses trial: Kinan_Jalan13 ===
# File: E:\1.Clustering_TA\dataset\gaitframe_steps\Kinan_Jalan13_gait_with_steps.csv
#
# === [V2] Proses trial: Kinan_Jalan14 ===
# File: E:\1.Clustering_TA\dataset\gaitframe_steps\Kinan_Jalan14_gait_with_steps.csv
#
# === [V2] Proses trial: Kinan_Jalan15 ===
# File: E:\1.Clustering_TA\dataset\gaitframe_steps\Kinan_Jalan15_gait_with_steps.csv
#
# === [V2] Proses trial: Kinan_Jalan16 ===
# File: E:\1.Clustering_TA\dataset\gaitframe_steps\Kinan_Jalan16_gait_with_steps.csv
#
# === [V2] Proses trial: Kinan_Jalan17 ===
# File: E:\1.Clustering_TA\dataset\gaitframe_steps\Kinan_Jalan17_gait_with_steps.csv
#
# === [V2] Proses trial: Kinan_Jalan18 ===
# File: E:\1.Clustering_TA\dataset\gaitframe_steps\Kinan_Jalan18_gait_with_steps.csv
#
# === [V2] Proses trial: Kinan_Jalan19 ===
# File: E:\1.Clustering_TA\dataset\gaitframe_steps\Kinan_Jalan19_gait_with_steps.csv
#
# === [V2] Proses trial: Kinan_Jalan1 ===
# File: E:\1.Clustering_TA\dataset\gaitframe_steps\Kinan_Jalan1_gait_with_steps.csv
#
# === [V2] Proses trial: Kinan_Jalan20 ===
# File: E:\1.Clustering_TA\dataset\gaitframe_steps\Kinan_Jalan20_gait_with_steps.csv
#
# === [V2] Proses trial: Kinan_Jalan21 ===
# File: E:\1.Clustering_TA\dataset\gaitframe_steps\Kinan_Jalan21_gait_with_steps.csv
#
# === [V2] Proses trial: Kinan_Jalan22 ===
# File: E:\1.Clustering_TA\dataset\gaitframe_steps\Kinan_Jalan22_gait_with_steps.csv
#
# === [V2] Proses trial: Kinan_Jalan23 ===
# File: E:\1.Clustering_TA\dataset\gaitframe_steps\Kinan_Jalan23_gait_with_steps.csv
#
# === [V2] Proses trial: Kinan_Jalan24 ===
# File: E:\1.Clustering_TA\dataset\gaitframe_steps\Kinan_Jalan24_gait_with_steps.csv
#
# === [V2] Proses trial: Kinan_Jalan25 ===
# File: E:\1.Clustering_TA\dataset\gaitframe_steps\Kinan_Jalan25_gait_with_steps.csv
#
# === [V2] Proses trial: Kinan_Jalan26 ===
# File: E:\1.Clustering_TA\dataset\gaitframe_steps\Kinan_Jalan26_gait_with_steps.csv
#
# === [V2] Proses trial: Kinan_Jalan27 ===
# File: E:\1.Clustering_TA\dataset\gaitframe_steps\Kinan_Jalan27_gait_with_steps.csv
#
# === [V2] Proses trial: Kinan_Jalan28 ===
# File: E:\1.Clustering_TA\dataset\gaitframe_steps\Kinan_Jalan28_gait_with_steps.csv
#
# === [V2] Proses trial: Kinan_Jalan29 ===
# File: E:\1.Clustering_TA\dataset\gaitframe_steps\Kinan_Jalan29_gait_with_steps.csv
#
# === [V2] Proses trial: Kinan_Jalan2 ===
# File: E:\1.Clustering_TA\dataset\gaitframe_steps\Kinan_Jalan2_gait_with_steps.csv
#
# === [V2] Proses trial: Kinan_Jalan30 ===
# File: E:\1.Clustering_TA\dataset\gaitframe_steps\Kinan_Jalan30_gait_with_steps.csv
#
# === [V2] Proses trial: Kinan_Jalan31 ===
# File: E:\1.Clustering_TA\dataset\gaitframe_steps\Kinan_Jalan31_gait_with_steps.csv
#
# === [V2] Proses trial: Kinan_Jalan32 ===
# File: E:\1.Clustering_TA\dataset\gaitframe_steps\Kinan_Jalan32_gait_with_steps.csv
#
# === [V2] Proses trial: Kinan_Jalan33 ===
# File: E:\1.Clustering_TA\dataset\gaitframe_steps\Kinan_Jalan33_gait_with_steps.csv
#
# === [V2] Proses trial: Kinan_Jalan34 ===
# File: E:\1.Clustering_TA\dataset\gaitframe_steps\Kinan_Jalan34_gait_with_steps.csv
#
# === [V2] Proses trial: Kinan_Jalan35 ===
# File: E:\1.Clustering_TA\dataset\gaitframe_steps\Kinan_Jalan35_gait_with_steps.csv
#
# === [V2] Proses trial: Kinan_Jalan36 ===
# File: E:\1.Clustering_TA\dataset\gaitframe_steps\Kinan_Jalan36_gait_with_steps.csv
#
# === [V2] Proses trial: Kinan_Jalan37 ===
# File: E:\1.Clustering_TA\dataset\gaitframe_steps\Kinan_Jalan37_gait_with_steps.csv
#
# === [V2] Proses trial: Kinan_Jalan38 ===
# File: E:\1.Clustering_TA\dataset\gaitframe_steps\Kinan_Jalan38_gait_with_steps.csv
#
# === [V2] Proses trial: Kinan_Jalan39 ===
# File: E:\1.Clustering_TA\dataset\gaitframe_steps\Kinan_Jalan39_gait_with_steps.csv
#
# === [V2] Proses trial: Kinan_Jalan3 ===
# File: E:\1.Clustering_TA\dataset\gaitframe_steps\Kinan_Jalan3_gait_with_steps.csv
#
# === [V2] Proses trial: Kinan_Jalan40 ===
# File: E:\1.Clustering_TA\dataset\gaitframe_steps\Kinan_Jalan40_gait_with_steps.csv
#
# === [V2] Proses trial: Kinan_Jalan41 ===
# File: E:\1.Clustering_TA\dataset\gaitframe_steps\Kinan_Jalan41_gait_with_steps.csv
#
# === [V2] Proses trial: Kinan_Jalan42 ===
# File: E:\1.Clustering_TA\dataset\gaitframe_steps\Kinan_Jalan42_gait_with_steps.csv
#
# === [V2] Proses trial: Kinan_Jalan43 ===
# File: E:\1.Clustering_TA\dataset\gaitframe_steps\Kinan_Jalan43_gait_with_steps.csv
#
# === [V2] Proses trial: Kinan_Jalan44 ===
# File: E:\1.Clustering_TA\dataset\gaitframe_steps\Kinan_Jalan44_gait_with_steps.csv
#
# === [V2] Proses trial: Kinan_Jalan45 ===
# File: E:\1.Clustering_TA\dataset\gaitframe_steps\Kinan_Jalan45_gait_with_steps.csv
#
# === [V2] Proses trial: Kinan_Jalan46 ===
# File: E:\1.Clustering_TA\dataset\gaitframe_steps\Kinan_Jalan46_gait_with_steps.csv
#
# === [V2] Proses trial: Kinan_Jalan47 ===
# File: E:\1.Clustering_TA\dataset\gaitframe_steps\Kinan_Jalan47_gait_with_steps.csv
#
# === [V2] Proses trial: Kinan_Jalan48 ===
# File: E:\1.Clustering_TA\dataset\gaitframe_steps\Kinan_Jalan48_gait_with_steps.csv
#
# === [V2] Proses trial: Kinan_Jalan49 ===
# File: E:\1.Clustering_TA\dataset\gaitframe_steps\Kinan_Jalan49_gait_with_steps.csv
#
# === [V2] Proses trial: Kinan_Jalan4 ===
# File: E:\1.Clustering_TA\dataset\gaitframe_steps\Kinan_Jalan4_gait_with_steps.csv
#
# === [V2] Proses trial: Kinan_Jalan50 ===
# File: E:\1.Clustering_TA\dataset\gaitframe_steps\Kinan_Jalan50_gait_with_steps.csv
#
# === [V2] Proses trial: Kinan_Jalan51 ===
# File: E:\1.Clustering_TA\dataset\gaitframe_steps\Kinan_Jalan51_gait_with_steps.csv
#
# === [V2] Proses trial: Kinan_Jalan52 ===
# File: E:\1.Clustering_TA\dataset\gaitframe_steps\Kinan_Jalan52_gait_with_steps.csv
#
# === [V2] Proses trial: Kinan_Jalan53 ===
# File: E:\1.Clustering_TA\dataset\gaitframe_steps\Kinan_Jalan53_gait_with_steps.csv
#
# === [V2] Proses trial: Kinan_Jalan54 ===
# File: E:\1.Clustering_TA\dataset\gaitframe_steps\Kinan_Jalan54_gait_with_steps.csv
#
# === [V2] Proses trial: Kinan_Jalan55 ===
# File: E:\1.Clustering_TA\dataset\gaitframe_steps\Kinan_Jalan55_gait_with_steps.csv
#
# === [V2] Proses trial: Kinan_Jalan56 ===
# File: E:\1.Clustering_TA\dataset\gaitframe_steps\Kinan_Jalan56_gait_with_steps.csv
#
# === [V2] Proses trial: Kinan_Jalan57 ===
# File: E:\1.Clustering_TA\dataset\gaitframe_steps\Kinan_Jalan57_gait_with_steps.csv
#
# === [V2] Proses trial: Kinan_Jalan58 ===
# File: E:\1.Clustering_TA\dataset\gaitframe_steps\Kinan_Jalan58_gait_with_steps.csv
#
# === [V2] Proses trial: Kinan_Jalan59 ===
# File: E:\1.Clustering_TA\dataset\gaitframe_steps\Kinan_Jalan59_gait_with_steps.csv
#
# === [V2] Proses trial: Kinan_Jalan5 ===
# File: E:\1.Clustering_TA\dataset\gaitframe_steps\Kinan_Jalan5_gait_with_steps.csv
#
# === [V2] Proses trial: Kinan_Jalan60 ===
# File: E:\1.Clustering_TA\dataset\gaitframe_steps\Kinan_Jalan60_gait_with_steps.csv
#
# === [V2] Proses trial: Kinan_Jalan61 ===
# File: E:\1.Clustering_TA\dataset\gaitframe_steps\Kinan_Jalan61_gait_with_steps.csv
#
# === [V2] Proses trial: Kinan_Jalan62 ===
# File: E:\1.Clustering_TA\dataset\gaitframe_steps\Kinan_Jalan62_gait_with_steps.csv
#
# === [V2] Proses trial: Kinan_Jalan63 ===
# File: E:\1.Clustering_TA\dataset\gaitframe_steps\Kinan_Jalan63_gait_with_steps.csv
#
# === [V2] Proses trial: Kinan_Jalan64 ===
# File: E:\1.Clustering_TA\dataset\gaitframe_steps\Kinan_Jalan64_gait_with_steps.csv
#
# === [V2] Proses trial: Kinan_Jalan65 ===
# File: E:\1.Clustering_TA\dataset\gaitframe_steps\Kinan_Jalan65_gait_with_steps.csv
#
# === [V2] Proses trial: Kinan_Jalan66 ===
# File: E:\1.Clustering_TA\dataset\gaitframe_steps\Kinan_Jalan66_gait_with_steps.csv
#
# === [V2] Proses trial: Kinan_Jalan67 ===
# File: E:\1.Clustering_TA\dataset\gaitframe_steps\Kinan_Jalan67_gait_with_steps.csv
#
# === [V2] Proses trial: Kinan_Jalan68 ===
# File: E:\1.Clustering_TA\dataset\gaitframe_steps\Kinan_Jalan68_gait_with_steps.csv
#
# === [V2] Proses trial: Kinan_Jalan69 ===
# File: E:\1.Clustering_TA\dataset\gaitframe_steps\Kinan_Jalan69_gait_with_steps.csv
#
# === [V2] Proses trial: Kinan_Jalan6 ===
# File: E:\1.Clustering_TA\dataset\gaitframe_steps\Kinan_Jalan6_gait_with_steps.csv
#
# === [V2] Proses trial: Kinan_Jalan70 ===
# File: E:\1.Clustering_TA\dataset\gaitframe_steps\Kinan_Jalan70_gait_with_steps.csv
#
# === [V2] Proses trial: Kinan_Jalan71 ===
# File: E:\1.Clustering_TA\dataset\gaitframe_steps\Kinan_Jalan71_gait_with_steps.csv
#
# === [V2] Proses trial: Kinan_Jalan72 ===
# File: E:\1.Clustering_TA\dataset\gaitframe_steps\Kinan_Jalan72_gait_with_steps.csv
#
# === [V2] Proses trial: Kinan_Jalan7 ===
# File: E:\1.Clustering_TA\dataset\gaitframe_steps\Kinan_Jalan7_gait_with_steps.csv
#
# === [V2] Proses trial: Kinan_Jalan8 ===
# File: E:\1.Clustering_TA\dataset\gaitframe_steps\Kinan_Jalan8_gait_with_steps.csv
#
# === [V2] Proses trial: Kinan_Jalan9 ===
# File: E:\1.Clustering_TA\dataset\gaitframe_steps\Kinan_Jalan9_gait_with_steps.csv
#
# === [V2] Proses trial: Miftah_Jalan10 ===
# File: E:\1.Clustering_TA\dataset\gaitframe_steps\Miftah_Jalan10_gait_with_steps.csv
#
# === [V2] Proses trial: Miftah_Jalan11 ===
# File: E:\1.Clustering_TA\dataset\gaitframe_steps\Miftah_Jalan11_gait_with_steps.csv
#
# === [V2] Proses trial: Miftah_Jalan12 ===
# File: E:\1.Clustering_TA\dataset\gaitframe_steps\Miftah_Jalan12_gait_with_steps.csv
#
# === [V2] Proses trial: Miftah_Jalan13 ===
# File: E:\1.Clustering_TA\dataset\gaitframe_steps\Miftah_Jalan13_gait_with_steps.csv
#
# === [V2] Proses trial: Miftah_Jalan14 ===
# File: E:\1.Clustering_TA\dataset\gaitframe_steps\Miftah_Jalan14_gait_with_steps.csv
#
# === [V2] Proses trial: Miftah_Jalan15 ===
# File: E:\1.Clustering_TA\dataset\gaitframe_steps\Miftah_Jalan15_gait_with_steps.csv
#
# === [V2] Proses trial: Miftah_Jalan16 ===
# File: E:\1.Clustering_TA\dataset\gaitframe_steps\Miftah_Jalan16_gait_with_steps.csv
#
# === [V2] Proses trial: Miftah_Jalan17 ===
# File: E:\1.Clustering_TA\dataset\gaitframe_steps\Miftah_Jalan17_gait_with_steps.csv
#
# === [V2] Proses trial: Miftah_Jalan18 ===
# File: E:\1.Clustering_TA\dataset\gaitframe_steps\Miftah_Jalan18_gait_with_steps.csv
#
# === [V2] Proses trial: Miftah_Jalan19 ===
# File: E:\1.Clustering_TA\dataset\gaitframe_steps\Miftah_Jalan19_gait_with_steps.csv
#
# === [V2] Proses trial: Miftah_Jalan1 ===
# File: E:\1.Clustering_TA\dataset\gaitframe_steps\Miftah_Jalan1_gait_with_steps.csv
#
# === [V2] Proses trial: Miftah_Jalan20 ===
# File: E:\1.Clustering_TA\dataset\gaitframe_steps\Miftah_Jalan20_gait_with_steps.csv
#
# === [V2] Proses trial: Miftah_Jalan21 ===
# File: E:\1.Clustering_TA\dataset\gaitframe_steps\Miftah_Jalan21_gait_with_steps.csv
#
# === [V2] Proses trial: Miftah_Jalan22 ===
# File: E:\1.Clustering_TA\dataset\gaitframe_steps\Miftah_Jalan22_gait_with_steps.csv
#
# === [V2] Proses trial: Miftah_Jalan23 ===
# File: E:\1.Clustering_TA\dataset\gaitframe_steps\Miftah_Jalan23_gait_with_steps.csv
#
# === [V2] Proses trial: Miftah_Jalan24 ===
# File: E:\1.Clustering_TA\dataset\gaitframe_steps\Miftah_Jalan24_gait_with_steps.csv
#
# === [V2] Proses trial: Miftah_Jalan25 ===
# File: E:\1.Clustering_TA\dataset\gaitframe_steps\Miftah_Jalan25_gait_with_steps.csv
#
# === [V2] Proses trial: Miftah_Jalan26 ===
# File: E:\1.Clustering_TA\dataset\gaitframe_steps\Miftah_Jalan26_gait_with_steps.csv
#
# === [V2] Proses trial: Miftah_Jalan27 ===
# File: E:\1.Clustering_TA\dataset\gaitframe_steps\Miftah_Jalan27_gait_with_steps.csv
#
# === [V2] Proses trial: Miftah_Jalan28 ===
# File: E:\1.Clustering_TA\dataset\gaitframe_steps\Miftah_Jalan28_gait_with_steps.csv
#
# === [V2] Proses trial: Miftah_Jalan29 ===
# File: E:\1.Clustering_TA\dataset\gaitframe_steps\Miftah_Jalan29_gait_with_steps.csv
#
# === [V2] Proses trial: Miftah_Jalan2 ===
# File: E:\1.Clustering_TA\dataset\gaitframe_steps\Miftah_Jalan2_gait_with_steps.csv
#
# === [V2] Proses trial: Miftah_Jalan30 ===
# File: E:\1.Clustering_TA\dataset\gaitframe_steps\Miftah_Jalan30_gait_with_steps.csv
#
# === [V2] Proses trial: Miftah_Jalan31 ===
# File: E:\1.Clustering_TA\dataset\gaitframe_steps\Miftah_Jalan31_gait_with_steps.csv
#
# === [V2] Proses trial: Miftah_Jalan32 ===
# File: E:\1.Clustering_TA\dataset\gaitframe_steps\Miftah_Jalan32_gait_with_steps.csv
#
# === [V2] Proses trial: Miftah_Jalan33 ===
# File: E:\1.Clustering_TA\dataset\gaitframe_steps\Miftah_Jalan33_gait_with_steps.csv
#
# === [V2] Proses trial: Miftah_Jalan34 ===
# File: E:\1.Clustering_TA\dataset\gaitframe_steps\Miftah_Jalan34_gait_with_steps.csv
#
# === [V2] Proses trial: Miftah_Jalan35 ===
# File: E:\1.Clustering_TA\dataset\gaitframe_steps\Miftah_Jalan35_gait_with_steps.csv
#
# === [V2] Proses trial: Miftah_Jalan36 ===
# File: E:\1.Clustering_TA\dataset\gaitframe_steps\Miftah_Jalan36_gait_with_steps.csv
#
# === [V2] Proses trial: Miftah_Jalan37 ===
# File: E:\1.Clustering_TA\dataset\gaitframe_steps\Miftah_Jalan37_gait_with_steps.csv
#
# === [V2] Proses trial: Miftah_Jalan38 ===
# File: E:\1.Clustering_TA\dataset\gaitframe_steps\Miftah_Jalan38_gait_with_steps.csv
#
# === [V2] Proses trial: Miftah_Jalan39 ===
# File: E:\1.Clustering_TA\dataset\gaitframe_steps\Miftah_Jalan39_gait_with_steps.csv
#
# === [V2] Proses trial: Miftah_Jalan3 ===
# File: E:\1.Clustering_TA\dataset\gaitframe_steps\Miftah_Jalan3_gait_with_steps.csv
#
# === [V2] Proses trial: Miftah_Jalan40 ===
# File: E:\1.Clustering_TA\dataset\gaitframe_steps\Miftah_Jalan40_gait_with_steps.csv
#
# === [V2] Proses trial: Miftah_Jalan41 ===
# File: E:\1.Clustering_TA\dataset\gaitframe_steps\Miftah_Jalan41_gait_with_steps.csv
#
# === [V2] Proses trial: Miftah_Jalan42 ===
# File: E:\1.Clustering_TA\dataset\gaitframe_steps\Miftah_Jalan42_gait_with_steps.csv
#
# === [V2] Proses trial: Miftah_Jalan43 ===
# File: E:\1.Clustering_TA\dataset\gaitframe_steps\Miftah_Jalan43_gait_with_steps.csv
#
# === [V2] Proses trial: Miftah_Jalan44 ===
# File: E:\1.Clustering_TA\dataset\gaitframe_steps\Miftah_Jalan44_gait_with_steps.csv
#
# === [V2] Proses trial: Miftah_Jalan45 ===
# File: E:\1.Clustering_TA\dataset\gaitframe_steps\Miftah_Jalan45_gait_with_steps.csv
#
# === [V2] Proses trial: Miftah_Jalan46 ===
# File: E:\1.Clustering_TA\dataset\gaitframe_steps\Miftah_Jalan46_gait_with_steps.csv
#
# === [V2] Proses trial: Miftah_Jalan47 ===
# File: E:\1.Clustering_TA\dataset\gaitframe_steps\Miftah_Jalan47_gait_with_steps.csv
#
# === [V2] Proses trial: Miftah_Jalan48 ===
# File: E:\1.Clustering_TA\dataset\gaitframe_steps\Miftah_Jalan48_gait_with_steps.csv
#
# === [V2] Proses trial: Miftah_Jalan49 ===
# File: E:\1.Clustering_TA\dataset\gaitframe_steps\Miftah_Jalan49_gait_with_steps.csv
#
# === [V2] Proses trial: Miftah_Jalan4 ===
# File: E:\1.Clustering_TA\dataset\gaitframe_steps\Miftah_Jalan4_gait_with_steps.csv
#
# === [V2] Proses trial: Miftah_Jalan50 ===
# File: E:\1.Clustering_TA\dataset\gaitframe_steps\Miftah_Jalan50_gait_with_steps.csv
#
# === [V2] Proses trial: Miftah_Jalan51 ===
# File: E:\1.Clustering_TA\dataset\gaitframe_steps\Miftah_Jalan51_gait_with_steps.csv
#
# === [V2] Proses trial: Miftah_Jalan52 ===
# File: E:\1.Clustering_TA\dataset\gaitframe_steps\Miftah_Jalan52_gait_with_steps.csv
#
# === [V2] Proses trial: Miftah_Jalan53 ===
# File: E:\1.Clustering_TA\dataset\gaitframe_steps\Miftah_Jalan53_gait_with_steps.csv
#
# === [V2] Proses trial: Miftah_Jalan54 ===
# File: E:\1.Clustering_TA\dataset\gaitframe_steps\Miftah_Jalan54_gait_with_steps.csv
#
# === [V2] Proses trial: Miftah_Jalan55 ===
# File: E:\1.Clustering_TA\dataset\gaitframe_steps\Miftah_Jalan55_gait_with_steps.csv
#
# === [V2] Proses trial: Miftah_Jalan56 ===
# File: E:\1.Clustering_TA\dataset\gaitframe_steps\Miftah_Jalan56_gait_with_steps.csv
#
# === [V2] Proses trial: Miftah_Jalan57 ===
# File: E:\1.Clustering_TA\dataset\gaitframe_steps\Miftah_Jalan57_gait_with_steps.csv
#
# === [V2] Proses trial: Miftah_Jalan58 ===
# File: E:\1.Clustering_TA\dataset\gaitframe_steps\Miftah_Jalan58_gait_with_steps.csv
#
# === [V2] Proses trial: Miftah_Jalan59 ===
# File: E:\1.Clustering_TA\dataset\gaitframe_steps\Miftah_Jalan59_gait_with_steps.csv
#
# === [V2] Proses trial: Miftah_Jalan5 ===
# File: E:\1.Clustering_TA\dataset\gaitframe_steps\Miftah_Jalan5_gait_with_steps.csv
#
# === [V2] Proses trial: Miftah_Jalan60 ===
# File: E:\1.Clustering_TA\dataset\gaitframe_steps\Miftah_Jalan60_gait_with_steps.csv
#
# === [V2] Proses trial: Miftah_Jalan61 ===
# File: E:\1.Clustering_TA\dataset\gaitframe_steps\Miftah_Jalan61_gait_with_steps.csv
#
# === [V2] Proses trial: Miftah_Jalan62 ===
# File: E:\1.Clustering_TA\dataset\gaitframe_steps\Miftah_Jalan62_gait_with_steps.csv
#
# === [V2] Proses trial: Miftah_Jalan63 ===
# File: E:\1.Clustering_TA\dataset\gaitframe_steps\Miftah_Jalan63_gait_with_steps.csv
#
# === [V2] Proses trial: Miftah_Jalan64 ===
# File: E:\1.Clustering_TA\dataset\gaitframe_steps\Miftah_Jalan64_gait_with_steps.csv
#
# === [V2] Proses trial: Miftah_Jalan65 ===
# File: E:\1.Clustering_TA\dataset\gaitframe_steps\Miftah_Jalan65_gait_with_steps.csv
#
# === [V2] Proses trial: Miftah_Jalan66 ===
# File: E:\1.Clustering_TA\dataset\gaitframe_steps\Miftah_Jalan66_gait_with_steps.csv
#
# === [V2] Proses trial: Miftah_Jalan67 ===
# File: E:\1.Clustering_TA\dataset\gaitframe_steps\Miftah_Jalan67_gait_with_steps.csv
#
# === [V2] Proses trial: Miftah_Jalan68 ===
# File: E:\1.Clustering_TA\dataset\gaitframe_steps\Miftah_Jalan68_gait_with_steps.csv
#
# === [V2] Proses trial: Miftah_Jalan69 ===
# File: E:\1.Clustering_TA\dataset\gaitframe_steps\Miftah_Jalan69_gait_with_steps.csv
#
# === [V2] Proses trial: Miftah_Jalan6 ===
# File: E:\1.Clustering_TA\dataset\gaitframe_steps\Miftah_Jalan6_gait_with_steps.csv
#
# === [V2] Proses trial: Miftah_Jalan70 ===
# File: E:\1.Clustering_TA\dataset\gaitframe_steps\Miftah_Jalan70_gait_with_steps.csv
#
# === [V2] Proses trial: Miftah_Jalan71 ===
# File: E:\1.Clustering_TA\dataset\gaitframe_steps\Miftah_Jalan71_gait_with_steps.csv
#
# === [V2] Proses trial: Miftah_Jalan72 ===
# File: E:\1.Clustering_TA\dataset\gaitframe_steps\Miftah_Jalan72_gait_with_steps.csv
#
# === [V2] Proses trial: Miftah_Jalan7 ===
# File: E:\1.Clustering_TA\dataset\gaitframe_steps\Miftah_Jalan7_gait_with_steps.csv
#
# === [V2] Proses trial: Miftah_Jalan8 ===
# File: E:\1.Clustering_TA\dataset\gaitframe_steps\Miftah_Jalan8_gait_with_steps.csv
#
# === [V2] Proses trial: Miftah_Jalan9 ===
# File: E:\1.Clustering_TA\dataset\gaitframe_steps\Miftah_Jalan9_gait_with_steps.csv
#
# === [V2] Global summary (sorted) disimpan ===
# E:\1.Clustering_TA\dataset\gait_features_final_v2_filtered\gait_features_final_all_v2_filtered_sorted.csv
#   -> [V2] Simpan fitur final untuk subject Afi:
#      E:\1.Clustering_TA\dataset\gait_features_final_v2_filtered\Afi\Afi_gait_features_5_v2_filtered_sorted.csv
#   -> [V2] Simpan fitur final untuk subject Kinan:
#      E:\1.Clustering_TA\dataset\gait_features_final_v2_filtered\Kinan\Kinan_gait_features_5_v2_filtered_sorted.csv
#   -> [V2] Simpan fitur final untuk subject Miftah:
#      E:\1.Clustering_TA\dataset\gait_features_final_v2_filtered\Miftah\Miftah_gait_features_5_v2_filtered_sorted.csv
#   subject       trial trial_id  step_count_raw  step_count_valid  \
# 0     Afi  Afi_Jalan1   Jalan1               3                 3
# 1     Afi  Afi_Jalan2   Jalan2               6                 6
# 2     Afi  Afi_Jalan3   Jalan3               5                 5
# 3     Afi  Afi_Jalan4   Jalan4               2                 2
# 4     Afi  Afi_Jalan5   Jalan5               5                 4
#
#    duration_walk_sec  mean_step_time  step_time_std  cadence_spm  \
# 0           0.714816        0.357408       0.040571   251.813054
# 1           2.083814        0.416763       0.253368   172.760141
# 2           1.597363        0.399341       0.052022   187.809534
# 3           0.391930        0.391930       0.000000   306.177123
# 4           1.049145        0.349715       0.081992   228.757703
#
#    distance_2d_m  walking_speed_ms  step_length_m  is_valid_trial  trial_num
# 0       1.180483          1.651451       0.590242               0        1.0
# 1       0.732601          0.351567       0.146520               1        2.0
# 2       3.081816          1.929315       0.770454               1        3.0
# 3       4.584173         11.696408       4.584173               0        4.0
# 4       1.700045          1.620410       0.566682               0        5.0

# %%
from pathlib import Path

global_sorted_path = Path(FOLDER_GAIT_FEATURES_FINAL_ROOT_V2) / "gait_features_final_v2_filtered.csv"
df_final_v2.to_csv(global_sorted_path, index=False)
print("Global sorted disimpan di:", global_sorted_path)
# Out:
# Global sorted disimpan di: E:\1.Clustering_TA\dataset\gait_features_final_v2_filtered\gait_features_final_v2_filtered.csv

# %%
# Cell 8: Sanity check fitur utama (V2)

df = df_final_v2.copy()

def count_true(series):
    # otomatis mengabaikan NaN
    return int(series.fillna(False).sum())

print("=== SANITY CHECK GLOBAL (V2) ===")
print("Total trial                    :", len(df))

# Perhatikan: pakai step_count_valid, bukan step_count
print("Step_count_raw  < 2            :", count_true(df["step_count_raw"] < 2))
print("Step_count_valid < 4           :", count_true(df["step_count_valid"] < 4))

print("Durasi_walk <= 0 (detik)       :", count_true(df["duration_walk_sec"] <= 0))
print("Distance_2d < 0.2 m            :", count_true(df["distance_2d_m"] < 0.2))
print("Speed > 3.0 m/s                :", count_true(df["walking_speed_ms"] > 3.0))
print("Speed 0-0.1 m/s (hampir diam)  :", count_true((df["walking_speed_ms"] > 0) & (df["walking_speed_ms"] < 0.1)))

# Tambahan penting: cek valid vs invalid trial
print("Trial dengan is_valid_trial = 0:", count_true(df["is_valid_trial"] == 0))

print("\n=== SANITY CHECK PER SUBJECT (V2) ===")
subjects = df["subject"].unique()
for subj in subjects:
    dsub = df[df["subject"] == subj]
    print(f"\n-- {subj} --")
    print("  Total trial                 :", len(dsub))
    print("  Step_count_raw  < 2         :", count_true(dsub["step_count_raw"] < 2))
    print("  Step_count_valid < 4        :", count_true(dsub["step_count_valid"] < 4))
    print("  Durasi_walk <= 0 (detik)    :", count_true(dsub["duration_walk_sec"] <= 0))
    print("  Distance_2d < 0.2 m         :", count_true(dsub["distance_2d_m"] < 0.2))
    print("  Speed > 3.0 m/s             :", count_true(dsub["walking_speed_ms"] > 3.0))
    print("  is_valid_trial = 0          :", count_true(dsub["is_valid_trial"] == 0))
# Out:
# === SANITY CHECK GLOBAL (V2) ===
# Total trial                    : 216
# Step_count_raw  < 2            : 1
# Step_count_valid < 4           : 22
# Durasi_walk <= 0 (detik)       : 0
# Distance_2d < 0.2 m            : 4
# Speed > 3.0 m/s                : 11
# Speed 0-0.1 m/s (hampir diam)  : 15
# Trial dengan is_valid_trial = 0: 101
#
# === SANITY CHECK PER SUBJECT (V2) ===
#
# -- Afi --
#   Total trial                 : 72
#   Step_count_raw  < 2         : 0
#   Step_count_valid < 4        : 11
#   Durasi_walk <= 0 (detik)    : 0
#   Distance_2d < 0.2 m         : 4
#   Speed > 3.0 m/s             : 6
#   is_valid_trial = 0          : 45
#
# -- Kinan --
#   Total trial                 : 72
#   Step_count_raw  < 2         : 0
#   Step_count_valid < 4        : 4
#   Durasi_walk <= 0 (detik)    : 0
#   Distance_2d < 0.2 m         : 0
#   Speed > 3.0 m/s             : 2
#   is_valid_trial = 0          : 28
#
# -- Miftah --
#   Total trial                 : 72
#   Step_count_raw  < 2         : 1
#   Step_count_valid < 4        : 7
#   Durasi_walk <= 0 (detik)    : 0
#   Distance_2d < 0.2 m         : 0
#   Speed > 3.0 m/s             : 3
#   is_valid_trial = 0          : 28

# %%
# Cell 9: Statistik ringkas per subject untuk fitur utama (V2)

df = df_final_v2.copy()

cols_stats = [
    "step_count_raw",
    "step_count_valid",
    "mean_step_time",
    "step_time_std",
    "cadence_spm",
    "walking_speed_ms",
    "step_length_m",
    "duration_walk_sec",
    "distance_2d_m",
]

group_stats = (
    df
    .groupby("subject")[cols_stats]
    .agg(["mean", "std", "min", "max"])
)

group_stats
# Out:
#         step_count_raw                   step_count_valid                    \
#                   mean       std min max             mean       std min max
# subject
# Afi           8.611111  5.572962   2  26         7.777778  5.297414   0  25
# Kinan         9.013889  4.570244   3  27         7.902778  4.431512   2  26
# Miftah        9.027778  5.202849   1  27         8.027778  4.717281   1  26
#
#         mean_step_time            ... step_length_m            \
#                   mean       std  ...           min       max
# subject                           ...
# Afi           0.497615  0.180189  ...      0.017573  4.584173
# Kinan         0.473002  0.184591  ...      0.031068  4.518180
# Miftah        0.527695  0.218176  ...      0.023131  2.941452
#
#         duration_walk_sec                                distance_2d_m  \
#                      mean       std       min        max          mean
# subject
# Afi              3.853434  3.774547  0.331384  15.564541      1.709440
# Kinan            3.578306  3.153748  0.329145  15.230792      1.715115
# Miftah           4.188775  3.724705  0.603805  16.940505      2.009220
#
#
#               std       min       max
# subject
# Afi      1.035593  0.087864  4.584173
# Kinan    0.875590  0.368204  4.518180
# Miftah   1.197089  0.231308  5.882904
#
# [3 rows x 36 columns]
