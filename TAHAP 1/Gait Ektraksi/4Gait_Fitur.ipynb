# %% [markdown]
# 🧩 Cell 1 – Import & path konfigurasi dasar

# %%
# Cell 1: Import & konfigurasi path V3

import os
import glob
import re
from pathlib import Path

import numpy as np
import pandas as pd

# Folder input: gait_with_steps (hasil Tahap 3)
FOLDER_GAIT_WITH_STEPS = r"E:\1.Clustering_TA\dataset\gaitframe_steps"

# Folder output: final fitur gait versi V3
FOLDER_GAIT_FEATURES_FINAL_ROOT_V3 = r"E:\1.Clustering_TA\dataset\gait_features_final_v3"
os.makedirs(FOLDER_GAIT_FEATURES_FINAL_ROOT_V3, exist_ok=True)

print("Input gait_with_steps  :", FOLDER_GAIT_WITH_STEPS)
print("Output root V3         :", FOLDER_GAIT_FEATURES_FINAL_ROOT_V3)

# Nama kolom waktu (detik) di file gait_with_steps
# Jika di file kamu namanya berbeda (misalnya 't_sec'),
# cukup ganti di sini.
COL_T_SEC = "timestamp_sec"   # ganti jika perlu
COL_STEP_FLAG = "step_event"

# Kolom posisi torso (dipakai untuk hitung jarak 2D)
COL_X = "torso_x"
COL_Y = "torso_y"
# Out:
# Input gait_with_steps  : E:\1.Clustering_TA\dataset\gaitframe_steps
# Output root V3         : E:\1.Clustering_TA\dataset\gait_features_final_v3

# %% [markdown]
# 🧩 Cell 2 – Helper: parsing nama file & MAD-based filtering step interval

# %%
# Cell 2: Helper parsing nama file & fungsi MAD untuk interval langkah

def parse_subject_trial_from_filename(path):
    """
    Contoh nama file:
    - Afi_Jalan1_gait_with_steps.csv
    - Kinan_Jalan10_gait_with_steps.csv

    Output:
    - subject: 'Afi'
    - trial_name: 'Jalan1'
    - trial_num: 1
    """
    p = Path(path)
    stem = p.stem  # tanpa .csv

    # buang suffix '_gait_with_steps' kalau ada
    stem = stem.replace("_gait_with_steps", "")

    parts = stem.split("_")
    if len(parts) >= 2:
        subject = parts[0]
        trial_name = "_".join(parts[1:])
    else:
        subject = stem
        trial_name = stem

    # ambil angka di akhir trial_name (misal 'Jalan10' -> 10)
    m = re.search(r"(\d+)$", trial_name)
    trial_num = int(m.group(1)) if m else None

    return subject, trial_name, trial_num


def compute_valid_interval_mask(intervals, min_interval=0.2, max_interval=2.5, mad_k=3.5):
    """
    intervals: np.array of step time intervals (detik)
    min_interval, max_interval: loose range untuk filter fisiologis
    mad_k: multiplier untuk MAD (outlier detection)

    Return:
    - mask boolean dengan panjang sama dengan intervals
      True artinya interval dianggap 'sehat'
    """
    if len(intervals) == 0:
        return np.array([], dtype=bool)

    # filter range fisiologis (longgar)
    mask_range = (intervals >= min_interval) & (intervals <= max_interval)

    if not np.any(mask_range):
        # kalau tidak ada satu pun interval dalam range,
        # kita fallback: gunakan semua interval apa adanya
        return np.ones_like(intervals, dtype=bool)

    # MAD-based filter di atas interval yang sudah dalam range
    valid_vals = intervals[mask_range]
    median = np.median(valid_vals)
    abs_dev = np.abs(valid_vals - median)
    mad = np.median(abs_dev)

    if mad == 0:
        # semua interval di subset ini kira-kira sama;
        # cukup pakai filter range saja
        return mask_range

    z_mad = abs_dev / mad
    # buat mask final di domain penuh
    mask_mad_full = np.zeros_like(intervals, dtype=bool)
    mask_mad_full[mask_range] = (z_mad <= mad_k)

    mask_final = mask_range & mask_mad_full
    if not np.any(mask_final):
        # kalau setelah MAD tidak ada yang lolos,
        # fallback ke filter range saja
        return mask_range

    return mask_final

# %% [markdown]
# 🧩 Cell 3 – Fungsi inti: hitung fitur gait V3 untuk satu trial

# %%
# Cell 3: Fungsi inti menghitung fitur gait V3 untuk satu trial

def compute_final_gait_features_v3_for_trial(
    df_trial,
    subject,
    trial_name,
    trial_num,
    col_t=COL_T_SEC,
    col_step=COL_STEP_FLAG,
    col_x=COL_X,
    col_y=COL_Y,
    min_interval=0.2,
    max_interval=2.5,
    mad_k=3.5
):
    """
    Hitung fitur gait (raw + filtered + quality) untuk satu trial.

    Output: dict satu baris untuk dimasukkan ke DataFrame final.
    """
    row = {
        "subject": subject,
        "trial_name": trial_name,
        "trial_num": trial_num,
    }

    df = df_trial.copy().reset_index(drop=True)

    # Pastikan kolom wajib ada
    for col in [col_t, col_step, col_x, col_y]:
        if col not in df.columns:
            raise KeyError(f"Kolom '{col}' tidak ditemukan di trial {subject} - {trial_name}")

    # Ambil step events
    step_mask = df[col_step] == 1
    idx_steps = np.where(step_mask)[0]
    ts_steps = df.loc[step_mask, col_t].to_numpy()

    # --- RAW FEATURES (V1-style) ---
    step_count_raw = len(ts_steps)
    row["step_count_raw"] = step_count_raw

    if step_count_raw < 2:
        # Tidak cukup step untuk hitung gait fitur
        row.update({
            "duration_raw_sec": np.nan,
            "distance_2d_raw_m": np.nan,
            "speed_raw_ms": np.nan,

            "step_count_valid": 0,
            "mean_step_time": np.nan,
            "step_time_std": np.nan,
            "cadence_spm": np.nan,
            "duration_valid_sec": np.nan,
            "distance_2d_valid_m": np.nan,
            "walking_speed_ms": np.nan,
            "step_length_m": np.nan,
            "ratio_valid_steps": 0.0,
            "is_valid_trial": 0,

            # alias backward-compat
            "duration_walk_sec": np.nan,
            "distance_2d_m": np.nan,
        })
        return row

    # Raw duration
    t0_raw = ts_steps[0]
    t1_raw = ts_steps[-1]
    duration_raw = float(t1_raw - t0_raw) if t1_raw > t0_raw else np.nan

    # Raw distance 2D
    first_idx_raw = idx_steps[0]
    last_idx_raw = idx_steps[-1]
    x0_raw = float(df.loc[first_idx_raw, col_x])
    y0_raw = float(df.loc[first_idx_raw, col_y])
    x1_raw = float(df.loc[last_idx_raw, col_x])
    y1_raw = float(df.loc[last_idx_raw, col_y])

    dx_raw = x1_raw - x0_raw
    dy_raw = y1_raw - y0_raw
    distance_raw = float(np.sqrt(dx_raw**2 + dy_raw**2))

    if duration_raw is not None and duration_raw > 0:
        speed_raw = distance_raw / duration_raw
    else:
        speed_raw = np.nan

    row["duration_raw_sec"] = duration_raw
    row["distance_2d_raw_m"] = distance_raw
    row["speed_raw_ms"] = speed_raw

    # --- FILTERED FEATURES (V3-based) ---

    # Interval antar step
    intervals = np.diff(ts_steps)  # len = step_count_raw - 1

    if len(intervals) == 0:
        # cuma 2 step, tidak ada interval variatif
        row.update({
            "step_count_valid": step_count_raw,
            "mean_step_time": np.nan,
            "step_time_std": np.nan,
            "cadence_spm": np.nan,
            "duration_valid_sec": duration_raw,
            "distance_2d_valid_m": distance_raw,
            "walking_speed_ms": speed_raw,
            "step_length_m": np.nan,
            "ratio_valid_steps": 1.0,
            "is_valid_trial": 0,  # trial terlalu pendek untuk ditandai valid penuh

            "duration_walk_sec": duration_raw,
            "distance_2d_m": distance_raw,
        })
        return row

    # Mask interval yang 'sehat' (loose range + MAD)
    mask_valid_intervals = compute_valid_interval_mask(
        intervals,
        min_interval=min_interval,
        max_interval=max_interval,
        mad_k=mad_k
    )

    # Indeks interval yang valid
    valid_int_indices = np.where(mask_valid_intervals)[0]

    if len(valid_int_indices) == 0:
        # Tidak ada interval yang sehat, semua step dianggap bermasalah
        row.update({
            "step_count_valid": 0,
            "mean_step_time": np.nan,
            "step_time_std": np.nan,
            "cadence_spm": np.nan,
            "duration_valid_sec": np.nan,
            "distance_2d_valid_m": np.nan,
            "walking_speed_ms": np.nan,
            "step_length_m": np.nan,
            "ratio_valid_steps": 0.0,
            "is_valid_trial": 0,

            "duration_walk_sec": duration_raw,
            "distance_2d_m": distance_raw,
        })
        return row

    # Tentukan range step index yang valid (pakai cluster pertama–terakhir yang valid)
    first_valid_interval_idx = valid_int_indices[0]
    last_valid_interval_idx = valid_int_indices[-1]

    # Interval i menghubungkan step i dan i+1
    # jadi subset step valid = [first_valid_interval_idx .. last_valid_interval_idx+1]
    start_step_idx = first_valid_interval_idx
    end_step_idx = last_valid_interval_idx + 1

    ts_steps_valid = ts_steps[start_step_idx : end_step_idx + 1]
    idx_steps_valid = idx_steps[start_step_idx : end_step_idx + 1]

    step_count_valid = len(ts_steps_valid)
    row["step_count_valid"] = step_count_valid

    # Mean & std step time (pakai intervals yang valid saja)
    intervals_valid = intervals[valid_int_indices]
    mean_step_time = float(np.mean(intervals_valid)) if len(intervals_valid) > 0 else np.nan
    step_time_std = float(np.std(intervals_valid, ddof=1)) if len(intervals_valid) > 1 else 0.0

    # Durasi valid
    t0_valid = ts_steps_valid[0]
    t1_valid = ts_steps_valid[-1]
    duration_valid = float(t1_valid - t0_valid) if t1_valid > t0_valid else np.nan

    # Distance valid (2D)
    first_idx_valid = idx_steps_valid[0]
    last_idx_valid = idx_steps_valid[-1]
    x0_valid = float(df.loc[first_idx_valid, col_x])
    y0_valid = float(df.loc[first_idx_valid, col_y])
    x1_valid = float(df.loc[last_idx_valid, col_x])
    y1_valid = float(df.loc[last_idx_valid, col_y])

    dx_valid = x1_valid - x0_valid
    dy_valid = y1_valid - y0_valid
    distance_valid = float(np.sqrt(dx_valid**2 + dy_valid**2))

    if duration_valid is not None and duration_valid > 0:
        walking_speed_ms = distance_valid / duration_valid
    else:
        walking_speed_ms = np.nan

    # Cadence (langkah per menit)
    if mean_step_time is not None and mean_step_time > 0:
        cadence_spm = 60.0 / mean_step_time
    else:
        cadence_spm = np.nan

    # Step length (m per step)
    if step_count_valid > 0:
        step_length_m = distance_valid / step_count_valid
    else:
        step_length_m = np.nan

    # Rasio valid steps
    ratio_valid_steps = step_count_valid / step_count_raw if step_count_raw > 0 else 0.0

    # Simpan ke row
    row.update({
        "mean_step_time": mean_step_time,
        "step_time_std": step_time_std,
        "cadence_spm": cadence_spm,
        "duration_valid_sec": duration_valid,
        "distance_2d_valid_m": distance_valid,
        "walking_speed_ms": walking_speed_ms,
        "step_length_m": step_length_m,
        "ratio_valid_steps": ratio_valid_steps,
    })

    # --- Penentuan is_valid_trial (V3 rules) ---
    # Aturan: versi kompromi (tidak terlalu ketat, tetap fisiologis)
    conds = []

    # Minimal step valid
    conds.append(step_count_valid >= 4)

    # Durasi minimal
    if duration_valid is not None and not np.isnan(duration_valid):
        conds.append(duration_valid >= 1.2)  # detik
    else:
        conds.append(False)

    # Jarak minimal
    if distance_valid is not None and not np.isnan(distance_valid):
        conds.append(distance_valid >= 0.3)  # meter
    else:
        conds.append(False)

    # Range kecepatan
    if walking_speed_ms is not None and not np.isnan(walking_speed_ms):
        conds.append(walking_speed_ms >= 0.1)
        conds.append(walking_speed_ms <= 3.5)
    else:
        conds.append(False)

    # Range mean_step_time (s)
    if mean_step_time is not None and not np.isnan(mean_step_time):
        conds.append(mean_step_time >= 0.2)
        conds.append(mean_step_time <= 2.0)
    else:
        conds.append(False)

    is_valid_trial = int(all(conds))

    row["is_valid_trial"] = is_valid_trial

    # Alias untuk kompatibilitas dengan V1/V2
    row["duration_walk_sec"] = duration_valid
    row["distance_2d_m"] = distance_valid

    return row

# %% [markdown]
# 🧩 Cell 4 – Fungsi utama: proses semua file gait_with_steps → df_final_v3

# %%
# Cell 4: Proses semua file gait_with_steps untuk membuat fitur V3

def process_all_final_gait_features_v3(
    folder_in=FOLDER_GAIT_WITH_STEPS,
    folder_out=FOLDER_GAIT_FEATURES_FINAL_ROOT_V3
):
    pattern = os.path.join(folder_in, "*_gait_with_steps.csv")
    files = sorted(glob.glob(pattern))

    if not files:
        print("Tidak ada file gait_with_steps yang ditemukan di:", folder_in)
        return None

    rows = []

    print("Ditemukan", len(files), "file gait_with_steps.")
    for fpath in files:
        subject, trial_name, trial_num = parse_subject_trial_from_filename(fpath)
        print(f"Proses: {Path(fpath).name} -> subject={subject}, trial={trial_name}, trial_num={trial_num}")

        df_trial = pd.read_csv(fpath)

        # Jika kolom waktu tidak sesuai, fallback otomatis
        col_t_used = COL_T_SEC
        if COL_T_SEC not in df_trial.columns:
            if "t_sec" in df_trial.columns:
                col_t_used = "t_sec"
            else:
                raise KeyError(f"Tidak menemukan kolom waktu '{COL_T_SEC}' maupun 't_sec' di {fpath}")

        row = compute_final_gait_features_v3_for_trial(
            df_trial,
            subject=subject,
            trial_name=trial_name,
            trial_num=trial_num,
            col_t=col_t_used,
            col_step=COL_STEP_FLAG,
            col_x=COL_X,
            col_y=COL_Y,
            min_interval=0.2,
            max_interval=2.5,
            mad_k=3.5,
        )

        rows.append(row)

    df_all = pd.DataFrame(rows)

    # Sort global: subject, lalu trial_num (kalau ada)
    sort_cols = ["subject"]
    if "trial_num" in df_all.columns:
        sort_cols.append("trial_num")
    df_all_sorted = df_all.sort_values(sort_cols).reset_index(drop=True)

    # Simpan global
    global_out_path = os.path.join(folder_out, "gait_features_final_all_v3.csv")
    df_all_sorted.to_csv(global_out_path, index=False)
    print("\n=== [V3] Global summary disimpan ===")
    print(global_out_path)

    # Simpan per subject (format mirip V1/V2)
    for subject, dsub in df_all_sorted.groupby("subject"):
        fname = f"{subject}_gait_features_5_v3.csv"
        fpath = os.path.join(folder_out, fname)
        dsub.to_csv(fpath, index=False)
        print(f"  [V3] Subject {subject} disimpan di: {fpath}")

    return df_all_sorted

# %% [markdown]
# 🧩 Cell 5 – Jalankan V3 & sanity check singkat

# %%
# Cell 5: Jalankan proses V3 dan sanity check sederhana

df_final_v3 = process_all_final_gait_features_v3()

df_final_v3.head()
# Out:
# Ditemukan 216 file gait_with_steps.
# Proses: Afi_Jalan10_gait_with_steps.csv -> subject=Afi, trial=Jalan10, trial_num=10
# Proses: Afi_Jalan11_gait_with_steps.csv -> subject=Afi, trial=Jalan11, trial_num=11
# Proses: Afi_Jalan12_gait_with_steps.csv -> subject=Afi, trial=Jalan12, trial_num=12
# Proses: Afi_Jalan13_gait_with_steps.csv -> subject=Afi, trial=Jalan13, trial_num=13
# Proses: Afi_Jalan14_gait_with_steps.csv -> subject=Afi, trial=Jalan14, trial_num=14
# Proses: Afi_Jalan15_gait_with_steps.csv -> subject=Afi, trial=Jalan15, trial_num=15
# Proses: Afi_Jalan16_gait_with_steps.csv -> subject=Afi, trial=Jalan16, trial_num=16
# Proses: Afi_Jalan17_gait_with_steps.csv -> subject=Afi, trial=Jalan17, trial_num=17
# Proses: Afi_Jalan18_gait_with_steps.csv -> subject=Afi, trial=Jalan18, trial_num=18
# Proses: Afi_Jalan19_gait_with_steps.csv -> subject=Afi, trial=Jalan19, trial_num=19
# Proses: Afi_Jalan1_gait_with_steps.csv -> subject=Afi, trial=Jalan1, trial_num=1
# Proses: Afi_Jalan20_gait_with_steps.csv -> subject=Afi, trial=Jalan20, trial_num=20
# Proses: Afi_Jalan21_gait_with_steps.csv -> subject=Afi, trial=Jalan21, trial_num=21
# Proses: Afi_Jalan22_gait_with_steps.csv -> subject=Afi, trial=Jalan22, trial_num=22
# Proses: Afi_Jalan23_gait_with_steps.csv -> subject=Afi, trial=Jalan23, trial_num=23
# Proses: Afi_Jalan24_gait_with_steps.csv -> subject=Afi, trial=Jalan24, trial_num=24
# Proses: Afi_Jalan25_gait_with_steps.csv -> subject=Afi, trial=Jalan25, trial_num=25
# Proses: Afi_Jalan26_gait_with_steps.csv -> subject=Afi, trial=Jalan26, trial_num=26
# Proses: Afi_Jalan27_gait_with_steps.csv -> subject=Afi, trial=Jalan27, trial_num=27
# Proses: Afi_Jalan28_gait_with_steps.csv -> subject=Afi, trial=Jalan28, trial_num=28
# Proses: Afi_Jalan29_gait_with_steps.csv -> subject=Afi, trial=Jalan29, trial_num=29
# Proses: Afi_Jalan2_gait_with_steps.csv -> subject=Afi, trial=Jalan2, trial_num=2
# Proses: Afi_Jalan30_gait_with_steps.csv -> subject=Afi, trial=Jalan30, trial_num=30
# Proses: Afi_Jalan31_gait_with_steps.csv -> subject=Afi, trial=Jalan31, trial_num=31
# Proses: Afi_Jalan32_gait_with_steps.csv -> subject=Afi, trial=Jalan32, trial_num=32
# Proses: Afi_Jalan33_gait_with_steps.csv -> subject=Afi, trial=Jalan33, trial_num=33
# Proses: Afi_Jalan34_gait_with_steps.csv -> subject=Afi, trial=Jalan34, trial_num=34
# Proses: Afi_Jalan35_gait_with_steps.csv -> subject=Afi, trial=Jalan35, trial_num=35
# Proses: Afi_Jalan36_gait_with_steps.csv -> subject=Afi, trial=Jalan36, trial_num=36
# Proses: Afi_Jalan37_gait_with_steps.csv -> subject=Afi, trial=Jalan37, trial_num=37
# Proses: Afi_Jalan38_gait_with_steps.csv -> subject=Afi, trial=Jalan38, trial_num=38
# Proses: Afi_Jalan39_gait_with_steps.csv -> subject=Afi, trial=Jalan39, trial_num=39
# Proses: Afi_Jalan3_gait_with_steps.csv -> subject=Afi, trial=Jalan3, trial_num=3
# Proses: Afi_Jalan40_gait_with_steps.csv -> subject=Afi, trial=Jalan40, trial_num=40
# Proses: Afi_Jalan41_gait_with_steps.csv -> subject=Afi, trial=Jalan41, trial_num=41
# Proses: Afi_Jalan42_gait_with_steps.csv -> subject=Afi, trial=Jalan42, trial_num=42
# Proses: Afi_Jalan43_gait_with_steps.csv -> subject=Afi, trial=Jalan43, trial_num=43
# Proses: Afi_Jalan44_gait_with_steps.csv -> subject=Afi, trial=Jalan44, trial_num=44
# Proses: Afi_Jalan45_gait_with_steps.csv -> subject=Afi, trial=Jalan45, trial_num=45
# Proses: Afi_Jalan46_gait_with_steps.csv -> subject=Afi, trial=Jalan46, trial_num=46
# Proses: Afi_Jalan47_gait_with_steps.csv -> subject=Afi, trial=Jalan47, trial_num=47
# Proses: Afi_Jalan48_gait_with_steps.csv -> subject=Afi, trial=Jalan48, trial_num=48
# Proses: Afi_Jalan49_gait_with_steps.csv -> subject=Afi, trial=Jalan49, trial_num=49
# Proses: Afi_Jalan4_gait_with_steps.csv -> subject=Afi, trial=Jalan4, trial_num=4
# Proses: Afi_Jalan50_gait_with_steps.csv -> subject=Afi, trial=Jalan50, trial_num=50
# Proses: Afi_Jalan51_gait_with_steps.csv -> subject=Afi, trial=Jalan51, trial_num=51
# Proses: Afi_Jalan52_gait_with_steps.csv -> subject=Afi, trial=Jalan52, trial_num=52
# Proses: Afi_Jalan53_gait_with_steps.csv -> subject=Afi, trial=Jalan53, trial_num=53
# Proses: Afi_Jalan54_gait_with_steps.csv -> subject=Afi, trial=Jalan54, trial_num=54
# Proses: Afi_Jalan55_gait_with_steps.csv -> subject=Afi, trial=Jalan55, trial_num=55
# Proses: Afi_Jalan56_gait_with_steps.csv -> subject=Afi, trial=Jalan56, trial_num=56
# Proses: Afi_Jalan57_gait_with_steps.csv -> subject=Afi, trial=Jalan57, trial_num=57
# Proses: Afi_Jalan58_gait_with_steps.csv -> subject=Afi, trial=Jalan58, trial_num=58
# Proses: Afi_Jalan59_gait_with_steps.csv -> subject=Afi, trial=Jalan59, trial_num=59
# Proses: Afi_Jalan5_gait_with_steps.csv -> subject=Afi, trial=Jalan5, trial_num=5
# Proses: Afi_Jalan60_gait_with_steps.csv -> subject=Afi, trial=Jalan60, trial_num=60
# Proses: Afi_Jalan61_gait_with_steps.csv -> subject=Afi, trial=Jalan61, trial_num=61
# Proses: Afi_Jalan62_gait_with_steps.csv -> subject=Afi, trial=Jalan62, trial_num=62
# Proses: Afi_Jalan63_gait_with_steps.csv -> subject=Afi, trial=Jalan63, trial_num=63
# Proses: Afi_Jalan64_gait_with_steps.csv -> subject=Afi, trial=Jalan64, trial_num=64
# Proses: Afi_Jalan65_gait_with_steps.csv -> subject=Afi, trial=Jalan65, trial_num=65
# Proses: Afi_Jalan66_gait_with_steps.csv -> subject=Afi, trial=Jalan66, trial_num=66
# Proses: Afi_Jalan67_gait_with_steps.csv -> subject=Afi, trial=Jalan67, trial_num=67
# Proses: Afi_Jalan68_gait_with_steps.csv -> subject=Afi, trial=Jalan68, trial_num=68
# Proses: Afi_Jalan69_gait_with_steps.csv -> subject=Afi, trial=Jalan69, trial_num=69
# Proses: Afi_Jalan6_gait_with_steps.csv -> subject=Afi, trial=Jalan6, trial_num=6
# Proses: Afi_Jalan70_gait_with_steps.csv -> subject=Afi, trial=Jalan70, trial_num=70
# Proses: Afi_Jalan71_gait_with_steps.csv -> subject=Afi, trial=Jalan71, trial_num=71
# Proses: Afi_Jalan72_gait_with_steps.csv -> subject=Afi, trial=Jalan72, trial_num=72
# Proses: Afi_Jalan7_gait_with_steps.csv -> subject=Afi, trial=Jalan7, trial_num=7
# Proses: Afi_Jalan8_gait_with_steps.csv -> subject=Afi, trial=Jalan8, trial_num=8
# Proses: Afi_Jalan9_gait_with_steps.csv -> subject=Afi, trial=Jalan9, trial_num=9
# Proses: Kinan_Jalan10_gait_with_steps.csv -> subject=Kinan, trial=Jalan10, trial_num=10
# Proses: Kinan_Jalan11_gait_with_steps.csv -> subject=Kinan, trial=Jalan11, trial_num=11
# Proses: Kinan_Jalan12_gait_with_steps.csv -> subject=Kinan, trial=Jalan12, trial_num=12
# Proses: Kinan_Jalan13_gait_with_steps.csv -> subject=Kinan, trial=Jalan13, trial_num=13
# Proses: Kinan_Jalan14_gait_with_steps.csv -> subject=Kinan, trial=Jalan14, trial_num=14
# Proses: Kinan_Jalan15_gait_with_steps.csv -> subject=Kinan, trial=Jalan15, trial_num=15
# Proses: Kinan_Jalan16_gait_with_steps.csv -> subject=Kinan, trial=Jalan16, trial_num=16
# Proses: Kinan_Jalan17_gait_with_steps.csv -> subject=Kinan, trial=Jalan17, trial_num=17
# Proses: Kinan_Jalan18_gait_with_steps.csv -> subject=Kinan, trial=Jalan18, trial_num=18
# Proses: Kinan_Jalan19_gait_with_steps.csv -> subject=Kinan, trial=Jalan19, trial_num=19
# Proses: Kinan_Jalan1_gait_with_steps.csv -> subject=Kinan, trial=Jalan1, trial_num=1
# Proses: Kinan_Jalan20_gait_with_steps.csv -> subject=Kinan, trial=Jalan20, trial_num=20
# Proses: Kinan_Jalan21_gait_with_steps.csv -> subject=Kinan, trial=Jalan21, trial_num=21
# Proses: Kinan_Jalan22_gait_with_steps.csv -> subject=Kinan, trial=Jalan22, trial_num=22
# Proses: Kinan_Jalan23_gait_with_steps.csv -> subject=Kinan, trial=Jalan23, trial_num=23
# Proses: Kinan_Jalan24_gait_with_steps.csv -> subject=Kinan, trial=Jalan24, trial_num=24
# Proses: Kinan_Jalan25_gait_with_steps.csv -> subject=Kinan, trial=Jalan25, trial_num=25
# Proses: Kinan_Jalan26_gait_with_steps.csv -> subject=Kinan, trial=Jalan26, trial_num=26
# Proses: Kinan_Jalan27_gait_with_steps.csv -> subject=Kinan, trial=Jalan27, trial_num=27
# Proses: Kinan_Jalan28_gait_with_steps.csv -> subject=Kinan, trial=Jalan28, trial_num=28
# Proses: Kinan_Jalan29_gait_with_steps.csv -> subject=Kinan, trial=Jalan29, trial_num=29
# Proses: Kinan_Jalan2_gait_with_steps.csv -> subject=Kinan, trial=Jalan2, trial_num=2
# Proses: Kinan_Jalan30_gait_with_steps.csv -> subject=Kinan, trial=Jalan30, trial_num=30
# Proses: Kinan_Jalan31_gait_with_steps.csv -> subject=Kinan, trial=Jalan31, trial_num=31
# Proses: Kinan_Jalan32_gait_with_steps.csv -> subject=Kinan, trial=Jalan32, trial_num=32
# Proses: Kinan_Jalan33_gait_with_steps.csv -> subject=Kinan, trial=Jalan33, trial_num=33
# Proses: Kinan_Jalan34_gait_with_steps.csv -> subject=Kinan, trial=Jalan34, trial_num=34
# Proses: Kinan_Jalan35_gait_with_steps.csv -> subject=Kinan, trial=Jalan35, trial_num=35
# Proses: Kinan_Jalan36_gait_with_steps.csv -> subject=Kinan, trial=Jalan36, trial_num=36
# Proses: Kinan_Jalan37_gait_with_steps.csv -> subject=Kinan, trial=Jalan37, trial_num=37
# Proses: Kinan_Jalan38_gait_with_steps.csv -> subject=Kinan, trial=Jalan38, trial_num=38
# Proses: Kinan_Jalan39_gait_with_steps.csv -> subject=Kinan, trial=Jalan39, trial_num=39
# Proses: Kinan_Jalan3_gait_with_steps.csv -> subject=Kinan, trial=Jalan3, trial_num=3
# Proses: Kinan_Jalan40_gait_with_steps.csv -> subject=Kinan, trial=Jalan40, trial_num=40
# Proses: Kinan_Jalan41_gait_with_steps.csv -> subject=Kinan, trial=Jalan41, trial_num=41
# Proses: Kinan_Jalan42_gait_with_steps.csv -> subject=Kinan, trial=Jalan42, trial_num=42
# Proses: Kinan_Jalan43_gait_with_steps.csv -> subject=Kinan, trial=Jalan43, trial_num=43
# Proses: Kinan_Jalan44_gait_with_steps.csv -> subject=Kinan, trial=Jalan44, trial_num=44
# Proses: Kinan_Jalan45_gait_with_steps.csv -> subject=Kinan, trial=Jalan45, trial_num=45
# Proses: Kinan_Jalan46_gait_with_steps.csv -> subject=Kinan, trial=Jalan46, trial_num=46
# Proses: Kinan_Jalan47_gait_with_steps.csv -> subject=Kinan, trial=Jalan47, trial_num=47
# Proses: Kinan_Jalan48_gait_with_steps.csv -> subject=Kinan, trial=Jalan48, trial_num=48
# Proses: Kinan_Jalan49_gait_with_steps.csv -> subject=Kinan, trial=Jalan49, trial_num=49
# Proses: Kinan_Jalan4_gait_with_steps.csv -> subject=Kinan, trial=Jalan4, trial_num=4
# Proses: Kinan_Jalan50_gait_with_steps.csv -> subject=Kinan, trial=Jalan50, trial_num=50
# Proses: Kinan_Jalan51_gait_with_steps.csv -> subject=Kinan, trial=Jalan51, trial_num=51
# Proses: Kinan_Jalan52_gait_with_steps.csv -> subject=Kinan, trial=Jalan52, trial_num=52
# Proses: Kinan_Jalan53_gait_with_steps.csv -> subject=Kinan, trial=Jalan53, trial_num=53
# Proses: Kinan_Jalan54_gait_with_steps.csv -> subject=Kinan, trial=Jalan54, trial_num=54
# Proses: Kinan_Jalan55_gait_with_steps.csv -> subject=Kinan, trial=Jalan55, trial_num=55
# Proses: Kinan_Jalan56_gait_with_steps.csv -> subject=Kinan, trial=Jalan56, trial_num=56
# Proses: Kinan_Jalan57_gait_with_steps.csv -> subject=Kinan, trial=Jalan57, trial_num=57
# Proses: Kinan_Jalan58_gait_with_steps.csv -> subject=Kinan, trial=Jalan58, trial_num=58
# Proses: Kinan_Jalan59_gait_with_steps.csv -> subject=Kinan, trial=Jalan59, trial_num=59
# Proses: Kinan_Jalan5_gait_with_steps.csv -> subject=Kinan, trial=Jalan5, trial_num=5
# Proses: Kinan_Jalan60_gait_with_steps.csv -> subject=Kinan, trial=Jalan60, trial_num=60
# Proses: Kinan_Jalan61_gait_with_steps.csv -> subject=Kinan, trial=Jalan61, trial_num=61
# Proses: Kinan_Jalan62_gait_with_steps.csv -> subject=Kinan, trial=Jalan62, trial_num=62
# Proses: Kinan_Jalan63_gait_with_steps.csv -> subject=Kinan, trial=Jalan63, trial_num=63
# Proses: Kinan_Jalan64_gait_with_steps.csv -> subject=Kinan, trial=Jalan64, trial_num=64
# Proses: Kinan_Jalan65_gait_with_steps.csv -> subject=Kinan, trial=Jalan65, trial_num=65
# Proses: Kinan_Jalan66_gait_with_steps.csv -> subject=Kinan, trial=Jalan66, trial_num=66
# Proses: Kinan_Jalan67_gait_with_steps.csv -> subject=Kinan, trial=Jalan67, trial_num=67
# Proses: Kinan_Jalan68_gait_with_steps.csv -> subject=Kinan, trial=Jalan68, trial_num=68
# Proses: Kinan_Jalan69_gait_with_steps.csv -> subject=Kinan, trial=Jalan69, trial_num=69
# Proses: Kinan_Jalan6_gait_with_steps.csv -> subject=Kinan, trial=Jalan6, trial_num=6
# Proses: Kinan_Jalan70_gait_with_steps.csv -> subject=Kinan, trial=Jalan70, trial_num=70
# Proses: Kinan_Jalan71_gait_with_steps.csv -> subject=Kinan, trial=Jalan71, trial_num=71
# Proses: Kinan_Jalan72_gait_with_steps.csv -> subject=Kinan, trial=Jalan72, trial_num=72
# Proses: Kinan_Jalan7_gait_with_steps.csv -> subject=Kinan, trial=Jalan7, trial_num=7
# Proses: Kinan_Jalan8_gait_with_steps.csv -> subject=Kinan, trial=Jalan8, trial_num=8
# Proses: Kinan_Jalan9_gait_with_steps.csv -> subject=Kinan, trial=Jalan9, trial_num=9
# Proses: Miftah_Jalan10_gait_with_steps.csv -> subject=Miftah, trial=Jalan10, trial_num=10
# Proses: Miftah_Jalan11_gait_with_steps.csv -> subject=Miftah, trial=Jalan11, trial_num=11
# Proses: Miftah_Jalan12_gait_with_steps.csv -> subject=Miftah, trial=Jalan12, trial_num=12
# Proses: Miftah_Jalan13_gait_with_steps.csv -> subject=Miftah, trial=Jalan13, trial_num=13
# Proses: Miftah_Jalan14_gait_with_steps.csv -> subject=Miftah, trial=Jalan14, trial_num=14
# Proses: Miftah_Jalan15_gait_with_steps.csv -> subject=Miftah, trial=Jalan15, trial_num=15
# Proses: Miftah_Jalan16_gait_with_steps.csv -> subject=Miftah, trial=Jalan16, trial_num=16
# Proses: Miftah_Jalan17_gait_with_steps.csv -> subject=Miftah, trial=Jalan17, trial_num=17
# Proses: Miftah_Jalan18_gait_with_steps.csv -> subject=Miftah, trial=Jalan18, trial_num=18
# Proses: Miftah_Jalan19_gait_with_steps.csv -> subject=Miftah, trial=Jalan19, trial_num=19
# Proses: Miftah_Jalan1_gait_with_steps.csv -> subject=Miftah, trial=Jalan1, trial_num=1
# Proses: Miftah_Jalan20_gait_with_steps.csv -> subject=Miftah, trial=Jalan20, trial_num=20
# Proses: Miftah_Jalan21_gait_with_steps.csv -> subject=Miftah, trial=Jalan21, trial_num=21
# Proses: Miftah_Jalan22_gait_with_steps.csv -> subject=Miftah, trial=Jalan22, trial_num=22
# Proses: Miftah_Jalan23_gait_with_steps.csv -> subject=Miftah, trial=Jalan23, trial_num=23
# Proses: Miftah_Jalan24_gait_with_steps.csv -> subject=Miftah, trial=Jalan24, trial_num=24
# Proses: Miftah_Jalan25_gait_with_steps.csv -> subject=Miftah, trial=Jalan25, trial_num=25
# Proses: Miftah_Jalan26_gait_with_steps.csv -> subject=Miftah, trial=Jalan26, trial_num=26
# Proses: Miftah_Jalan27_gait_with_steps.csv -> subject=Miftah, trial=Jalan27, trial_num=27
# Proses: Miftah_Jalan28_gait_with_steps.csv -> subject=Miftah, trial=Jalan28, trial_num=28
# Proses: Miftah_Jalan29_gait_with_steps.csv -> subject=Miftah, trial=Jalan29, trial_num=29
# Proses: Miftah_Jalan2_gait_with_steps.csv -> subject=Miftah, trial=Jalan2, trial_num=2
# Proses: Miftah_Jalan30_gait_with_steps.csv -> subject=Miftah, trial=Jalan30, trial_num=30
# Proses: Miftah_Jalan31_gait_with_steps.csv -> subject=Miftah, trial=Jalan31, trial_num=31
# Proses: Miftah_Jalan32_gait_with_steps.csv -> subject=Miftah, trial=Jalan32, trial_num=32
# Proses: Miftah_Jalan33_gait_with_steps.csv -> subject=Miftah, trial=Jalan33, trial_num=33
# Proses: Miftah_Jalan34_gait_with_steps.csv -> subject=Miftah, trial=Jalan34, trial_num=34
# Proses: Miftah_Jalan35_gait_with_steps.csv -> subject=Miftah, trial=Jalan35, trial_num=35
# Proses: Miftah_Jalan36_gait_with_steps.csv -> subject=Miftah, trial=Jalan36, trial_num=36
# Proses: Miftah_Jalan37_gait_with_steps.csv -> subject=Miftah, trial=Jalan37, trial_num=37
# Proses: Miftah_Jalan38_gait_with_steps.csv -> subject=Miftah, trial=Jalan38, trial_num=38
# Proses: Miftah_Jalan39_gait_with_steps.csv -> subject=Miftah, trial=Jalan39, trial_num=39
# Proses: Miftah_Jalan3_gait_with_steps.csv -> subject=Miftah, trial=Jalan3, trial_num=3
# Proses: Miftah_Jalan40_gait_with_steps.csv -> subject=Miftah, trial=Jalan40, trial_num=40
# Proses: Miftah_Jalan41_gait_with_steps.csv -> subject=Miftah, trial=Jalan41, trial_num=41
# Proses: Miftah_Jalan42_gait_with_steps.csv -> subject=Miftah, trial=Jalan42, trial_num=42
# Proses: Miftah_Jalan43_gait_with_steps.csv -> subject=Miftah, trial=Jalan43, trial_num=43
# Proses: Miftah_Jalan44_gait_with_steps.csv -> subject=Miftah, trial=Jalan44, trial_num=44
# Proses: Miftah_Jalan45_gait_with_steps.csv -> subject=Miftah, trial=Jalan45, trial_num=45
# Proses: Miftah_Jalan46_gait_with_steps.csv -> subject=Miftah, trial=Jalan46, trial_num=46
# Proses: Miftah_Jalan47_gait_with_steps.csv -> subject=Miftah, trial=Jalan47, trial_num=47
# Proses: Miftah_Jalan48_gait_with_steps.csv -> subject=Miftah, trial=Jalan48, trial_num=48
# Proses: Miftah_Jalan49_gait_with_steps.csv -> subject=Miftah, trial=Jalan49, trial_num=49
# Proses: Miftah_Jalan4_gait_with_steps.csv -> subject=Miftah, trial=Jalan4, trial_num=4
# Proses: Miftah_Jalan50_gait_with_steps.csv -> subject=Miftah, trial=Jalan50, trial_num=50
# Proses: Miftah_Jalan51_gait_with_steps.csv -> subject=Miftah, trial=Jalan51, trial_num=51
# Proses: Miftah_Jalan52_gait_with_steps.csv -> subject=Miftah, trial=Jalan52, trial_num=52
# Proses: Miftah_Jalan53_gait_with_steps.csv -> subject=Miftah, trial=Jalan53, trial_num=53
# Proses: Miftah_Jalan54_gait_with_steps.csv -> subject=Miftah, trial=Jalan54, trial_num=54
# Proses: Miftah_Jalan55_gait_with_steps.csv -> subject=Miftah, trial=Jalan55, trial_num=55
# Proses: Miftah_Jalan56_gait_with_steps.csv -> subject=Miftah, trial=Jalan56, trial_num=56
# Proses: Miftah_Jalan57_gait_with_steps.csv -> subject=Miftah, trial=Jalan57, trial_num=57
# Proses: Miftah_Jalan58_gait_with_steps.csv -> subject=Miftah, trial=Jalan58, trial_num=58
# Proses: Miftah_Jalan59_gait_with_steps.csv -> subject=Miftah, trial=Jalan59, trial_num=59
# Proses: Miftah_Jalan5_gait_with_steps.csv -> subject=Miftah, trial=Jalan5, trial_num=5
# Proses: Miftah_Jalan60_gait_with_steps.csv -> subject=Miftah, trial=Jalan60, trial_num=60
# Proses: Miftah_Jalan61_gait_with_steps.csv -> subject=Miftah, trial=Jalan61, trial_num=61
# Proses: Miftah_Jalan62_gait_with_steps.csv -> subject=Miftah, trial=Jalan62, trial_num=62
# Proses: Miftah_Jalan63_gait_with_steps.csv -> subject=Miftah, trial=Jalan63, trial_num=63
# Proses: Miftah_Jalan64_gait_with_steps.csv -> subject=Miftah, trial=Jalan64, trial_num=64
# Proses: Miftah_Jalan65_gait_with_steps.csv -> subject=Miftah, trial=Jalan65, trial_num=65
# Proses: Miftah_Jalan66_gait_with_steps.csv -> subject=Miftah, trial=Jalan66, trial_num=66
# Proses: Miftah_Jalan67_gait_with_steps.csv -> subject=Miftah, trial=Jalan67, trial_num=67
# Proses: Miftah_Jalan68_gait_with_steps.csv -> subject=Miftah, trial=Jalan68, trial_num=68
# Proses: Miftah_Jalan69_gait_with_steps.csv -> subject=Miftah, trial=Jalan69, trial_num=69
# Proses: Miftah_Jalan6_gait_with_steps.csv -> subject=Miftah, trial=Jalan6, trial_num=6
# Proses: Miftah_Jalan70_gait_with_steps.csv -> subject=Miftah, trial=Jalan70, trial_num=70
# Proses: Miftah_Jalan71_gait_with_steps.csv -> subject=Miftah, trial=Jalan71, trial_num=71
# Proses: Miftah_Jalan72_gait_with_steps.csv -> subject=Miftah, trial=Jalan72, trial_num=72
# Proses: Miftah_Jalan7_gait_with_steps.csv -> subject=Miftah, trial=Jalan7, trial_num=7
# Proses: Miftah_Jalan8_gait_with_steps.csv -> subject=Miftah, trial=Jalan8, trial_num=8
# Proses: Miftah_Jalan9_gait_with_steps.csv -> subject=Miftah, trial=Jalan9, trial_num=9
#
# === [V3] Global summary disimpan ===
# E:\1.Clustering_TA\dataset\gait_features_final_v3\gait_features_final_all_v3.csv
#   [V3] Subject Afi disimpan di: E:\1.Clustering_TA\dataset\gait_features_final_v3\Afi_gait_features_5_v3.csv
#   [V3] Subject Kinan disimpan di: E:\1.Clustering_TA\dataset\gait_features_final_v3\Kinan_gait_features_5_v3.csv
#   [V3] Subject Miftah disimpan di: E:\1.Clustering_TA\dataset\gait_features_final_v3\Miftah_gait_features_5_v3.csv
#   subject trial_name  trial_num  step_count_raw  duration_raw_sec  \
# 0     Afi     Jalan1          1               3          0.714816
# 1     Afi     Jalan2          2               6          2.083814
# 2     Afi     Jalan3          3               5          1.597363
# 3     Afi     Jalan4          4               2          0.391930
# 4     Afi     Jalan5          5               5          1.971074
#
#    distance_2d_raw_m  speed_raw_ms  step_count_valid  mean_step_time  \
# 0           1.180483      1.651451                 3        0.357408
# 1           0.732601      0.351567                 6        0.304218
# 2           3.081816      1.929315                 5        0.399341
# 3           4.584173     11.696408                 2        0.391930
# 4           2.492903      1.264743                 4        0.349715
#
#    step_time_std  cadence_spm  duration_valid_sec  distance_2d_valid_m  \
# 0       0.040571   167.875369            0.714816             1.180483
# 1       0.033932   197.226989            2.083814             0.732601
# 2       0.052022   150.247627            1.597363             3.081816
# 3       0.000000   153.088562            0.391930             4.584173
# 4       0.081992   171.568277            1.049145             1.700045
#
#    walking_speed_ms  step_length_m  ratio_valid_steps  is_valid_trial  \
# 0          1.651451       0.393494                1.0               0
# 1          0.351567       0.122100                1.0               1
# 2          1.929315       0.616363                1.0               1
# 3         11.696408       2.292087                1.0               0
# 4          1.620410       0.425011                0.8               0
#
#    duration_walk_sec  distance_2d_m
# 0           0.714816       1.180483
# 1           2.083814       0.732601
# 2           1.597363       3.081816
# 3           0.391930       4.584173
# 4           1.049145       1.700045

# %%
# Cell 6: Sanity check V3 (mirip V1/V2 tapi pakai kolom baru)

df = df_final_v3.copy()

def count_true(series):
    return int(series.fillna(False).sum())

print("=== SANITY CHECK GLOBAL (V3) ===")
print("Total trial                    :", len(df))
print("Step_count_raw  < 2            :", count_true(df["step_count_raw"] < 2))
print("Step_count_valid < 4           :", count_true(df["step_count_valid"] < 4))
print("Durasi_valid <= 0 (detik)      :", count_true(df["duration_valid_sec"] <= 0))
print("Distance_valid < 0.2 m         :", count_true(df["distance_2d_valid_m"] < 0.2))
print("Speed_valid > 3.5 m/s          :", count_true(df["walking_speed_ms"] > 3.5))
print("Speed_valid 0–0.1 m/s          :", count_true((df["walking_speed_ms"] > 0) & (df["walking_speed_ms"] < 0.1)))
print("Trial dengan is_valid_trial = 0:", count_true(df["is_valid_trial"] == 0))

print("\n=== SANITY CHECK PER SUBJECT (V3) ===")
for subj in df["subject"].unique():
    dsub = df[df["subject"] == subj]
    print(f"\n-- {subj} --")
    print("  Total trial                 :", len(dsub))
    print("  Step_count_raw  < 2         :", count_true(dsub["step_count_raw"] < 2))
    print("  Step_count_valid < 4        :", count_true(dsub["step_count_valid"] < 4))
    print("  Durasi_valid <= 0 (detik)   :", count_true(dsub["duration_valid_sec"] <= 0))
    print("  Distance_valid < 0.2 m      :", count_true(dsub["distance_2d_valid_m"] < 0.2))
    print("  Speed_valid > 3.5 m/s       :", count_true(dsub["walking_speed_ms"] > 3.5))
    print("  is_valid_trial = 0          :", count_true(dsub["is_valid_trial"] == 0))
# Out:
# === SANITY CHECK GLOBAL (V3) ===
# Total trial                    : 216
# Step_count_raw  < 2            : 1
# Step_count_valid < 4           : 20
# Durasi_valid <= 0 (detik)      : 0
# Distance_valid < 0.2 m         : 4
# Speed_valid > 3.5 m/s          : 8
# Speed_valid 0–0.1 m/s          : 15
# Trial dengan is_valid_trial = 0: 61
#
# === SANITY CHECK PER SUBJECT (V3) ===
#
# -- Afi --
#   Total trial                 : 72
#   Step_count_raw  < 2         : 0
#   Step_count_valid < 4        : 10
#   Durasi_valid <= 0 (detik)   : 0
#   Distance_valid < 0.2 m      : 4
#   Speed_valid > 3.5 m/s       : 4
#   is_valid_trial = 0          : 30
#
# -- Kinan --
#   Total trial                 : 72
#   Step_count_raw  < 2         : 0
#   Step_count_valid < 4        : 4
#   Durasi_valid <= 0 (detik)   : 0
#   Distance_valid < 0.2 m      : 0
#   Speed_valid > 3.5 m/s       : 2
#   is_valid_trial = 0          : 16
#
# -- Miftah --
#   Total trial                 : 72
#   Step_count_raw  < 2         : 1
#   Step_count_valid < 4        : 6
#   Durasi_valid <= 0 (detik)   : 0
#   Distance_valid < 0.2 m      : 0
#   Speed_valid > 3.5 m/s       : 2
#   is_valid_trial = 0          : 15
