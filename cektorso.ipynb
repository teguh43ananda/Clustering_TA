# %%
FOLDER_TORSO = r"E:\1.Clustering_TA\5output_clustering\02_torso_per_frame"

# %% [markdown]
# Cek Torso (Centroind)

# %% [markdown]
# AFI

# %%
import os, glob
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# --- 1. List semua file torso untuk Afi ---
pattern_afi = os.path.join(FOLDER_TORSO, "Afi_*_torso.csv")
torso_files_afi = sorted(glob.glob(pattern_afi))

print("Daftar file torso Afi:")
for i, f in enumerate(torso_files_afi):
    print(f"{i}: {os.path.basename(f)}")

# --- 2. PILIH salah satu file Afi yang mau diplot ---
# ganti index di sini kalau mau file lain
idx_afi = -7
afi_torso_csv = torso_files_afi[idx_afi]
print("\nFile yang dipakai:", os.path.basename(afi_torso_csv))

df_afi = pd.read_csv(afi_torso_csv)

# pastikan terurut
df_afi = df_afi.sort_values('frame').reset_index(drop=True)

# --- 3. Plot torso_x vs frame ---
plt.figure(figsize=(8, 3.5))
plt.plot(df_afi['frame'], df_afi['torso_x'], marker='o', linewidth=1)
plt.xlabel("Frame")
plt.ylabel("Torso X (m)")
plt.title(f"Trajectory torso_x vs frame | {os.path.basename(afi_torso_csv)}")
plt.grid(True)
plt.tight_layout()
plt.show()

# --- 4. Plot torso_y vs frame ---
plt.figure(figsize=(8, 3.5))
plt.plot(df_afi['frame'], df_afi['torso_y'], marker='o', linewidth=1)
plt.xlabel("Frame")
plt.ylabel("Torso Y (m)")
plt.title(f"Trajectory torso_y vs frame | {os.path.basename(afi_torso_csv)}")
plt.grid(True)
plt.tight_layout()
plt.show()

# --- 5. Plot torso_z vs frame ---
plt.figure(figsize=(8, 3.5))
plt.plot(df_afi['frame'], df_afi['torso_z'], marker='o', linewidth=1)
plt.xlabel("Frame")
plt.ylabel("Torso Z (m)")
plt.title(f"Trajectory torso_z vs frame | {os.path.basename(afi_torso_csv)}")
plt.grid(True)
plt.tight_layout()
plt.show()

# --- 6. Hitung v_walk_rel (ΔY per frame) ---
df_afi['dy'] = df_afi['torso_y'].diff()
df_afi['v_walk_rel'] = df_afi['dy']   # ΔY per frame (belum dikali fps)

plt.figure(figsize=(8, 3.5))
plt.plot(df_afi['frame'], df_afi['v_walk_rel'], marker='o', linewidth=1)
plt.axhline(0, color='k', linewidth=0.8)
plt.xlabel("Frame")
plt.ylabel("v_walk_rel (ΔY per frame)")
plt.title("Kecepatan relatif berjalan (approx v_walk) per frame - Afi")
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# Daftar file torso Afi:
# 0: Afi_Jalan10_clustered_torso.csv
# 1: Afi_Jalan11_clustered_torso.csv
# 2: Afi_Jalan12_clustered_torso.csv
# 3: Afi_Jalan13_clustered_torso.csv
# 4: Afi_Jalan14_clustered_torso.csv
# 5: Afi_Jalan15_clustered_torso.csv
# 6: Afi_Jalan16_clustered_torso.csv
# 7: Afi_Jalan17_clustered_torso.csv
# 8: Afi_Jalan18_clustered_torso.csv
# 9: Afi_Jalan19_clustered_torso.csv
# 10: Afi_Jalan1_clustered_torso.csv
# 11: Afi_Jalan20_clustered_torso.csv
# 12: Afi_Jalan21_clustered_torso.csv
# 13: Afi_Jalan22_clustered_torso.csv
# 14: Afi_Jalan23_clustered_torso.csv
# 15: Afi_Jalan24_clustered_torso.csv
# 16: Afi_Jalan25_clustered_torso.csv
# 17: Afi_Jalan26_clustered_torso.csv
# 18: Afi_Jalan27_clustered_torso.csv
# 19: Afi_Jalan28_clustered_torso.csv
# 20: Afi_Jalan29_clustered_torso.csv
# 21: Afi_Jalan2_clustered_torso.csv
# 22: Afi_Jalan30_clustered_torso.csv
# 23: Afi_Jalan31_clustered_torso.csv
# 24: Afi_Jalan32_clustered_torso.csv
# ...

# %%
FOLDER_TORSO2 = r"E:\1.Clustering_TA\3output_clustering\02_torso_per_frame"

# %%
import os, glob
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# --- 1. List semua file torso untuk Afi ---
pattern_afi = os.path.join(FOLDER_TORSO2, "Afi_*_torso.csv")
torso_files_afi = sorted(glob.glob(pattern_afi))

print("Daftar file torso Afi:")
for i, f in enumerate(torso_files_afi):
    print(f"{i}: {os.path.basename(f)}")

# --- 2. PILIH salah satu file Afi yang mau diplot ---
# ganti index di sini kalau mau file lain
idx_afi = -7
afi_torso_csv = torso_files_afi[idx_afi]
print("\nFile yang dipakai:", os.path.basename(afi_torso_csv))

df_afi = pd.read_csv(afi_torso_csv)

# pastikan terurut
df_afi = df_afi.sort_values('frame').reset_index(drop=True)

# --- 3. Plot torso_x vs frame ---
plt.figure(figsize=(8, 3.5))
plt.plot(df_afi['frame'], df_afi['torso_x'], marker='o', linewidth=1)
plt.xlabel("Frame")
plt.ylabel("Torso X (m)")
plt.title(f"Trajectory torso_x vs frame | {os.path.basename(afi_torso_csv)}")
plt.grid(True)
plt.tight_layout()
plt.show()

# --- 4. Plot torso_y vs frame ---
plt.figure(figsize=(8, 3.5))
plt.plot(df_afi['frame'], df_afi['torso_y'], marker='o', linewidth=1)
plt.xlabel("Frame")
plt.ylabel("Torso Y (m)")
plt.title(f"Trajectory torso_y vs frame | {os.path.basename(afi_torso_csv)}")
plt.grid(True)
plt.tight_layout()
plt.show()

# --- 5. Plot torso_z vs frame ---
plt.figure(figsize=(8, 3.5))
plt.plot(df_afi['frame'], df_afi['torso_z'], marker='o', linewidth=1)
plt.xlabel("Frame")
plt.ylabel("Torso Z (m)")
plt.title(f"Trajectory torso_z vs frame | {os.path.basename(afi_torso_csv)}")
plt.grid(True)
plt.tight_layout()
plt.show()

# --- 6. Hitung v_walk_rel (ΔY per frame) ---
df_afi['dy'] = df_afi['torso_y'].diff()
df_afi['v_walk_rel'] = df_afi['dy']   # ΔY per frame (belum dikali fps)

plt.figure(figsize=(8, 3.5))
plt.plot(df_afi['frame'], df_afi['v_walk_rel'], marker='o', linewidth=1)
plt.axhline(0, color='k', linewidth=0.8)
plt.xlabel("Frame")
plt.ylabel("v_walk_rel (ΔY per frame)")
plt.title("Kecepatan relatif berjalan (approx v_walk) per frame - Afi")
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# Daftar file torso Afi:
# 0: Afi_Jalan10_clustered_torso.csv
# 1: Afi_Jalan11_clustered_torso.csv
# 2: Afi_Jalan12_clustered_torso.csv
# 3: Afi_Jalan13_clustered_torso.csv
# 4: Afi_Jalan14_clustered_torso.csv
# 5: Afi_Jalan15_clustered_torso.csv
# 6: Afi_Jalan16_clustered_torso.csv
# 7: Afi_Jalan17_clustered_torso.csv
# 8: Afi_Jalan18_clustered_torso.csv
# 9: Afi_Jalan19_clustered_torso.csv
# 10: Afi_Jalan1_clustered_torso.csv
# 11: Afi_Jalan20_clustered_torso.csv
# 12: Afi_Jalan21_clustered_torso.csv
# 13: Afi_Jalan22_clustered_torso.csv
# 14: Afi_Jalan23_clustered_torso.csv
# 15: Afi_Jalan24_clustered_torso.csv
# 16: Afi_Jalan25_clustered_torso.csv
# 17: Afi_Jalan26_clustered_torso.csv
# 18: Afi_Jalan27_clustered_torso.csv
# 19: Afi_Jalan28_clustered_torso.csv
# 20: Afi_Jalan29_clustered_torso.csv
# 21: Afi_Jalan2_clustered_torso.csv
# 22: Afi_Jalan30_clustered_torso.csv
# 23: Afi_Jalan31_clustered_torso.csv
# 24: Afi_Jalan32_clustered_torso.csv
# ...

# %% [markdown]
# KINAN

# %%
import os, glob
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# --- 1. List semua file torso untuk Kinan ---
pattern_kinan = os.path.join(FOLDER_TORSO, "Kinan_*_torso.csv")
torso_files_kinan = sorted(glob.glob(pattern_kinan))

print("Daftar file torso Kinan:")
for i, f in enumerate(torso_files_kinan):
    print(f"{i}: {os.path.basename(f)}")

# --- 2. PILIH salah satu file Kinan ---
idx_kinan = 63   # ganti kalau mau file lain
kinan_torso_csv = torso_files_kinan[idx_kinan]
print("\nFile yang dipakai:", os.path.basename(kinan_torso_csv))

df_kinan = pd.read_csv(kinan_torso_csv)
df_kinan = df_kinan.sort_values('frame').reset_index(drop=True)

# --- 3. Plot torso_X vs frame ---
plt.figure(figsize=(8, 3.5))
plt.plot(df_kinan['frame'], df_kinan['torso_x'], marker='o', linewidth=1)
plt.xlabel("Frame")
plt.ylabel("Torso x (m)")
plt.title(f"Trajectory torso_x vs frame | {os.path.basename(kinan_torso_csv)}")
plt.grid(True)
plt.tight_layout()
plt.show()

# --- 4. Plot torso_y vs frame ---
plt.figure(figsize=(8, 3.5))
plt.plot(df_kinan['frame'], df_kinan['torso_y'], marker='o', linewidth=1)
plt.xlabel("Frame")
plt.ylabel("Torso Y (m)")
plt.title(f"Trajectory torso_y vs frame | {os.path.basename(kinan_torso_csv)}")
plt.grid(True)
plt.tight_layout()
plt.show()

# --- 5. Plot torso_y vs frame ---
plt.figure(figsize=(8, 3.5))
plt.plot(df_kinan['frame'], df_kinan['torso_z'], marker='o', linewidth=1)
plt.xlabel("Frame")
plt.ylabel("Torso Z (m)")
plt.title(f"Trajectory torso_z vs frame | {os.path.basename(kinan_torso_csv)}")
plt.grid(True)
plt.tight_layout()
plt.show()

# --- 6. v_walk_rel (ΔY per frame) ---
df_kinan['dy'] = df_kinan['torso_y'].diff()
df_kinan['v_walk_rel'] = df_kinan['dy']

plt.figure(figsize=(8, 3.5))
plt.plot(df_kinan['frame'], df_kinan['v_walk_rel'], marker='o', linewidth=1)
plt.axhline(0, color='k', linewidth=0.8)
plt.xlabel("Frame")
plt.ylabel("v_walk_rel (ΔY per frame)")
plt.title("Kecepatan relatif berjalan (approx v_walk) per frame - Kinan")
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# MIFTAH

# %%
import os, glob
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# --- 1. List semua file torso untuk Miftah ---
pattern_miftah = os.path.join(FOLDER_TORSO, "Miftah_*_torso.csv")
torso_files_miftah = sorted(glob.glob(pattern_miftah))

print("Daftar file torso Miftah:")
for i, f in enumerate(torso_files_miftah):
    print(f"{i}: {os.path.basename(f)}")

# --- 2. PILIH salah satu file Miftah ---
idx_miftah = 31   # ganti kalau mau file lain
miftah_torso_csv = torso_files_miftah[idx_miftah]
print("\nFile yang dipakai:", os.path.basename(miftah_torso_csv))

df_miftah = pd.read_csv(miftah_torso_csv)
df_miftah = df_miftah.sort_values('frame').reset_index(drop=True)

# --- 3. Plot torso_x vs frame ---
plt.figure(figsize=(8, 3.5))
plt.plot(df_miftah['frame'], df_miftah['torso_x'], marker='o', linewidth=1)
plt.xlabel("Frame")
plt.ylabel("Torso X (m)")
plt.title(f"Trajectory torso_x vs frame | {os.path.basename(miftah_torso_csv)}")
plt.grid(True)
plt.tight_layout()
plt.show()

# --- 4. Plot torso_y vs frame ---
plt.figure(figsize=(8, 3.5))
plt.plot(df_miftah['frame'], df_miftah['torso_y'], marker='o', linewidth=1)
plt.xlabel("Frame")
plt.ylabel("Torso Y (m)")
plt.title(f"Trajectory torso_y vs frame | {os.path.basename(miftah_torso_csv)}")
plt.grid(True)
plt.tight_layout()
plt.show()

# --- 5. Plot torso_z vs frame ---
plt.figure(figsize=(8, 3.5))
plt.plot(df_miftah['frame'], df_miftah['torso_z'], marker='o', linewidth=1)
plt.xlabel("Frame")
plt.ylabel("Torso Z (m)")
plt.title(f"Trajectory torso_z vs frame | {os.path.basename(miftah_torso_csv)}")
plt.grid(True)
plt.tight_layout()
plt.show()

# --- 6. v_walk_rel (ΔY per frame) ---
df_miftah['dy'] = df_miftah['torso_y'].diff()
df_miftah['v_walk_rel'] = df_miftah['dy']

plt.figure(figsize=(8, 3.5))
plt.plot(df_miftah['frame'], df_miftah['v_walk_rel'], marker='o', linewidth=1)
plt.axhline(0, color='k', linewidth=0.8)
plt.xlabel("Frame")
plt.ylabel("v_walk_rel (ΔY per frame)")
plt.title("Kecepatan relatif berjalan (approx v_walk) per frame - Miftah")
plt.grid(True)
plt.tight_layout()
plt.show()
