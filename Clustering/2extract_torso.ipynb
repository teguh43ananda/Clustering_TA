# %% [markdown]
# 🧩 Cell A – Konfigurasi ekstra untuk torso temporal

# %%
# Cell A: Konfigurasi tambahan untuk torso versi TEMPORAL
# Cell 1: Import library & konfigurasi dasar

import os
import glob
import numpy as np
import pandas as pd

# Daftar subjek
SUBJECTS = ["Afi", "Tsamara", "Tsania"]

# Folder input: hasil clustering (DBSCAN)
CLUSTER_BASE_DIR = r"E:\1.Clustering_TA\dataset2\hasil_clustering"

# Folder output baru untuk torso versi temporal
TORSO_TEMP_BASE_DIR = r"E:\0.TA_Teguh\dataset2\hasil_torso_temporal"

# Hyperparameter sederhana untuk skor
W_SIZE      = 0.7   # bobot ukuran cluster
W_DIST      = 0.3   # bobot kedekatan posisi
DIST_NORM   = 1.0   # normalisasi jarak (meter), asumsi perpindahan torso per frame < 1 m

# Reset kalau gap frame terlalu panjang (misal > 5 frame)
GAP_RESET_FRAMES = 2
print("SUBJECTS        :", SUBJECTS)
print("CLUSTER_BASE_DIR:", CLUSTER_BASE_DIR)

print("TORSO_TEMP_BASE_DIR:", TORSO_TEMP_BASE_DIR)
print("W_SIZE, W_DIST, DIST_NORM, GAP_RESET_FRAMES =", W_SIZE, W_DIST, DIST_NORM, GAP_RESET_FRAMES)
# Out:
# SUBJECTS        : ['Afi', 'Tsamara', 'Tsania']
# CLUSTER_BASE_DIR: E:\1.Clustering_TA\dataset2\hasil_clustering
# TORSO_TEMP_BASE_DIR: E:\0.TA_Teguh\dataset2\hasil_torso_temporal
# W_SIZE, W_DIST, DIST_NORM, GAP_RESET_FRAMES = 0.7 0.3 1.0 2

# %%
# Cell 1b: Kolom yang wajib ada di file clustering
REQUIRED_COLUMNS = [
    "timestamp",
    "frame",
    "x",
    "y",
    "z",
    "doppler",
    "SNR",
    "cluster_id",
]
print("REQUIRED_COLUMNS:", REQUIRED_COLUMNS)
# Out:
# REQUIRED_COLUMNS: ['timestamp', 'frame', 'x', 'y', 'z', 'doppler', 'SNR', 'cluster_id']

# %%
# Cell 1c: Helper untuk listing file clustering per subjek

def list_cluster_files_for_subject(subject_name: str):
    """
    Mengembalikan daftar file clustering untuk 1 subjek, mis:
      E:\\1.Clustering_TA\\dataset2\\hasil_clustering\\Afi\\clustering_Jalan1.csv
      ...
    """
    subj_dir = os.path.join(CLUSTER_BASE_DIR, subject_name)
    pattern = os.path.join(subj_dir, "clustering_*.csv")
    files = sorted(glob.glob(pattern))
    # (opsional) print ringkas
    print(f"[INFO] {subject_name}: ditemukan {len(files)} file clustering")
    return files

# %% [markdown]
# 🧩 Cell B – Helper: path output torso temporal

# %%
# Cell B: Path output untuk torso versi temporal

def build_output_torso_temp_path(subject_name: str, cluster_file_path: str) -> str:
    """
    Dari:
        E:\1.Clustering_TA\dataset2\hasil_clustering\Afi\clustering_Jalan1.csv
    Menjadi:
        E:\0.TA_Teguh\dataset2\hasil_torso_temporal\Afi\torsoT_Jalan1.csv
    """
    fname = os.path.basename(cluster_file_path)  # "clustering_Jalan1.csv"
    if fname.startswith("clustering_"):
        torso_fname = "torsoT_" + fname[len("clustering_"):]
    else:
        torso_fname = "torsoT_" + fname

    subj_out_dir = os.path.join(TORSO_TEMP_BASE_DIR, subject_name)
    os.makedirs(subj_out_dir, exist_ok=True)

    return os.path.join(subj_out_dir, torso_fname)

# Cek contoh
for subj in SUBJECTS:
    files = list_cluster_files_for_subject(subj)
    if files:
        print(subj, "->", build_output_torso_temp_path(subj, files[0]))
# Out:
# [INFO] Afi: ditemukan 72 file clustering
# Afi -> E:\0.TA_Teguh\dataset2\hasil_torso_temporal\Afi\torsoT_Jalan1.csv
# [INFO] Tsamara: ditemukan 72 file clustering
# Tsamara -> E:\0.TA_Teguh\dataset2\hasil_torso_temporal\Tsamara\torsoT_Jalan1.csv
# [INFO] Tsania: ditemukan 72 file clustering
# Tsania -> E:\0.TA_Teguh\dataset2\hasil_torso_temporal\Tsania\torsoT_Jalan1.csv

# %% [markdown]
# 🧩 Cell C – Ekstraksi torso versi temporal

# %%
# Cell C: Ekstraksi torso versi TEMPORAL (size + distance)

def extract_torso_temporal_for_file(cluster_file_path: str, torso_temp_file_path: str):
    """
    Versi torso extraction dengan MEMPERTIMBANGKAN TEMPORAL CONSISTENCY:
      - Buang noise (cluster_id == -1)
      - Kalau belum ada torso_prev -> pilih cluster terbesar
      - Kalau sudah ada torso_prev & gap frame kecil:
            skor = kombinasi ukuran cluster + kedekatan ke centroid_prev
            pilih cluster dengan skor tertinggi
      - Kalau gap frame terlalu besar (>= GAP_RESET_FRAMES):
            reset: pilih cluster terbesar lagi

    Output:
      - CSV torso-only seperti input (semua titik cluster torso),
      - summary per file.
    """
    print(f"\n=== [TEMPORAL] Proses file clustering: {cluster_file_path}")
    df = pd.read_csv(cluster_file_path)

    missing = [c for c in REQUIRED_COLUMNS if c not in df.columns]
    if missing:
        raise ValueError(f"File {cluster_file_path} tidak memiliki kolom: {missing}")

    # Frame unik dan urutan
    unique_frames = sorted(df["frame"].unique())
    n_frames_total = len(unique_frames)
    print(f"  Total frame unik dalam file ini: {n_frames_total}")

    torso_rows = []

    # State temporal
    prev_centroid = None    # np.array([x, y, z])
    prev_frame_id = None

    for frame_id in unique_frames:
        df_frame = df[df["frame"] == frame_id]

        # Filter non-noise
        df_valid = df_frame[df_frame["cluster_id"] != -1]
        if df_valid.empty:
            # tidak ada cluster valid di frame ini
            continue

        # Hitung jumlah titik per cluster
        counts = df_valid["cluster_id"].value_counts()
        cluster_ids = counts.index.tolist()

        # Hitung centroid tiap cluster
        centroids = {}
        for cid in cluster_ids:
            sub = df_valid[df_valid["cluster_id"] == cid]
            cx = sub["x"].mean()
            cy = sub["y"].mean()
            cz = sub["z"].mean()
            centroids[cid] = np.array([cx, cy, cz], dtype=float)

        # Kalau belum ada prev_centroid atau gap terlalu besar -> reset (pilih cluster terbesar)
        use_simple = (prev_centroid is None)
        if (prev_frame_id is not None) and (frame_id - prev_frame_id >= GAP_RESET_FRAMES):
            use_simple = True

        if use_simple:
            # Reset / frame pertama: pakai cluster terbesar
            torso_cluster_id = counts.idxmax()
        else:
            # Pakai scoring: ukuran + jarak ke prev_centroid
            max_points_in_frame = counts.max()
            best_score = -1e9
            best_cid = None

            for cid in cluster_ids:
                n_points = counts.loc[cid]
                centroid = centroids[cid]

                # ukuran dinormalisasi
                size_norm = n_points / max_points_in_frame

                # jarak ke prev_centroid
                dist = np.linalg.norm(centroid - prev_centroid)
                dist_norm = min(dist / DIST_NORM, 1.0)  # clamp (0..1)

                # skor gabungan
                score = W_SIZE * size_norm - W_DIST * dist_norm

                if score > best_score:
                    best_score = score
                    best_cid = cid

            torso_cluster_id = best_cid

        # Ambil titik-titik torso cluster ini
        df_torso_frame = df_valid[df_valid["cluster_id"] == torso_cluster_id].copy()
        torso_rows.append(df_torso_frame)

        # Update state temporal
        prev_centroid = centroids[torso_cluster_id]
        prev_frame_id = frame_id

    # Gabung semua frame torso
    if torso_rows:
        df_torso_all = pd.concat(torso_rows, ignore_index=True)
    else:
        df_torso_all = pd.DataFrame(columns=df.columns)

    # Summary
    if df_torso_all.empty:
        print("  PERINGATAN: [TEMPORAL] Tidak ada frame dengan torso.")
        n_frames_with_torso = 0
        avg_points_per_torso_frame = 0.0
    else:
        frames_with_torso = df_torso_all["frame"].unique()
        n_frames_with_torso = len(frames_with_torso)
        n_frames_no_torso = n_frames_total - n_frames_with_torso
        avg_points_per_torso_frame = len(df_torso_all) / max(n_frames_with_torso, 1)

        print(f"  Frame dengan torso   : {n_frames_with_torso}")
        print(f"  Frame tanpa torso    : {n_frames_no_torso}")
        print(f"  Rata-rata titik torso/frame: {avg_points_per_torso_frame:.2f}")

    # Simpan
    os.makedirs(os.path.dirname(torso_temp_file_path), exist_ok=True)
    df_torso_all.to_csv(torso_temp_file_path, index=False)
    print(f"  >> [TEMPORAL] Disimpan ke: {torso_temp_file_path}")

    return {
        "file": cluster_file_path,
        "torso_file": torso_temp_file_path,
        "n_frames_total": n_frames_total,
        "n_frames_with_torso": int(n_frames_with_torso),
        "avg_points_per_torso_frame": float(avg_points_per_torso_frame),
    }

# %% [markdown]
# 🧩 Cell D – Jalankan torso temporal untuk semua subjek & summary

# %%
# Cell D: Jalankan torso extraction versi TEMPORAL untuk semua subjek

def run_torso_temporal_for_all_subjects():
    summaries = []

    for subj in SUBJECTS:
        print("\n" + "=" * 70)
        print(f"[TEMPORAL] Subjek: {subj}")
        print("=" * 70)

        cluster_files = list_cluster_files_for_subject(subj)
        if not cluster_files:
            print(f"  Tidak ada file clustering untuk subjek {subj}")
            continue

        for cluster_path in cluster_files:
            torso_temp_path = build_output_torso_temp_path(subj, cluster_path)
            summary = extract_torso_temporal_for_file(cluster_path, torso_temp_path)
            summary["subject"] = subj
            summaries.append(summary)

    if summaries:
        df_summary_temp = pd.DataFrame(summaries)
    else:
        df_summary_temp = pd.DataFrame(
            columns=["subject", "file", "torso_file",
                     "n_frames_total", "n_frames_with_torso",
                     "avg_points_per_torso_frame"]
        )

    return df_summary_temp


# Jalankan
df_torso_temp_summary = run_torso_temporal_for_all_subjects()

print("\n=== [TEMPORAL] Ringkasan global torso extraction (head) ===")
display(df_torso_temp_summary.head())
# Out:
# ======================================================================
# [TEMPORAL] Subjek: Afi
# ======================================================================
# [INFO] Afi: ditemukan 72 file clustering
#
# === [TEMPORAL] Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Afi\clustering_Jalan1.csv
#   Total frame unik dalam file ini: 99
#   Frame dengan torso   : 91
#   Frame tanpa torso    : 8
#   Rata-rata titik torso/frame: 20.45
#   >> [TEMPORAL] Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso_temporal\Afi\torsoT_Jalan1.csv
#
# === [TEMPORAL] Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Afi\clustering_Jalan10.csv
#   Total frame unik dalam file ini: 94
#   Frame dengan torso   : 89
#   Frame tanpa torso    : 5
#   Rata-rata titik torso/frame: 23.76
#   >> [TEMPORAL] Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso_temporal\Afi\torsoT_Jalan10.csv
#
# === [TEMPORAL] Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Afi\clustering_Jalan11.csv
#   Total frame unik dalam file ini: 96
#   Frame dengan torso   : 90
#   Frame tanpa torso    : 6
#   Rata-rata titik torso/frame: 19.86
#   >> [TEMPORAL] Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso_temporal\Afi\torsoT_Jalan11.csv
#
# === [TEMPORAL] Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Afi\clustering_Jalan12.csv
#   Total frame unik dalam file ini: 77
#   Frame dengan torso   : 71
#   Frame tanpa torso    : 6
#   Rata-rata titik torso/frame: 29.83
#   >> [TEMPORAL] Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso_temporal\Afi\torsoT_Jalan12.csv
#
# === [TEMPORAL] Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Afi\clustering_Jalan13.csv
#   Total frame unik dalam file ini: 99
#   Frame dengan torso   : 92
#   Frame tanpa torso    : 7
#   Rata-rata titik torso/frame: 24.53
#   >> [TEMPORAL] Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso_temporal\Afi\torsoT_Jalan13.csv
#
# === [TEMPORAL] Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Afi\clustering_Jalan14.csv
#   Total frame unik dalam file ini: 92
#   Frame dengan torso   : 84
#   Frame tanpa torso    : 8
#   Rata-rata titik torso/frame: 25.56
#   >> [TEMPORAL] Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso_temporal\Afi\torsoT_Jalan14.csv
#
# === [TEMPORAL] Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Afi\clustering_Jalan15.csv
#   Total frame unik dalam file ini: 219
#   Frame dengan torso   : 198
#   Frame tanpa torso    : 21
#   Rata-rata titik torso/frame: 27.43
#   >> [TEMPORAL] Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso_temporal\Afi\torsoT_Jalan15.csv
#
# === [TEMPORAL] Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Afi\clustering_Jalan16.csv
#   Total frame unik dalam file ini: 214
#   Frame dengan torso   : 191
#   Frame tanpa torso    : 23
#   Rata-rata titik torso/frame: 34.58
#   >> [TEMPORAL] Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso_temporal\Afi\torsoT_Jalan16.csv
#
# === [TEMPORAL] Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Afi\clustering_Jalan17.csv
#   Total frame unik dalam file ini: 170
#   Frame dengan torso   : 158
#   Frame tanpa torso    : 12
#   Rata-rata titik torso/frame: 36.06
#   >> [TEMPORAL] Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso_temporal\Afi\torsoT_Jalan17.csv
#
# === [TEMPORAL] Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Afi\clustering_Jalan18.csv
#   Total frame unik dalam file ini: 146
#   Frame dengan torso   : 133
#   Frame tanpa torso    : 13
#   Rata-rata titik torso/frame: 42.04
#   >> [TEMPORAL] Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso_temporal\Afi\torsoT_Jalan18.csv
#
# === [TEMPORAL] Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Afi\clustering_Jalan19.csv
#   Total frame unik dalam file ini: 192
#   Frame dengan torso   : 173
#   Frame tanpa torso    : 19
#   Rata-rata titik torso/frame: 28.02
#   >> [TEMPORAL] Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso_temporal\Afi\torsoT_Jalan19.csv
#
# === [TEMPORAL] Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Afi\clustering_Jalan2.csv
#   Total frame unik dalam file ini: 84
#   Frame dengan torso   : 76
#   Frame tanpa torso    : 8
#   Rata-rata titik torso/frame: 36.67
#   >> [TEMPORAL] Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso_temporal\Afi\torsoT_Jalan2.csv
#
# === [TEMPORAL] Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Afi\clustering_Jalan20.csv
#   Total frame unik dalam file ini: 175
#   Frame dengan torso   : 157
#   Frame tanpa torso    : 18
#   Rata-rata titik torso/frame: 31.40
#   >> [TEMPORAL] Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso_temporal\Afi\torsoT_Jalan20.csv
#
# === [TEMPORAL] Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Afi\clustering_Jalan21.csv
#   Total frame unik dalam file ini: 141
#   Frame dengan torso   : 128
#   Frame tanpa torso    : 13
#   Rata-rata titik torso/frame: 38.46
#   >> [TEMPORAL] Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso_temporal\Afi\torsoT_Jalan21.csv
#
# === [TEMPORAL] Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Afi\clustering_Jalan22.csv
#   Total frame unik dalam file ini: 101
#   Frame dengan torso   : 87
#   Frame tanpa torso    : 14
#   Rata-rata titik torso/frame: 40.26
#   >> [TEMPORAL] Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso_temporal\Afi\torsoT_Jalan22.csv
#
# === [TEMPORAL] Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Afi\clustering_Jalan23.csv
#   Total frame unik dalam file ini: 364
#   Frame dengan torso   : 331
#   Frame tanpa torso    : 33
#   Rata-rata titik torso/frame: 22.91
#   >> [TEMPORAL] Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso_temporal\Afi\torsoT_Jalan23.csv
#
# === [TEMPORAL] Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Afi\clustering_Jalan24.csv
#   Total frame unik dalam file ini: 333
#   Frame dengan torso   : 296
#   Frame tanpa torso    : 37
#   Rata-rata titik torso/frame: 30.26
#   >> [TEMPORAL] Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso_temporal\Afi\torsoT_Jalan24.csv
#
# === [TEMPORAL] Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Afi\clustering_Jalan25.csv
#   Total frame unik dalam file ini: 67
#   Frame dengan torso   : 63
#   Frame tanpa torso    : 4
#   Rata-rata titik torso/frame: 20.24
#   >> [TEMPORAL] Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso_temporal\Afi\torsoT_Jalan25.csv
#
# === [TEMPORAL] Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Afi\clustering_Jalan26.csv
#   Total frame unik dalam file ini: 75
#   Frame dengan torso   : 61
#   Frame tanpa torso    : 14
#   Rata-rata titik torso/frame: 28.30
#   >> [TEMPORAL] Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso_temporal\Afi\torsoT_Jalan26.csv
#
# === [TEMPORAL] Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Afi\clustering_Jalan27.csv
#   Total frame unik dalam file ini: 77
#   Frame dengan torso   : 67
#   Frame tanpa torso    : 10
#   Rata-rata titik torso/frame: 18.54
#   >> [TEMPORAL] Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso_temporal\Afi\torsoT_Jalan27.csv
#
# === [TEMPORAL] Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Afi\clustering_Jalan28.csv
#   Total frame unik dalam file ini: 65
#   Frame dengan torso   : 58
#   Frame tanpa torso    : 7
#   Rata-rata titik torso/frame: 16.72
#   >> [TEMPORAL] Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso_temporal\Afi\torsoT_Jalan28.csv
#
# === [TEMPORAL] Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Afi\clustering_Jalan29.csv
#   Total frame unik dalam file ini: 76
#   Frame dengan torso   : 69
#   Frame tanpa torso    : 7
#   Rata-rata titik torso/frame: 16.20
#   >> [TEMPORAL] Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso_temporal\Afi\torsoT_Jalan29.csv
#
# === [TEMPORAL] Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Afi\clustering_Jalan3.csv
#   Total frame unik dalam file ini: 86
#   Frame dengan torso   : 77
#   Frame tanpa torso    : 9
#   Rata-rata titik torso/frame: 23.43
#   >> [TEMPORAL] Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso_temporal\Afi\torsoT_Jalan3.csv
#
# === [TEMPORAL] Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Afi\clustering_Jalan30.csv
#   Total frame unik dalam file ini: 80
#   Frame dengan torso   : 65
#   Frame tanpa torso    : 15
#   Rata-rata titik torso/frame: 18.43
#   >> [TEMPORAL] Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso_temporal\Afi\torsoT_Jalan30.csv
#
# === [TEMPORAL] Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Afi\clustering_Jalan31.csv
#   Total frame unik dalam file ini: 69
#   Frame dengan torso   : 61
#   Frame tanpa torso    : 8
#   Rata-rata titik torso/frame: 26.11
#   >> [TEMPORAL] Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso_temporal\Afi\torsoT_Jalan31.csv
#
# === [TEMPORAL] Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Afi\clustering_Jalan32.csv
#   Total frame unik dalam file ini: 77
#   Frame dengan torso   : 72
#   Frame tanpa torso    : 5
#   Rata-rata titik torso/frame: 52.71
#   >> [TEMPORAL] Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso_temporal\Afi\torsoT_Jalan32.csv
#
# === [TEMPORAL] Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Afi\clustering_Jalan33.csv
#   Total frame unik dalam file ini: 76
#   Frame dengan torso   : 73
#   Frame tanpa torso    : 3
#   Rata-rata titik torso/frame: 27.63
#   >> [TEMPORAL] Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso_temporal\Afi\torsoT_Jalan33.csv
#
# === [TEMPORAL] Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Afi\clustering_Jalan34.csv
#   Total frame unik dalam file ini: 87
#   Frame dengan torso   : 84
#   Frame tanpa torso    : 3
#   Rata-rata titik torso/frame: 22.35
#   >> [TEMPORAL] Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso_temporal\Afi\torsoT_Jalan34.csv
#
# === [TEMPORAL] Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Afi\clustering_Jalan35.csv
#   Total frame unik dalam file ini: 88
#   Frame dengan torso   : 85
#   Frame tanpa torso    : 3
#   Rata-rata titik torso/frame: 20.49
#   >> [TEMPORAL] Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso_temporal\Afi\torsoT_Jalan35.csv
#
# === [TEMPORAL] Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Afi\clustering_Jalan36.csv
#   Total frame unik dalam file ini: 68
#   Frame dengan torso   : 59
#   Frame tanpa torso    : 9
#   Rata-rata titik torso/frame: 21.98
#   >> [TEMPORAL] Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso_temporal\Afi\torsoT_Jalan36.csv
#
# === [TEMPORAL] Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Afi\clustering_Jalan37.csv
#   Total frame unik dalam file ini: 83
#   Frame dengan torso   : 76
#   Frame tanpa torso    : 7
#   Rata-rata titik torso/frame: 27.18
#   >> [TEMPORAL] Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso_temporal\Afi\torsoT_Jalan37.csv
#
# === [TEMPORAL] Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Afi\clustering_Jalan38.csv
#   Total frame unik dalam file ini: 81
#   Frame dengan torso   : 71
#   Frame tanpa torso    : 10
#   Rata-rata titik torso/frame: 23.69
#   >> [TEMPORAL] Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso_temporal\Afi\torsoT_Jalan38.csv
#
# === [TEMPORAL] Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Afi\clustering_Jalan39.csv
#   Total frame unik dalam file ini: 191
#   Frame dengan torso   : 174
#   Frame tanpa torso    : 17
#   Rata-rata titik torso/frame: 27.72
#   >> [TEMPORAL] Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso_temporal\Afi\torsoT_Jalan39.csv
#
# === [TEMPORAL] Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Afi\clustering_Jalan4.csv
#   Total frame unik dalam file ini: 89
#   Frame dengan torso   : 84
#   Frame tanpa torso    : 5
#   Rata-rata titik torso/frame: 15.73
#   >> [TEMPORAL] Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso_temporal\Afi\torsoT_Jalan4.csv
#
# === [TEMPORAL] Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Afi\clustering_Jalan40.csv
#   Total frame unik dalam file ini: 157
#   Frame dengan torso   : 143
#   Frame tanpa torso    : 14
#   Rata-rata titik torso/frame: 32.06
#   >> [TEMPORAL] Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso_temporal\Afi\torsoT_Jalan40.csv
#
# === [TEMPORAL] Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Afi\clustering_Jalan41.csv
#   Total frame unik dalam file ini: 119
#   Frame dengan torso   : 106
#   Frame tanpa torso    : 13
#   Rata-rata titik torso/frame: 42.57
#   >> [TEMPORAL] Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso_temporal\Afi\torsoT_Jalan41.csv
#
# === [TEMPORAL] Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Afi\clustering_Jalan42.csv
#   Total frame unik dalam file ini: 107
#   Frame dengan torso   : 98
#   Frame tanpa torso    : 9
#   Rata-rata titik torso/frame: 35.70
#   >> [TEMPORAL] Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso_temporal\Afi\torsoT_Jalan42.csv
#
# === [TEMPORAL] Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Afi\clustering_Jalan43.csv
#   Total frame unik dalam file ini: 165
#   Frame dengan torso   : 145
#   Frame tanpa torso    : 20
#   Rata-rata titik torso/frame: 26.01
#   >> [TEMPORAL] Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso_temporal\Afi\torsoT_Jalan43.csv
#
# === [TEMPORAL] Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Afi\clustering_Jalan44.csv
#   Total frame unik dalam file ini: 135
#   Frame dengan torso   : 125
#   Frame tanpa torso    : 10
#   Rata-rata titik torso/frame: 28.58
#   >> [TEMPORAL] Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso_temporal\Afi\torsoT_Jalan44.csv
#
# === [TEMPORAL] Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Afi\clustering_Jalan45.csv
#   Total frame unik dalam file ini: 120
#   Frame dengan torso   : 112
#   Frame tanpa torso    : 8
#   Rata-rata titik torso/frame: 37.38
#   >> [TEMPORAL] Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso_temporal\Afi\torsoT_Jalan45.csv
#
# === [TEMPORAL] Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Afi\clustering_Jalan46.csv
#   Total frame unik dalam file ini: 77
#   Frame dengan torso   : 70
#   Frame tanpa torso    : 7
#   Rata-rata titik torso/frame: 43.99
#   >> [TEMPORAL] Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso_temporal\Afi\torsoT_Jalan46.csv
#
# === [TEMPORAL] Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Afi\clustering_Jalan47.csv
#   Total frame unik dalam file ini: 290
#   Frame dengan torso   : 263
#   Frame tanpa torso    : 27
#   Rata-rata titik torso/frame: 24.63
#   >> [TEMPORAL] Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso_temporal\Afi\torsoT_Jalan47.csv
#
# === [TEMPORAL] Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Afi\clustering_Jalan48.csv
#   Total frame unik dalam file ini: 274
#   Frame dengan torso   : 241
#   Frame tanpa torso    : 33
#   Rata-rata titik torso/frame: 31.79
#   >> [TEMPORAL] Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso_temporal\Afi\torsoT_Jalan48.csv
#
# === [TEMPORAL] Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Afi\clustering_Jalan49.csv
#   Total frame unik dalam file ini: 92
#   Frame dengan torso   : 88
#   Frame tanpa torso    : 4
#   Rata-rata titik torso/frame: 18.48
#   >> [TEMPORAL] Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso_temporal\Afi\torsoT_Jalan49.csv
#
# === [TEMPORAL] Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Afi\clustering_Jalan5.csv
#   Total frame unik dalam file ini: 87
#   Frame dengan torso   : 82
#   Frame tanpa torso    : 5
#   Rata-rata titik torso/frame: 16.16
#   >> [TEMPORAL] Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso_temporal\Afi\torsoT_Jalan5.csv
#
# === [TEMPORAL] Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Afi\clustering_Jalan50.csv
#   Total frame unik dalam file ini: 89
#   Frame dengan torso   : 76
#   Frame tanpa torso    : 13
#   Rata-rata titik torso/frame: 31.34
#   >> [TEMPORAL] Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso_temporal\Afi\torsoT_Jalan50.csv
#
# === [TEMPORAL] Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Afi\clustering_Jalan51.csv
#   Total frame unik dalam file ini: 88
#   Frame dengan torso   : 79
#   Frame tanpa torso    : 9
#   Rata-rata titik torso/frame: 18.41
#   >> [TEMPORAL] Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso_temporal\Afi\torsoT_Jalan51.csv
#
# === [TEMPORAL] Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Afi\clustering_Jalan52.csv
#   Total frame unik dalam file ini: 91
#   Frame dengan torso   : 87
#   Frame tanpa torso    : 4
#   Rata-rata titik torso/frame: 13.86
#   >> [TEMPORAL] Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso_temporal\Afi\torsoT_Jalan52.csv
#
# === [TEMPORAL] Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Afi\clustering_Jalan53.csv
#   Total frame unik dalam file ini: 102
#   Frame dengan torso   : 94
#   Frame tanpa torso    : 8
#   Rata-rata titik torso/frame: 13.37
#   >> [TEMPORAL] Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso_temporal\Afi\torsoT_Jalan53.csv
#
# === [TEMPORAL] Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Afi\clustering_Jalan54.csv
#   Total frame unik dalam file ini: 90
#   Frame dengan torso   : 84
#   Frame tanpa torso    : 6
#   Rata-rata titik torso/frame: 18.06
#   >> [TEMPORAL] Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso_temporal\Afi\torsoT_Jalan54.csv
#
# === [TEMPORAL] Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Afi\clustering_Jalan55.csv
#   Total frame unik dalam file ini: 101
#   Frame dengan torso   : 92
#   Frame tanpa torso    : 9
#   Rata-rata titik torso/frame: 25.99
#   >> [TEMPORAL] Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso_temporal\Afi\torsoT_Jalan55.csv
#
# === [TEMPORAL] Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Afi\clustering_Jalan56.csv
#   Total frame unik dalam file ini: 115
#   Frame dengan torso   : 104
#   Frame tanpa torso    : 11
#   Rata-rata titik torso/frame: 26.25
#   >> [TEMPORAL] Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso_temporal\Afi\torsoT_Jalan56.csv
#
# === [TEMPORAL] Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Afi\clustering_Jalan57.csv
#   Total frame unik dalam file ini: 115
#   Frame dengan torso   : 99
#   Frame tanpa torso    : 16
#   Rata-rata titik torso/frame: 24.90
#   >> [TEMPORAL] Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso_temporal\Afi\torsoT_Jalan57.csv
#
# === [TEMPORAL] Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Afi\clustering_Jalan58.csv
#   Total frame unik dalam file ini: 121
#   Frame dengan torso   : 114
#   Frame tanpa torso    : 7
#   Rata-rata titik torso/frame: 25.61
#   >> [TEMPORAL] Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso_temporal\Afi\torsoT_Jalan58.csv
#
# === [TEMPORAL] Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Afi\clustering_Jalan59.csv
#   Total frame unik dalam file ini: 120
#   Frame dengan torso   : 83
#   Frame tanpa torso    : 37
#   Rata-rata titik torso/frame: 25.27
#   >> [TEMPORAL] Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso_temporal\Afi\torsoT_Jalan59.csv
#
# === [TEMPORAL] Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Afi\clustering_Jalan6.csv
#   Total frame unik dalam file ini: 101
#   Frame dengan torso   : 90
#   Frame tanpa torso    : 11
#   Rata-rata titik torso/frame: 21.87
#   >> [TEMPORAL] Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso_temporal\Afi\torsoT_Jalan6.csv
#
# === [TEMPORAL] Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Afi\clustering_Jalan60.csv
#   Total frame unik dalam file ini: 108
#   Frame dengan torso   : 101
#   Frame tanpa torso    : 7
#   Rata-rata titik torso/frame: 22.70
#   >> [TEMPORAL] Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso_temporal\Afi\torsoT_Jalan60.csv
#
# === [TEMPORAL] Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Afi\clustering_Jalan61.csv
#   Total frame unik dalam file ini: 136
#   Frame dengan torso   : 126
#   Frame tanpa torso    : 10
#   Rata-rata titik torso/frame: 28.40
#   >> [TEMPORAL] Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso_temporal\Afi\torsoT_Jalan61.csv
#
# === [TEMPORAL] Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Afi\clustering_Jalan62.csv
#   Total frame unik dalam file ini: 97
#   Frame dengan torso   : 84
#   Frame tanpa torso    : 13
#   Rata-rata titik torso/frame: 36.05
#   >> [TEMPORAL] Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso_temporal\Afi\torsoT_Jalan62.csv
#
# === [TEMPORAL] Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Afi\clustering_Jalan63.csv
#   Total frame unik dalam file ini: 209
#   Frame dengan torso   : 188
#   Frame tanpa torso    : 21
#   Rata-rata titik torso/frame: 29.12
#   >> [TEMPORAL] Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso_temporal\Afi\torsoT_Jalan63.csv
#
# === [TEMPORAL] Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Afi\clustering_Jalan64.csv
#   Total frame unik dalam file ini: 155
#   Frame dengan torso   : 137
#   Frame tanpa torso    : 18
#   Rata-rata titik torso/frame: 36.09
#   >> [TEMPORAL] Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso_temporal\Afi\torsoT_Jalan64.csv
#
# === [TEMPORAL] Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Afi\clustering_Jalan65.csv
#   Total frame unik dalam file ini: 146
#   Frame dengan torso   : 126
#   Frame tanpa torso    : 20
#   Rata-rata titik torso/frame: 37.99
#   >> [TEMPORAL] Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso_temporal\Afi\torsoT_Jalan65.csv
#
# === [TEMPORAL] Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Afi\clustering_Jalan66.csv
#   Total frame unik dalam file ini: 139
#   Frame dengan torso   : 125
#   Frame tanpa torso    : 14
#   Rata-rata titik torso/frame: 41.28
#   >> [TEMPORAL] Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso_temporal\Afi\torsoT_Jalan66.csv
#
# === [TEMPORAL] Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Afi\clustering_Jalan67.csv
#   Total frame unik dalam file ini: 193
#   Frame dengan torso   : 167
#   Frame tanpa torso    : 26
#   Rata-rata titik torso/frame: 28.75
#   >> [TEMPORAL] Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso_temporal\Afi\torsoT_Jalan67.csv
#
# === [TEMPORAL] Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Afi\clustering_Jalan68.csv
#   Total frame unik dalam file ini: 160
#   Frame dengan torso   : 143
#   Frame tanpa torso    : 17
#   Rata-rata titik torso/frame: 31.46
#   >> [TEMPORAL] Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso_temporal\Afi\torsoT_Jalan68.csv
#
# === [TEMPORAL] Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Afi\clustering_Jalan69.csv
#   Total frame unik dalam file ini: 131
#   Frame dengan torso   : 116
#   Frame tanpa torso    : 15
#   Rata-rata titik torso/frame: 43.49
#   >> [TEMPORAL] Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso_temporal\Afi\torsoT_Jalan69.csv
#
# === [TEMPORAL] Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Afi\clustering_Jalan7.csv
#   Total frame unik dalam file ini: 95
#   Frame dengan torso   : 90
#   Frame tanpa torso    : 5
#   Rata-rata titik torso/frame: 27.50
#   >> [TEMPORAL] Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso_temporal\Afi\torsoT_Jalan7.csv
#
# === [TEMPORAL] Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Afi\clustering_Jalan70.csv
#   Total frame unik dalam file ini: 111
#   Frame dengan torso   : 105
#   Frame tanpa torso    : 6
#   Rata-rata titik torso/frame: 41.68
#   >> [TEMPORAL] Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso_temporal\Afi\torsoT_Jalan70.csv
#
# === [TEMPORAL] Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Afi\clustering_Jalan71.csv
#   Total frame unik dalam file ini: 354
#   Frame dengan torso   : 325
#   Frame tanpa torso    : 29
#   Rata-rata titik torso/frame: 22.95
#   >> [TEMPORAL] Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso_temporal\Afi\torsoT_Jalan71.csv
#
# === [TEMPORAL] Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Afi\clustering_Jalan72.csv
#   Total frame unik dalam file ini: 308
#   Frame dengan torso   : 284
#   Frame tanpa torso    : 24
#   Rata-rata titik torso/frame: 32.24
#   >> [TEMPORAL] Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso_temporal\Afi\torsoT_Jalan72.csv
#
# === [TEMPORAL] Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Afi\clustering_Jalan8.csv
#   Total frame unik dalam file ini: 126
#   Frame dengan torso   : 110
#   Frame tanpa torso    : 16
#   Rata-rata titik torso/frame: 21.17
#   >> [TEMPORAL] Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso_temporal\Afi\torsoT_Jalan8.csv
#
# === [TEMPORAL] Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Afi\clustering_Jalan9.csv
#   Total frame unik dalam file ini: 98
#   Frame dengan torso   : 94
#   Frame tanpa torso    : 4
#   Rata-rata titik torso/frame: 31.10
#   >> [TEMPORAL] Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso_temporal\Afi\torsoT_Jalan9.csv
#
# ======================================================================
# [TEMPORAL] Subjek: Tsamara
# ======================================================================
# [INFO] Tsamara: ditemukan 72 file clustering
#
# === [TEMPORAL] Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Tsamara\clustering_Jalan1.csv
#   Total frame unik dalam file ini: 91
#   Frame dengan torso   : 83
#   Frame tanpa torso    : 8
#   Rata-rata titik torso/frame: 22.47
#   >> [TEMPORAL] Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso_temporal\Tsamara\torsoT_Jalan1.csv
#
# === [TEMPORAL] Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Tsamara\clustering_Jalan10.csv
#   Total frame unik dalam file ini: 137
#   Frame dengan torso   : 129
#   Frame tanpa torso    : 8
#   Rata-rata titik torso/frame: 26.88
#   >> [TEMPORAL] Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso_temporal\Tsamara\torsoT_Jalan10.csv
#
# === [TEMPORAL] Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Tsamara\clustering_Jalan11.csv
#   Total frame unik dalam file ini: 130
#   Frame dengan torso   : 122
#   Frame tanpa torso    : 8
#   Rata-rata titik torso/frame: 27.47
#   >> [TEMPORAL] Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso_temporal\Tsamara\torsoT_Jalan11.csv
#
# === [TEMPORAL] Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Tsamara\clustering_Jalan12.csv
#   Total frame unik dalam file ini: 110
#   Frame dengan torso   : 103
#   Frame tanpa torso    : 7
#   Rata-rata titik torso/frame: 22.46
#   >> [TEMPORAL] Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso_temporal\Tsamara\torsoT_Jalan12.csv
#
# === [TEMPORAL] Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Tsamara\clustering_Jalan13.csv
#   Total frame unik dalam file ini: 139
#   Frame dengan torso   : 127
#   Frame tanpa torso    : 12
#   Rata-rata titik torso/frame: 23.44
#   >> [TEMPORAL] Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso_temporal\Tsamara\torsoT_Jalan13.csv
#
# === [TEMPORAL] Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Tsamara\clustering_Jalan14.csv
#   Total frame unik dalam file ini: 113
#   Frame dengan torso   : 104
#   Frame tanpa torso    : 9
#   Rata-rata titik torso/frame: 32.81
#   >> [TEMPORAL] Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso_temporal\Tsamara\torsoT_Jalan14.csv
#
# === [TEMPORAL] Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Tsamara\clustering_Jalan15.csv
#   Total frame unik dalam file ini: 321
#   Frame dengan torso   : 301
#   Frame tanpa torso    : 20
#   Rata-rata titik torso/frame: 20.44
#   >> [TEMPORAL] Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso_temporal\Tsamara\torsoT_Jalan15.csv
#
# === [TEMPORAL] Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Tsamara\clustering_Jalan16.csv
#   Total frame unik dalam file ini: 249
#   Frame dengan torso   : 228
#   Frame tanpa torso    : 21
#   Rata-rata titik torso/frame: 26.74
#   >> [TEMPORAL] Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso_temporal\Tsamara\torsoT_Jalan16.csv
#
# === [TEMPORAL] Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Tsamara\clustering_Jalan17.csv
#   Total frame unik dalam file ini: 228
#   Frame dengan torso   : 215
#   Frame tanpa torso    : 13
#   Rata-rata titik torso/frame: 26.31
#   >> [TEMPORAL] Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso_temporal\Tsamara\torsoT_Jalan17.csv
#
# === [TEMPORAL] Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Tsamara\clustering_Jalan18.csv
#   Total frame unik dalam file ini: 163
#   Frame dengan torso   : 151
#   Frame tanpa torso    : 12
#   Rata-rata titik torso/frame: 37.09
#   >> [TEMPORAL] Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso_temporal\Tsamara\torsoT_Jalan18.csv
#
# === [TEMPORAL] Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Tsamara\clustering_Jalan19.csv
#   Total frame unik dalam file ini: 274
#   Frame dengan torso   : 240
#   Frame tanpa torso    : 34
#   Rata-rata titik torso/frame: 25.05
#   >> [TEMPORAL] Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso_temporal\Tsamara\torsoT_Jalan19.csv
#
# === [TEMPORAL] Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Tsamara\clustering_Jalan2.csv
#   Total frame unik dalam file ini: 99
#   Frame dengan torso   : 94
#   Frame tanpa torso    : 5
#   Rata-rata titik torso/frame: 39.68
#   >> [TEMPORAL] Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso_temporal\Tsamara\torsoT_Jalan2.csv
#
# === [TEMPORAL] Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Tsamara\clustering_Jalan20.csv
#   Total frame unik dalam file ini: 262
#   Frame dengan torso   : 218
#   Frame tanpa torso    : 44
#   Rata-rata titik torso/frame: 33.56
#   >> [TEMPORAL] Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso_temporal\Tsamara\torsoT_Jalan20.csv
#
# === [TEMPORAL] Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Tsamara\clustering_Jalan21.csv
#   Total frame unik dalam file ini: 194
#   Frame dengan torso   : 183
#   Frame tanpa torso    : 11
#   Rata-rata titik torso/frame: 34.70
#   >> [TEMPORAL] Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso_temporal\Tsamara\torsoT_Jalan21.csv
#
# === [TEMPORAL] Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Tsamara\clustering_Jalan22.csv
#   Total frame unik dalam file ini: 176
#   Frame dengan torso   : 165
#   Frame tanpa torso    : 11
#   Rata-rata titik torso/frame: 32.56
#   >> [TEMPORAL] Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso_temporal\Tsamara\torsoT_Jalan22.csv
#
# === [TEMPORAL] Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Tsamara\clustering_Jalan23.csv
#   Total frame unik dalam file ini: 571
#   Frame dengan torso   : 547
#   Frame tanpa torso    : 24
#   Rata-rata titik torso/frame: 22.78
#   >> [TEMPORAL] Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso_temporal\Tsamara\torsoT_Jalan23.csv
#
# === [TEMPORAL] Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Tsamara\clustering_Jalan24.csv
#   Total frame unik dalam file ini: 489
#   Frame dengan torso   : 455
#   Frame tanpa torso    : 34
#   Rata-rata titik torso/frame: 26.36
#   >> [TEMPORAL] Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso_temporal\Tsamara\torsoT_Jalan24.csv
#
# === [TEMPORAL] Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Tsamara\clustering_Jalan25.csv
#   Total frame unik dalam file ini: 87
#   Frame dengan torso   : 81
#   Frame tanpa torso    : 6
#   Rata-rata titik torso/frame: 16.44
#   >> [TEMPORAL] Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso_temporal\Tsamara\torsoT_Jalan25.csv
#
# === [TEMPORAL] Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Tsamara\clustering_Jalan26.csv
#   Total frame unik dalam file ini: 92
#   Frame dengan torso   : 88
#   Frame tanpa torso    : 4
#   Rata-rata titik torso/frame: 38.57
#   >> [TEMPORAL] Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso_temporal\Tsamara\torsoT_Jalan26.csv
#
# === [TEMPORAL] Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Tsamara\clustering_Jalan27.csv
#   Total frame unik dalam file ini: 100
#   Frame dengan torso   : 90
#   Frame tanpa torso    : 10
#   Rata-rata titik torso/frame: 21.51
#   >> [TEMPORAL] Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso_temporal\Tsamara\torsoT_Jalan27.csv
#
# === [TEMPORAL] Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Tsamara\clustering_Jalan28.csv
#   Total frame unik dalam file ini: 90
#   Frame dengan torso   : 85
#   Frame tanpa torso    : 5
#   Rata-rata titik torso/frame: 24.93
#   >> [TEMPORAL] Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso_temporal\Tsamara\torsoT_Jalan28.csv
#
# === [TEMPORAL] Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Tsamara\clustering_Jalan29.csv
#   Total frame unik dalam file ini: 80
#   Frame dengan torso   : 76
#   Frame tanpa torso    : 4
#   Rata-rata titik torso/frame: 13.78
#   >> [TEMPORAL] Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso_temporal\Tsamara\torsoT_Jalan29.csv
#
# === [TEMPORAL] Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Tsamara\clustering_Jalan3.csv
#   Total frame unik dalam file ini: 89
#   Frame dengan torso   : 83
#   Frame tanpa torso    : 6
#   Rata-rata titik torso/frame: 28.63
#   >> [TEMPORAL] Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso_temporal\Tsamara\torsoT_Jalan3.csv
#
# === [TEMPORAL] Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Tsamara\clustering_Jalan30.csv
#   Total frame unik dalam file ini: 86
#   Frame dengan torso   : 78
#   Frame tanpa torso    : 8
#   Rata-rata titik torso/frame: 18.23
#   >> [TEMPORAL] Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso_temporal\Tsamara\torsoT_Jalan30.csv
#
# === [TEMPORAL] Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Tsamara\clustering_Jalan31.csv
#   Total frame unik dalam file ini: 82
#   Frame dengan torso   : 78
#   Frame tanpa torso    : 4
#   Rata-rata titik torso/frame: 26.53
#   >> [TEMPORAL] Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso_temporal\Tsamara\torsoT_Jalan31.csv
#
# === [TEMPORAL] Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Tsamara\clustering_Jalan32.csv
#   Total frame unik dalam file ini: 96
#   Frame dengan torso   : 90
#   Frame tanpa torso    : 6
#   Rata-rata titik torso/frame: 28.32
#   >> [TEMPORAL] Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso_temporal\Tsamara\torsoT_Jalan32.csv
#
# === [TEMPORAL] Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Tsamara\clustering_Jalan33.csv
#   Total frame unik dalam file ini: 86
#   Frame dengan torso   : 79
#   Frame tanpa torso    : 7
#   Rata-rata titik torso/frame: 27.19
#   >> [TEMPORAL] Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso_temporal\Tsamara\torsoT_Jalan33.csv
#
# === [TEMPORAL] Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Tsamara\clustering_Jalan34.csv
#   Total frame unik dalam file ini: 110
#   Frame dengan torso   : 106
#   Frame tanpa torso    : 4
#   Rata-rata titik torso/frame: 24.40
#   >> [TEMPORAL] Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso_temporal\Tsamara\torsoT_Jalan34.csv
#
# === [TEMPORAL] Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Tsamara\clustering_Jalan35.csv
#   Total frame unik dalam file ini: 87
#   Frame dengan torso   : 83
#   Frame tanpa torso    : 4
#   Rata-rata titik torso/frame: 24.70
#   >> [TEMPORAL] Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso_temporal\Tsamara\torsoT_Jalan35.csv
#
# === [TEMPORAL] Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Tsamara\clustering_Jalan36.csv
#   Total frame unik dalam file ini: 94
#   Frame dengan torso   : 82
#   Frame tanpa torso    : 12
#   Rata-rata titik torso/frame: 19.23
#   >> [TEMPORAL] Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso_temporal\Tsamara\torsoT_Jalan36.csv
#
# === [TEMPORAL] Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Tsamara\clustering_Jalan37.csv
#   Total frame unik dalam file ini: 114
#   Frame dengan torso   : 105
#   Frame tanpa torso    : 9
#   Rata-rata titik torso/frame: 20.97
#   >> [TEMPORAL] Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso_temporal\Tsamara\torsoT_Jalan37.csv
#
# === [TEMPORAL] Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Tsamara\clustering_Jalan38.csv
#   Total frame unik dalam file ini: 105
#   Frame dengan torso   : 84
#   Frame tanpa torso    : 21
#   Rata-rata titik torso/frame: 20.67
#   >> [TEMPORAL] Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso_temporal\Tsamara\torsoT_Jalan38.csv
#
# === [TEMPORAL] Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Tsamara\clustering_Jalan39.csv
#   Total frame unik dalam file ini: 187
#   Frame dengan torso   : 176
#   Frame tanpa torso    : 11
#   Rata-rata titik torso/frame: 23.60
#   >> [TEMPORAL] Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso_temporal\Tsamara\torsoT_Jalan39.csv
#
# === [TEMPORAL] Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Tsamara\clustering_Jalan4.csv
#   Total frame unik dalam file ini: 111
#   Frame dengan torso   : 104
#   Frame tanpa torso    : 7
#   Rata-rata titik torso/frame: 28.31
#   >> [TEMPORAL] Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso_temporal\Tsamara\torsoT_Jalan4.csv
#
# === [TEMPORAL] Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Tsamara\clustering_Jalan40.csv
#   Total frame unik dalam file ini: 182
#   Frame dengan torso   : 153
#   Frame tanpa torso    : 29
#   Rata-rata titik torso/frame: 23.46
#   >> [TEMPORAL] Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso_temporal\Tsamara\torsoT_Jalan40.csv
#
# === [TEMPORAL] Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Tsamara\clustering_Jalan41.csv
#   Total frame unik dalam file ini: 164
#   Frame dengan torso   : 153
#   Frame tanpa torso    : 11
#   Rata-rata titik torso/frame: 28.86
#   >> [TEMPORAL] Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso_temporal\Tsamara\torsoT_Jalan41.csv
#
# === [TEMPORAL] Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Tsamara\clustering_Jalan42.csv
#   Total frame unik dalam file ini: 160
#   Frame dengan torso   : 144
#   Frame tanpa torso    : 16
#   Rata-rata titik torso/frame: 28.57
#   >> [TEMPORAL] Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso_temporal\Tsamara\torsoT_Jalan42.csv
#
# === [TEMPORAL] Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Tsamara\clustering_Jalan43.csv
#   Total frame unik dalam file ini: 160
#   Frame dengan torso   : 144
#   Frame tanpa torso    : 16
#   Rata-rata titik torso/frame: 27.81
#   >> [TEMPORAL] Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso_temporal\Tsamara\torsoT_Jalan43.csv
#
# === [TEMPORAL] Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Tsamara\clustering_Jalan44.csv
#   Total frame unik dalam file ini: 137
#   Frame dengan torso   : 125
#   Frame tanpa torso    : 12
#   Rata-rata titik torso/frame: 33.12
#   >> [TEMPORAL] Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso_temporal\Tsamara\torsoT_Jalan44.csv
#
# === [TEMPORAL] Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Tsamara\clustering_Jalan45.csv
#   Total frame unik dalam file ini: 149
#   Frame dengan torso   : 133
#   Frame tanpa torso    : 16
#   Rata-rata titik torso/frame: 27.97
#   >> [TEMPORAL] Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso_temporal\Tsamara\torsoT_Jalan45.csv
#
# === [TEMPORAL] Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Tsamara\clustering_Jalan46.csv
#   Total frame unik dalam file ini: 140
#   Frame dengan torso   : 122
#   Frame tanpa torso    : 18
#   Rata-rata titik torso/frame: 39.03
#   >> [TEMPORAL] Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso_temporal\Tsamara\torsoT_Jalan46.csv
#
# === [TEMPORAL] Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Tsamara\clustering_Jalan47.csv
#   Total frame unik dalam file ini: 301
#   Frame dengan torso   : 276
#   Frame tanpa torso    : 25
#   Rata-rata titik torso/frame: 24.72
#   >> [TEMPORAL] Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso_temporal\Tsamara\torsoT_Jalan47.csv
#
# === [TEMPORAL] Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Tsamara\clustering_Jalan48.csv
#   Total frame unik dalam file ini: 287
#   Frame dengan torso   : 270
#   Frame tanpa torso    : 17
#   Rata-rata titik torso/frame: 29.70
#   >> [TEMPORAL] Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso_temporal\Tsamara\torsoT_Jalan48.csv
#
# === [TEMPORAL] Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Tsamara\clustering_Jalan49.csv
#   Total frame unik dalam file ini: 155
#   Frame dengan torso   : 140
#   Frame tanpa torso    : 15
#   Rata-rata titik torso/frame: 21.70
#   >> [TEMPORAL] Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso_temporal\Tsamara\torsoT_Jalan49.csv
#
# === [TEMPORAL] Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Tsamara\clustering_Jalan5.csv
#   Total frame unik dalam file ini: 105
#   Frame dengan torso   : 94
#   Frame tanpa torso    : 11
#   Rata-rata titik torso/frame: 15.16
#   >> [TEMPORAL] Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso_temporal\Tsamara\torsoT_Jalan5.csv
#
# === [TEMPORAL] Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Tsamara\clustering_Jalan50.csv
#   Total frame unik dalam file ini: 129
#   Frame dengan torso   : 125
#   Frame tanpa torso    : 4
#   Rata-rata titik torso/frame: 48.48
#   >> [TEMPORAL] Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso_temporal\Tsamara\torsoT_Jalan50.csv
#
# === [TEMPORAL] Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Tsamara\clustering_Jalan51.csv
#   Total frame unik dalam file ini: 152
#   Frame dengan torso   : 131
#   Frame tanpa torso    : 21
#   Rata-rata titik torso/frame: 33.76
#   >> [TEMPORAL] Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso_temporal\Tsamara\torsoT_Jalan51.csv
#
# === [TEMPORAL] Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Tsamara\clustering_Jalan52.csv
#   Total frame unik dalam file ini: 135
#   Frame dengan torso   : 115
#   Frame tanpa torso    : 20
#   Rata-rata titik torso/frame: 27.36
#   >> [TEMPORAL] Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso_temporal\Tsamara\torsoT_Jalan52.csv
#
# === [TEMPORAL] Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Tsamara\clustering_Jalan53.csv
#   Total frame unik dalam file ini: 132
#   Frame dengan torso   : 127
#   Frame tanpa torso    : 5
#   Rata-rata titik torso/frame: 13.35
#   >> [TEMPORAL] Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso_temporal\Tsamara\torsoT_Jalan53.csv
#
# === [TEMPORAL] Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Tsamara\clustering_Jalan54.csv
#   Total frame unik dalam file ini: 149
#   Frame dengan torso   : 139
#   Frame tanpa torso    : 10
#   Rata-rata titik torso/frame: 17.29
#   >> [TEMPORAL] Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso_temporal\Tsamara\torsoT_Jalan54.csv
#
# === [TEMPORAL] Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Tsamara\clustering_Jalan55.csv
#   Total frame unik dalam file ini: 163
#   Frame dengan torso   : 148
#   Frame tanpa torso    : 15
#   Rata-rata titik torso/frame: 25.56
#   >> [TEMPORAL] Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso_temporal\Tsamara\torsoT_Jalan55.csv
#
# === [TEMPORAL] Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Tsamara\clustering_Jalan56.csv
#   Total frame unik dalam file ini: 157
#   Frame dengan torso   : 150
#   Frame tanpa torso    : 7
#   Rata-rata titik torso/frame: 25.43
#   >> [TEMPORAL] Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso_temporal\Tsamara\torsoT_Jalan56.csv
#
# === [TEMPORAL] Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Tsamara\clustering_Jalan57.csv
#   Total frame unik dalam file ini: 120
#   Frame dengan torso   : 114
#   Frame tanpa torso    : 6
#   Rata-rata titik torso/frame: 37.08
#   >> [TEMPORAL] Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso_temporal\Tsamara\torsoT_Jalan57.csv
#
# === [TEMPORAL] Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Tsamara\clustering_Jalan58.csv
#   Total frame unik dalam file ini: 184
#   Frame dengan torso   : 170
#   Frame tanpa torso    : 14
#   Rata-rata titik torso/frame: 22.23
#   >> [TEMPORAL] Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso_temporal\Tsamara\torsoT_Jalan58.csv
#
# === [TEMPORAL] Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Tsamara\clustering_Jalan59.csv
#   Total frame unik dalam file ini: 117
#   Frame dengan torso   : 110
#   Frame tanpa torso    : 7
#   Rata-rata titik torso/frame: 25.94
#   >> [TEMPORAL] Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso_temporal\Tsamara\torsoT_Jalan59.csv
#
# === [TEMPORAL] Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Tsamara\clustering_Jalan6.csv
#   Total frame unik dalam file ini: 117
#   Frame dengan torso   : 104
#   Frame tanpa torso    : 13
#   Rata-rata titik torso/frame: 17.16
#   >> [TEMPORAL] Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso_temporal\Tsamara\torsoT_Jalan6.csv
#
# === [TEMPORAL] Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Tsamara\clustering_Jalan60.csv
#   Total frame unik dalam file ini: 125
#   Frame dengan torso   : 112
#   Frame tanpa torso    : 13
#   Rata-rata titik torso/frame: 17.79
#   >> [TEMPORAL] Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso_temporal\Tsamara\torsoT_Jalan60.csv
#
# === [TEMPORAL] Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Tsamara\clustering_Jalan61.csv
#   Total frame unik dalam file ini: 162
#   Frame dengan torso   : 143
#   Frame tanpa torso    : 19
#   Rata-rata titik torso/frame: 29.22
#   >> [TEMPORAL] Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso_temporal\Tsamara\torsoT_Jalan61.csv
#
# === [TEMPORAL] Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Tsamara\clustering_Jalan62.csv
#   Total frame unik dalam file ini: 132
#   Frame dengan torso   : 116
#   Frame tanpa torso    : 16
#   Rata-rata titik torso/frame: 30.82
#   >> [TEMPORAL] Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso_temporal\Tsamara\torsoT_Jalan62.csv
#
# === [TEMPORAL] Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Tsamara\clustering_Jalan63.csv
#   Total frame unik dalam file ini: 348
#   Frame dengan torso   : 318
#   Frame tanpa torso    : 30
#   Rata-rata titik torso/frame: 21.01
#   >> [TEMPORAL] Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso_temporal\Tsamara\torsoT_Jalan63.csv
#
# === [TEMPORAL] Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Tsamara\clustering_Jalan64.csv
#   Total frame unik dalam file ini: 349
#   Frame dengan torso   : 321
#   Frame tanpa torso    : 28
#   Rata-rata titik torso/frame: 27.69
#   >> [TEMPORAL] Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso_temporal\Tsamara\torsoT_Jalan64.csv
#
# === [TEMPORAL] Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Tsamara\clustering_Jalan65.csv
#   Total frame unik dalam file ini: 215
#   Frame dengan torso   : 207
#   Frame tanpa torso    : 8
#   Rata-rata titik torso/frame: 25.97
#   >> [TEMPORAL] Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso_temporal\Tsamara\torsoT_Jalan65.csv
#
# === [TEMPORAL] Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Tsamara\clustering_Jalan66.csv
#   Total frame unik dalam file ini: 177
#   Frame dengan torso   : 167
#   Frame tanpa torso    : 10
#   Rata-rata titik torso/frame: 34.29
#   >> [TEMPORAL] Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso_temporal\Tsamara\torsoT_Jalan66.csv
#
# === [TEMPORAL] Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Tsamara\clustering_Jalan67.csv
#   Total frame unik dalam file ini: 270
#   Frame dengan torso   : 252
#   Frame tanpa torso    : 18
#   Rata-rata titik torso/frame: 23.44
#   >> [TEMPORAL] Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso_temporal\Tsamara\torsoT_Jalan67.csv
#
# === [TEMPORAL] Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Tsamara\clustering_Jalan68.csv
#   Total frame unik dalam file ini: 255
#   Frame dengan torso   : 234
#   Frame tanpa torso    : 21
#   Rata-rata titik torso/frame: 21.68
#   >> [TEMPORAL] Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso_temporal\Tsamara\torsoT_Jalan68.csv
#
# === [TEMPORAL] Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Tsamara\clustering_Jalan69.csv
#   Total frame unik dalam file ini: 180
#   Frame dengan torso   : 161
#   Frame tanpa torso    : 19
#   Rata-rata titik torso/frame: 27.29
#   >> [TEMPORAL] Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso_temporal\Tsamara\torsoT_Jalan69.csv
#
# === [TEMPORAL] Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Tsamara\clustering_Jalan7.csv
#   Total frame unik dalam file ini: 124
#   Frame dengan torso   : 104
# ...
#   Total frame unik dalam file ini: 102
#   Frame dengan torso   : 84
#   Frame tanpa torso    : 18
#   Rata-rata titik torso/frame: 23.60
#   >> [TEMPORAL] Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso_temporal\Tsania\torsoT_Jalan36.csv
#
# === [TEMPORAL] Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Tsania\clustering_Jalan37.csv
#   Total frame unik dalam file ini: 107
#   Frame dengan torso   : 99
#   Frame tanpa torso    : 8
#   Rata-rata titik torso/frame: 23.65
#   >> [TEMPORAL] Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso_temporal\Tsania\torsoT_Jalan37.csv
#
# === [TEMPORAL] Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Tsania\clustering_Jalan38.csv
#   Total frame unik dalam file ini: 99
#   Frame dengan torso   : 90
#   Frame tanpa torso    : 9
#   Rata-rata titik torso/frame: 19.91
#   >> [TEMPORAL] Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso_temporal\Tsania\torsoT_Jalan38.csv
#
# === [TEMPORAL] Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Tsania\clustering_Jalan39.csv
#   Total frame unik dalam file ini: 177
#   Frame dengan torso   : 155
#   Frame tanpa torso    : 22
#   Rata-rata titik torso/frame: 22.85
#   >> [TEMPORAL] Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso_temporal\Tsania\torsoT_Jalan39.csv
#
# === [TEMPORAL] Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Tsania\clustering_Jalan4.csv
#   Total frame unik dalam file ini: 93
#   Frame dengan torso   : 89
#   Frame tanpa torso    : 4
#   Rata-rata titik torso/frame: 16.84
#   >> [TEMPORAL] Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso_temporal\Tsania\torsoT_Jalan4.csv
#
# === [TEMPORAL] Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Tsania\clustering_Jalan40.csv
#   Total frame unik dalam file ini: 166
#   Frame dengan torso   : 152
#   Frame tanpa torso    : 14
#   Rata-rata titik torso/frame: 32.05
#   >> [TEMPORAL] Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso_temporal\Tsania\torsoT_Jalan40.csv
#
# === [TEMPORAL] Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Tsania\clustering_Jalan41.csv
#   Total frame unik dalam file ini: 147
#   Frame dengan torso   : 136
#   Frame tanpa torso    : 11
#   Rata-rata titik torso/frame: 37.01
#   >> [TEMPORAL] Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso_temporal\Tsania\torsoT_Jalan41.csv
#
# === [TEMPORAL] Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Tsania\clustering_Jalan42.csv
#   Total frame unik dalam file ini: 111
#   Frame dengan torso   : 106
#   Frame tanpa torso    : 5
#   Rata-rata titik torso/frame: 39.39
#   >> [TEMPORAL] Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso_temporal\Tsania\torsoT_Jalan42.csv
#
# === [TEMPORAL] Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Tsania\clustering_Jalan43.csv
#   Total frame unik dalam file ini: 149
#   Frame dengan torso   : 128
#   Frame tanpa torso    : 21
#   Rata-rata titik torso/frame: 38.25
#   >> [TEMPORAL] Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso_temporal\Tsania\torsoT_Jalan43.csv
#
# === [TEMPORAL] Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Tsania\clustering_Jalan44.csv
#   Total frame unik dalam file ini: 132
#   Frame dengan torso   : 120
#   Frame tanpa torso    : 12
#   Rata-rata titik torso/frame: 41.33
#   >> [TEMPORAL] Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso_temporal\Tsania\torsoT_Jalan44.csv
#
# === [TEMPORAL] Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Tsania\clustering_Jalan45.csv
#   Total frame unik dalam file ini: 122
#   Frame dengan torso   : 114
#   Frame tanpa torso    : 8
#   Rata-rata titik torso/frame: 45.51
#   >> [TEMPORAL] Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso_temporal\Tsania\torsoT_Jalan45.csv
#
# === [TEMPORAL] Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Tsania\clustering_Jalan46.csv
#   Total frame unik dalam file ini: 111
#   Frame dengan torso   : 94
#   Frame tanpa torso    : 17
#   Rata-rata titik torso/frame: 45.96
#   >> [TEMPORAL] Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso_temporal\Tsania\torsoT_Jalan46.csv
#
# === [TEMPORAL] Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Tsania\clustering_Jalan47.csv
#   Total frame unik dalam file ini: 322
#   Frame dengan torso   : 289
#   Frame tanpa torso    : 33
#   Rata-rata titik torso/frame: 24.43
#   >> [TEMPORAL] Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso_temporal\Tsania\torsoT_Jalan47.csv
#
# === [TEMPORAL] Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Tsania\clustering_Jalan48.csv
#   Total frame unik dalam file ini: 278
#   Frame dengan torso   : 256
#   Frame tanpa torso    : 22
#   Rata-rata titik torso/frame: 28.43
#   >> [TEMPORAL] Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso_temporal\Tsania\torsoT_Jalan48.csv
#
# === [TEMPORAL] Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Tsania\clustering_Jalan49.csv
#   Total frame unik dalam file ini: 129
#   Frame dengan torso   : 116
#   Frame tanpa torso    : 13
#   Rata-rata titik torso/frame: 23.96
#   >> [TEMPORAL] Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso_temporal\Tsania\torsoT_Jalan49.csv
#
# === [TEMPORAL] Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Tsania\clustering_Jalan5.csv
#   Total frame unik dalam file ini: 114
#   Frame dengan torso   : 96
#   Frame tanpa torso    : 18
#   Rata-rata titik torso/frame: 16.51
#   >> [TEMPORAL] Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso_temporal\Tsania\torsoT_Jalan5.csv
#
# === [TEMPORAL] Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Tsania\clustering_Jalan50.csv
#   Total frame unik dalam file ini: 106
#   Frame dengan torso   : 95
#   Frame tanpa torso    : 11
#   Rata-rata titik torso/frame: 26.41
#   >> [TEMPORAL] Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso_temporal\Tsania\torsoT_Jalan50.csv
#
# === [TEMPORAL] Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Tsania\clustering_Jalan51.csv
#   Total frame unik dalam file ini: 123
#   Frame dengan torso   : 113
#   Frame tanpa torso    : 10
#   Rata-rata titik torso/frame: 30.77
#   >> [TEMPORAL] Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso_temporal\Tsania\torsoT_Jalan51.csv
#
# === [TEMPORAL] Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Tsania\clustering_Jalan52.csv
#   Total frame unik dalam file ini: 129
#   Frame dengan torso   : 122
#   Frame tanpa torso    : 7
#   Rata-rata titik torso/frame: 17.29
#   >> [TEMPORAL] Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso_temporal\Tsania\torsoT_Jalan52.csv
#
# === [TEMPORAL] Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Tsania\clustering_Jalan53.csv
#   Total frame unik dalam file ini: 118
#   Frame dengan torso   : 108
#   Frame tanpa torso    : 10
#   Rata-rata titik torso/frame: 19.17
#   >> [TEMPORAL] Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso_temporal\Tsania\torsoT_Jalan53.csv
#
# === [TEMPORAL] Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Tsania\clustering_Jalan54.csv
#   Total frame unik dalam file ini: 122
#   Frame dengan torso   : 110
#   Frame tanpa torso    : 12
#   Rata-rata titik torso/frame: 26.68
#   >> [TEMPORAL] Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso_temporal\Tsania\torsoT_Jalan54.csv
#
# === [TEMPORAL] Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Tsania\clustering_Jalan55.csv
#   Total frame unik dalam file ini: 103
#   Frame dengan torso   : 96
#   Frame tanpa torso    : 7
#   Rata-rata titik torso/frame: 29.73
#   >> [TEMPORAL] Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso_temporal\Tsania\torsoT_Jalan55.csv
#
# === [TEMPORAL] Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Tsania\clustering_Jalan56.csv
#   Total frame unik dalam file ini: 129
#   Frame dengan torso   : 119
#   Frame tanpa torso    : 10
#   Rata-rata titik torso/frame: 27.18
#   >> [TEMPORAL] Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso_temporal\Tsania\torsoT_Jalan56.csv
#
# === [TEMPORAL] Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Tsania\clustering_Jalan57.csv
#   Total frame unik dalam file ini: 116
#   Frame dengan torso   : 102
#   Frame tanpa torso    : 14
#   Rata-rata titik torso/frame: 34.42
#   >> [TEMPORAL] Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso_temporal\Tsania\torsoT_Jalan57.csv
#
# === [TEMPORAL] Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Tsania\clustering_Jalan58.csv
#   Total frame unik dalam file ini: 142
#   Frame dengan torso   : 132
#   Frame tanpa torso    : 10
#   Rata-rata titik torso/frame: 27.39
#   >> [TEMPORAL] Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso_temporal\Tsania\torsoT_Jalan58.csv
#
# === [TEMPORAL] Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Tsania\clustering_Jalan59.csv
#   Total frame unik dalam file ini: 110
#   Frame dengan torso   : 101
#   Frame tanpa torso    : 9
#   Rata-rata titik torso/frame: 23.81
#   >> [TEMPORAL] Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso_temporal\Tsania\torsoT_Jalan59.csv
#
# === [TEMPORAL] Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Tsania\clustering_Jalan6.csv
#   Total frame unik dalam file ini: 119
#   Frame dengan torso   : 103
#   Frame tanpa torso    : 16
#   Rata-rata titik torso/frame: 27.77
#   >> [TEMPORAL] Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso_temporal\Tsania\torsoT_Jalan6.csv
#
# === [TEMPORAL] Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Tsania\clustering_Jalan60.csv
#   Total frame unik dalam file ini: 122
#   Frame dengan torso   : 97
#   Frame tanpa torso    : 25
#   Rata-rata titik torso/frame: 26.90
#   >> [TEMPORAL] Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso_temporal\Tsania\torsoT_Jalan60.csv
#
# === [TEMPORAL] Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Tsania\clustering_Jalan61.csv
#   Total frame unik dalam file ini: 144
#   Frame dengan torso   : 137
#   Frame tanpa torso    : 7
#   Rata-rata titik torso/frame: 30.36
#   >> [TEMPORAL] Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso_temporal\Tsania\torsoT_Jalan61.csv
#
# === [TEMPORAL] Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Tsania\clustering_Jalan62.csv
#   Total frame unik dalam file ini: 127
#   Frame dengan torso   : 112
#   Frame tanpa torso    : 15
#   Rata-rata titik torso/frame: 30.26
#   >> [TEMPORAL] Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso_temporal\Tsania\torsoT_Jalan62.csv
#
# === [TEMPORAL] Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Tsania\clustering_Jalan63.csv
#   Total frame unik dalam file ini: 251
#   Frame dengan torso   : 230
#   Frame tanpa torso    : 21
#   Rata-rata titik torso/frame: 31.74
#   >> [TEMPORAL] Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso_temporal\Tsania\torsoT_Jalan63.csv
#
# === [TEMPORAL] Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Tsania\clustering_Jalan64.csv
#   Total frame unik dalam file ini: 212
#   Frame dengan torso   : 186
#   Frame tanpa torso    : 26
#   Rata-rata titik torso/frame: 37.33
#   >> [TEMPORAL] Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso_temporal\Tsania\torsoT_Jalan64.csv
#
# === [TEMPORAL] Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Tsania\clustering_Jalan65.csv
#   Total frame unik dalam file ini: 136
#   Frame dengan torso   : 128
#   Frame tanpa torso    : 8
#   Rata-rata titik torso/frame: 51.09
#   >> [TEMPORAL] Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso_temporal\Tsania\torsoT_Jalan65.csv
#
# === [TEMPORAL] Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Tsania\clustering_Jalan66.csv
#   Total frame unik dalam file ini: 122
#   Frame dengan torso   : 115
#   Frame tanpa torso    : 7
#   Rata-rata titik torso/frame: 46.75
#   >> [TEMPORAL] Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso_temporal\Tsania\torsoT_Jalan66.csv
#
# === [TEMPORAL] Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Tsania\clustering_Jalan67.csv
#   Total frame unik dalam file ini: 187
#   Frame dengan torso   : 162
#   Frame tanpa torso    : 25
#   Rata-rata titik torso/frame: 37.75
#   >> [TEMPORAL] Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso_temporal\Tsania\torsoT_Jalan67.csv
#
# === [TEMPORAL] Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Tsania\clustering_Jalan68.csv
#   Total frame unik dalam file ini: 162
#   Frame dengan torso   : 154
#   Frame tanpa torso    : 8
#   Rata-rata titik torso/frame: 50.81
#   >> [TEMPORAL] Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso_temporal\Tsania\torsoT_Jalan68.csv
#
# === [TEMPORAL] Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Tsania\clustering_Jalan69.csv
#   Total frame unik dalam file ini: 133
#   Frame dengan torso   : 123
#   Frame tanpa torso    : 10
#   Rata-rata titik torso/frame: 47.14
#   >> [TEMPORAL] Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso_temporal\Tsania\torsoT_Jalan69.csv
#
# === [TEMPORAL] Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Tsania\clustering_Jalan7.csv
#   Total frame unik dalam file ini: 96
#   Frame dengan torso   : 85
#   Frame tanpa torso    : 11
#   Rata-rata titik torso/frame: 27.44
#   >> [TEMPORAL] Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso_temporal\Tsania\torsoT_Jalan7.csv
#
# === [TEMPORAL] Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Tsania\clustering_Jalan70.csv
#   Total frame unik dalam file ini: 122
#   Frame dengan torso   : 115
#   Frame tanpa torso    : 7
#   Rata-rata titik torso/frame: 46.11
#   >> [TEMPORAL] Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso_temporal\Tsania\torsoT_Jalan70.csv
#
# === [TEMPORAL] Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Tsania\clustering_Jalan71.csv
#   Total frame unik dalam file ini: 428
#   Frame dengan torso   : 387
#   Frame tanpa torso    : 41
#   Rata-rata titik torso/frame: 32.70
#   >> [TEMPORAL] Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso_temporal\Tsania\torsoT_Jalan71.csv
#
# === [TEMPORAL] Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Tsania\clustering_Jalan72.csv
#   Total frame unik dalam file ini: 449
#   Frame dengan torso   : 409
#   Frame tanpa torso    : 40
#   Rata-rata titik torso/frame: 33.20
#   >> [TEMPORAL] Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso_temporal\Tsania\torsoT_Jalan72.csv
#
# === [TEMPORAL] Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Tsania\clustering_Jalan8.csv
#   Total frame unik dalam file ini: 119
#   Frame dengan torso   : 107
#   Frame tanpa torso    : 12
#   Rata-rata titik torso/frame: 32.37
#   >> [TEMPORAL] Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso_temporal\Tsania\torsoT_Jalan8.csv
#
# === [TEMPORAL] Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Tsania\clustering_Jalan9.csv
#   Total frame unik dalam file ini: 116
#   Frame dengan torso   : 108
#   Frame tanpa torso    : 8
#   Rata-rata titik torso/frame: 31.88
#   >> [TEMPORAL] Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso_temporal\Tsania\torsoT_Jalan9.csv
#
# === [TEMPORAL] Ringkasan global torso extraction (head) ===
#                                                 file  \
# 0  E:\1.Clustering_TA\dataset2\hasil_clustering\A...
# 1  E:\1.Clustering_TA\dataset2\hasil_clustering\A...
# 2  E:\1.Clustering_TA\dataset2\hasil_clustering\A...
# 3  E:\1.Clustering_TA\dataset2\hasil_clustering\A...
# 4  E:\1.Clustering_TA\dataset2\hasil_clustering\A...
#
#                                           torso_file  n_frames_total  \
# 0  E:\0.TA_Teguh\dataset2\hasil_torso_temporal\Af...              99
# 1  E:\0.TA_Teguh\dataset2\hasil_torso_temporal\Af...              94
# 2  E:\0.TA_Teguh\dataset2\hasil_torso_temporal\Af...              96
# 3  E:\0.TA_Teguh\dataset2\hasil_torso_temporal\Af...              77
# 4  E:\0.TA_Teguh\dataset2\hasil_torso_temporal\Af...              99
#
#    n_frames_with_torso  avg_points_per_torso_frame subject
# 0                   91                   20.450549     Afi
# 1                   89                   23.764045     Afi
# 2                   90                   19.855556     Afi
# 3                   71                   29.830986     Afi
# 4                   92                   24.532609     Afi

# %% [markdown]
# 🧩 Cell E – Bandingkan simple vs temporal per subjek

# %%
# Cell E: Bandingkan SIMPLE vs TEMPORAL per SUBJEK

def summarize_by_subject(df_summary):
    df = df_summary.copy()
    df["ratio_frames_with_torso"] = (
        df["n_frames_with_torso"] / df["n_frames_total"]
    )
    return (
        df.groupby("subject")
        .agg({
            "n_frames_total": "sum",
            "n_frames_with_torso": "sum",
            "avg_points_per_torso_frame": "mean",
            "ratio_frames_with_torso": "mean"
        })
    )

# print("=== SIMPLE (cluster terbesar saja) ===")
# df_simple_by_subj = summarize_by_subject(df_torso_summary)
# print(df_simple_by_subj)

print("\n=== TEMPORAL (size + distance) ===")
df_temp_by_subj = summarize_by_subject(df_torso_temp_summary)
print(df_temp_by_subj)
# Out:
# === TEMPORAL (size + distance) ===
#          n_frames_total  n_frames_with_torso  avg_points_per_torso_frame  \
# subject
# Afi                9453                 8540                   27.969310
# Tsamara           12675                11643                   26.459048
# Tsania            10812                 9827                   30.112175
#
#          ratio_frames_with_torso
# subject
# Afi                     0.904585
# Tsamara                 0.917326
# Tsania                  0.906527
