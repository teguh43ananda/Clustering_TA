# %% [markdown]
# 🧩 Cell 1 – Import & Konfigurasi Dasar

# %%
# Cell 1: Import library & konfigurasi dasar

import os
import glob
import numpy as np
import pandas as pd

# Daftar subjek
SUBJECTS = ["Afi", "Tsamara", "Tsania"]

# Folder input: hasil clustering (DBSCAN)
CLUSTER_BASE_DIR = r"E:\1.Clustering_TA\dataset2\hasil_clustering"

# Folder output: hasil torso (branch utama, point cloud torso-only)
TORSO_BASE_DIR = r"E:\0.TA_Teguh\dataset2\hasil_torso"

print("SUBJECTS        :", SUBJECTS)
print("CLUSTER_BASE_DIR:", CLUSTER_BASE_DIR)
print("TORSO_BASE_DIR  :", TORSO_BASE_DIR)
# Out:
# SUBJECTS        : ['Afi', 'Tsamara', 'Tsania']
# CLUSTER_BASE_DIR: E:\1.Clustering_TA\dataset2\hasil_clustering
# TORSO_BASE_DIR  : E:\0.TA_Teguh\dataset2\hasil_torso

# %% [markdown]
# 🧩 Cell 2 – Helper: List file clustering per subjek

# %%
# Cell 2: Fungsi untuk mengambil daftar file clustering per subjek

def list_cluster_files_for_subject(subject_name: str):
    """
    Mengembalikan list path file hasil clustering untuk satu subjek.
    Mengasumsikan struktur:
        E:\1.Clustering_TA\dataset2\hasil_clustering\<SUBJEK>\clustering_JalanN.csv
    """
    subj_dir = os.path.join(CLUSTER_BASE_DIR, subject_name)
    pattern = os.path.join(subj_dir, "clustering_*.csv")
    file_list = sorted(glob.glob(pattern))
    return file_list

# Cek contoh
for subj in SUBJECTS:
    files = list_cluster_files_for_subject(subj)
    print(f"{subj}: {len(files)} file clustering ditemukan.")
    if files:
        print("  Contoh:", files[0])
# Out:
# Afi: 72 file clustering ditemukan.
#   Contoh: E:\1.Clustering_TA\dataset2\hasil_clustering\Afi\clustering_Jalan1.csv
# Tsamara: 72 file clustering ditemukan.
#   Contoh: E:\1.Clustering_TA\dataset2\hasil_clustering\Tsamara\clustering_Jalan1.csv
# Tsania: 72 file clustering ditemukan.
#   Contoh: E:\1.Clustering_TA\dataset2\hasil_clustering\Tsania\clustering_Jalan1.csv

# %% [markdown]
# 🧩 Cell 3 – Helper: Path output torso per file

# %%
# Cell 3: Fungsi untuk membangun path output torso per file

def build_output_torso_path(subject_name: str, cluster_file_path: str) -> str:
    """
    Dari path input clustering, misal:
        E:\1.Clustering_TA\dataset2\hasil_clustering\Afi\clustering_Jalan1.csv
    hasilkan path output:
        E:\0.TA_Teguh\dataset2\hasil_torso\Afi\torso_Jalan1.csv
    """
    fname = os.path.basename(cluster_file_path)     # "clustering_Jalan1.csv"
    # Ganti prefix "clustering_" dengan "torso_"
    if fname.startswith("clustering_"):
        torso_fname = "torso_" + fname[len("clustering_"):]
    else:
        torso_fname = "torso_" + fname

    subj_out_dir = os.path.join(TORSO_BASE_DIR, subject_name)
    os.makedirs(subj_out_dir, exist_ok=True)

    return os.path.join(subj_out_dir, torso_fname)

# Cek contoh path
for subj in SUBJECTS:
    files = list_cluster_files_for_subject(subj)
    if files:
        print(subj, "->", build_output_torso_path(subj, files[0]))
# Out:
# Afi -> E:\0.TA_Teguh\dataset2\hasil_torso\Afi\torso_Jalan1.csv
# Tsamara -> E:\0.TA_Teguh\dataset2\hasil_torso\Tsamara\torso_Jalan1.csv
# Tsania -> E:\0.TA_Teguh\dataset2\hasil_torso\Tsania\torso_Jalan1.csv

# %% [markdown]
# 🧩 Cell 4 – Ekstraksi torso untuk 1 file (versi simple: cluster terbesar per frame)

# %%
# Cell 4: Fungsi ekstraksi torso untuk 1 file clustering (BRANCH 1 - SIMPLE)

REQUIRED_COLUMNS = ["timestamp", "frame", "x", "y", "z", "doppler", "SNR", "cluster_id"]

def extract_torso_for_file(cluster_file_path: str, torso_file_path: str):
    """
    Membaca file hasil clustering (point cloud + cluster_id),
    lalu mengekstrak point cloud torso-only per frame dengan aturan:
      - buang semua titik dengan cluster_id == -1 (noise)
      - kalau ada >1 cluster valid di frame tsb, pilih cluster dengan jumlah titik terbanyak
      - simpan SEMUA titik cluster torso ke file output (tidak dirata-ratakan)

    Output:
      - CSV torso-only (format sama seperti input, tanpa cluster_id kalau mau)
      - summary singkat dicetak ke layar
    """
    print(f"\n=== Proses file clustering: {cluster_file_path}")
    df = pd.read_csv(cluster_file_path)

    # Validasi kolom
    missing = [c for c in REQUIRED_COLUMNS if c not in df.columns]
    if missing:
        raise ValueError(f"File {cluster_file_path} tidak memiliki kolom: {missing}")

    # Info awal
    unique_frames = sorted(df["frame"].unique())
    n_frames_total = len(unique_frames)
    print(f"  Total frame unik dalam file ini: {n_frames_total}")

    # List untuk menampung baris torso
    torso_rows = []

    # Loop per frame
    for frame_id, idx in df.groupby("frame").groups.items():
        df_frame = df.loc[idx]

        # Filter non-noise
        df_valid = df_frame[df_frame["cluster_id"] != -1]

        if df_valid.empty:
            # Frame ini tidak punya cluster valid → no-torso (skip)
            continue

        # Hitung jumlah titik per cluster_id
        counts = df_valid["cluster_id"].value_counts()

        # Pilih cluster dengan jumlah titik terbanyak
        torso_cluster_id = counts.idxmax()
        n_points_torso = counts.max()

        # Ambil semua titik milik cluster torso ini
        df_torso_frame = df_valid[df_valid["cluster_id"] == torso_cluster_id].copy()

        # (Opsional) kalau kamu ingin tetap menyimpan cluster_id, biarkan kolom ini
        # Kalau tidak ingin, uncomment baris di bawah:
        # df_torso_frame = df_torso_frame.drop(columns=["cluster_id"])

        torso_rows.append(df_torso_frame)

    # Gabungkan semua frame torso
    if torso_rows:
        df_torso_all = pd.concat(torso_rows, ignore_index=True)
    else:
        df_torso_all = pd.DataFrame(columns=df.columns)  # bisa kosong

    # Summary per file
    if df_torso_all.empty:
        print("  PERINGATAN: Tidak ada frame yang memiliki torso valid di file ini!")
        n_frames_with_torso = 0
        avg_points_per_torso_frame = 0.0
    else:
        frames_with_torso = df_torso_all["frame"].unique()
        n_frames_with_torso = len(frames_with_torso)
        n_frames_no_torso = n_frames_total - n_frames_with_torso
        avg_points_per_torso_frame = len(df_torso_all) / max(n_frames_with_torso, 1)

        print(f"  Frame dengan torso   : {n_frames_with_torso}")
        print(f"  Frame tanpa torso    : {n_frames_no_torso}")
        print(f"  Rata-rata titik torso/frame: {avg_points_per_torso_frame:.2f}")

    # Simpan ke CSV
    os.makedirs(os.path.dirname(torso_file_path), exist_ok=True)
    df_torso_all.to_csv(torso_file_path, index=False)
    print(f"  >> Disimpan ke: {torso_file_path}")

    # Kembalikan summary untuk agregasi global
    return {
        "file": cluster_file_path,
        "torso_file": torso_file_path,
        "n_frames_total": n_frames_total,
        "n_frames_with_torso": int(n_frames_with_torso),
        "avg_points_per_torso_frame": float(avg_points_per_torso_frame),
    }

# %% [markdown]
# 🧩 Cell 5 – Jalankan torso extraction untuk semua subjek & semua file

# %%
# Cell 5: Jalankan ekstraksi torso (branch utama) untuk semua subjek & semua file

def run_torso_extraction_for_all_subjects():
    """
    Loop semua subjek & semua file clustering,
    jalankan extract_torso_for_file,
    dan kumpulkan summary global.
    """
    summaries = []

    for subj in SUBJECTS:
        print("\n" + "=" * 70)
        print(f"Subjek: {subj}")
        print("=" * 70)

        cluster_files = list_cluster_files_for_subject(subj)
        if not cluster_files:
            print(f"  Tidak ada file clustering untuk subjek {subj}")
            continue

        for cluster_path in cluster_files:
            torso_path = build_output_torso_path(subj, cluster_path)
            summary = extract_torso_for_file(cluster_path, torso_path)
            summary["subject"] = subj
            summaries.append(summary)

    # Buat DataFrame summary global
    if summaries:
        df_summary = pd.DataFrame(summaries)
    else:
        df_summary = pd.DataFrame(
            columns=["subject", "file", "torso_file",
                     "n_frames_total", "n_frames_with_torso",
                     "avg_points_per_torso_frame"]
        )

    return df_summary


# Jalankan ekstraksi torso untuk semua subjek
df_torso_summary = run_torso_extraction_for_all_subjects()

print("\n=== Ringkasan global torso extraction (head) ===")
display(df_torso_summary.head())
# Out:
# ======================================================================
# Subjek: Afi
# ======================================================================
#
# === Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Afi\clustering_Jalan1.csv
#   Total frame unik dalam file ini: 99
#   Frame dengan torso   : 91
#   Frame tanpa torso    : 8
#   Rata-rata titik torso/frame: 20.45
#   >> Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso\Afi\torso_Jalan1.csv
#
# === Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Afi\clustering_Jalan10.csv
#   Total frame unik dalam file ini: 94
#   Frame dengan torso   : 89
#   Frame tanpa torso    : 5
#   Rata-rata titik torso/frame: 23.76
#   >> Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso\Afi\torso_Jalan10.csv
#
# === Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Afi\clustering_Jalan11.csv
#   Total frame unik dalam file ini: 96
#   Frame dengan torso   : 90
#   Frame tanpa torso    : 6
#   Rata-rata titik torso/frame: 19.86
#   >> Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso\Afi\torso_Jalan11.csv
#
# === Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Afi\clustering_Jalan12.csv
#   Total frame unik dalam file ini: 77
#   Frame dengan torso   : 71
#   Frame tanpa torso    : 6
#   Rata-rata titik torso/frame: 29.83
#   >> Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso\Afi\torso_Jalan12.csv
#
# === Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Afi\clustering_Jalan13.csv
#   Total frame unik dalam file ini: 99
#   Frame dengan torso   : 92
#   Frame tanpa torso    : 7
#   Rata-rata titik torso/frame: 24.53
#   >> Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso\Afi\torso_Jalan13.csv
#
# === Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Afi\clustering_Jalan14.csv
#   Total frame unik dalam file ini: 92
#   Frame dengan torso   : 84
#   Frame tanpa torso    : 8
#   Rata-rata titik torso/frame: 25.56
#   >> Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso\Afi\torso_Jalan14.csv
#
# === Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Afi\clustering_Jalan15.csv
#   Total frame unik dalam file ini: 219
#   Frame dengan torso   : 198
#   Frame tanpa torso    : 21
#   Rata-rata titik torso/frame: 27.43
#   >> Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso\Afi\torso_Jalan15.csv
#
# === Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Afi\clustering_Jalan16.csv
#   Total frame unik dalam file ini: 214
#   Frame dengan torso   : 191
#   Frame tanpa torso    : 23
#   Rata-rata titik torso/frame: 34.58
#   >> Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso\Afi\torso_Jalan16.csv
#
# === Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Afi\clustering_Jalan17.csv
#   Total frame unik dalam file ini: 170
#   Frame dengan torso   : 158
#   Frame tanpa torso    : 12
#   Rata-rata titik torso/frame: 36.06
#   >> Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso\Afi\torso_Jalan17.csv
#
# === Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Afi\clustering_Jalan18.csv
#   Total frame unik dalam file ini: 146
#   Frame dengan torso   : 133
#   Frame tanpa torso    : 13
#   Rata-rata titik torso/frame: 42.04
#   >> Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso\Afi\torso_Jalan18.csv
#
# === Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Afi\clustering_Jalan19.csv
#   Total frame unik dalam file ini: 192
#   Frame dengan torso   : 173
#   Frame tanpa torso    : 19
#   Rata-rata titik torso/frame: 28.02
#   >> Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso\Afi\torso_Jalan19.csv
#
# === Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Afi\clustering_Jalan2.csv
#   Total frame unik dalam file ini: 84
#   Frame dengan torso   : 76
#   Frame tanpa torso    : 8
#   Rata-rata titik torso/frame: 36.67
#   >> Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso\Afi\torso_Jalan2.csv
#
# === Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Afi\clustering_Jalan20.csv
#   Total frame unik dalam file ini: 175
#   Frame dengan torso   : 157
#   Frame tanpa torso    : 18
#   Rata-rata titik torso/frame: 31.40
#   >> Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso\Afi\torso_Jalan20.csv
#
# === Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Afi\clustering_Jalan21.csv
#   Total frame unik dalam file ini: 141
#   Frame dengan torso   : 128
#   Frame tanpa torso    : 13
#   Rata-rata titik torso/frame: 38.63
#   >> Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso\Afi\torso_Jalan21.csv
#
# === Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Afi\clustering_Jalan22.csv
#   Total frame unik dalam file ini: 101
#   Frame dengan torso   : 87
#   Frame tanpa torso    : 14
#   Rata-rata titik torso/frame: 40.26
#   >> Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso\Afi\torso_Jalan22.csv
#
# === Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Afi\clustering_Jalan23.csv
#   Total frame unik dalam file ini: 364
#   Frame dengan torso   : 331
#   Frame tanpa torso    : 33
#   Rata-rata titik torso/frame: 22.91
#   >> Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso\Afi\torso_Jalan23.csv
#
# === Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Afi\clustering_Jalan24.csv
#   Total frame unik dalam file ini: 333
#   Frame dengan torso   : 296
#   Frame tanpa torso    : 37
#   Rata-rata titik torso/frame: 30.26
#   >> Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso\Afi\torso_Jalan24.csv
#
# === Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Afi\clustering_Jalan25.csv
#   Total frame unik dalam file ini: 67
#   Frame dengan torso   : 63
#   Frame tanpa torso    : 4
#   Rata-rata titik torso/frame: 20.24
#   >> Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso\Afi\torso_Jalan25.csv
#
# === Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Afi\clustering_Jalan26.csv
#   Total frame unik dalam file ini: 75
#   Frame dengan torso   : 61
#   Frame tanpa torso    : 14
#   Rata-rata titik torso/frame: 28.30
#   >> Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso\Afi\torso_Jalan26.csv
#
# === Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Afi\clustering_Jalan27.csv
#   Total frame unik dalam file ini: 77
#   Frame dengan torso   : 67
#   Frame tanpa torso    : 10
#   Rata-rata titik torso/frame: 18.54
#   >> Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso\Afi\torso_Jalan27.csv
#
# === Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Afi\clustering_Jalan28.csv
#   Total frame unik dalam file ini: 65
#   Frame dengan torso   : 58
#   Frame tanpa torso    : 7
#   Rata-rata titik torso/frame: 16.72
#   >> Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso\Afi\torso_Jalan28.csv
#
# === Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Afi\clustering_Jalan29.csv
#   Total frame unik dalam file ini: 76
#   Frame dengan torso   : 69
#   Frame tanpa torso    : 7
#   Rata-rata titik torso/frame: 16.20
#   >> Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso\Afi\torso_Jalan29.csv
#
# === Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Afi\clustering_Jalan3.csv
#   Total frame unik dalam file ini: 86
#   Frame dengan torso   : 77
#   Frame tanpa torso    : 9
#   Rata-rata titik torso/frame: 23.43
#   >> Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso\Afi\torso_Jalan3.csv
#
# === Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Afi\clustering_Jalan30.csv
#   Total frame unik dalam file ini: 80
#   Frame dengan torso   : 65
#   Frame tanpa torso    : 15
#   Rata-rata titik torso/frame: 18.43
#   >> Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso\Afi\torso_Jalan30.csv
#
# === Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Afi\clustering_Jalan31.csv
#   Total frame unik dalam file ini: 69
#   Frame dengan torso   : 61
#   Frame tanpa torso    : 8
#   Rata-rata titik torso/frame: 26.11
#   >> Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso\Afi\torso_Jalan31.csv
#
# === Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Afi\clustering_Jalan32.csv
#   Total frame unik dalam file ini: 77
#   Frame dengan torso   : 72
#   Frame tanpa torso    : 5
#   Rata-rata titik torso/frame: 53.07
#   >> Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso\Afi\torso_Jalan32.csv
#
# === Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Afi\clustering_Jalan33.csv
#   Total frame unik dalam file ini: 76
#   Frame dengan torso   : 73
#   Frame tanpa torso    : 3
#   Rata-rata titik torso/frame: 27.63
#   >> Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso\Afi\torso_Jalan33.csv
#
# === Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Afi\clustering_Jalan34.csv
#   Total frame unik dalam file ini: 87
#   Frame dengan torso   : 84
#   Frame tanpa torso    : 3
#   Rata-rata titik torso/frame: 22.35
#   >> Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso\Afi\torso_Jalan34.csv
#
# === Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Afi\clustering_Jalan35.csv
#   Total frame unik dalam file ini: 88
#   Frame dengan torso   : 85
#   Frame tanpa torso    : 3
#   Rata-rata titik torso/frame: 20.49
#   >> Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso\Afi\torso_Jalan35.csv
#
# === Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Afi\clustering_Jalan36.csv
#   Total frame unik dalam file ini: 68
#   Frame dengan torso   : 59
#   Frame tanpa torso    : 9
#   Rata-rata titik torso/frame: 21.98
#   >> Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso\Afi\torso_Jalan36.csv
#
# === Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Afi\clustering_Jalan37.csv
#   Total frame unik dalam file ini: 83
#   Frame dengan torso   : 76
#   Frame tanpa torso    : 7
#   Rata-rata titik torso/frame: 27.18
#   >> Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso\Afi\torso_Jalan37.csv
#
# === Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Afi\clustering_Jalan38.csv
#   Total frame unik dalam file ini: 81
#   Frame dengan torso   : 71
#   Frame tanpa torso    : 10
#   Rata-rata titik torso/frame: 23.69
#   >> Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso\Afi\torso_Jalan38.csv
#
# === Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Afi\clustering_Jalan39.csv
#   Total frame unik dalam file ini: 191
#   Frame dengan torso   : 174
#   Frame tanpa torso    : 17
#   Rata-rata titik torso/frame: 27.72
#   >> Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso\Afi\torso_Jalan39.csv
#
# === Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Afi\clustering_Jalan4.csv
#   Total frame unik dalam file ini: 89
#   Frame dengan torso   : 84
#   Frame tanpa torso    : 5
#   Rata-rata titik torso/frame: 15.73
#   >> Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso\Afi\torso_Jalan4.csv
#
# === Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Afi\clustering_Jalan40.csv
#   Total frame unik dalam file ini: 157
#   Frame dengan torso   : 143
#   Frame tanpa torso    : 14
#   Rata-rata titik torso/frame: 32.06
#   >> Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso\Afi\torso_Jalan40.csv
#
# === Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Afi\clustering_Jalan41.csv
#   Total frame unik dalam file ini: 119
#   Frame dengan torso   : 106
#   Frame tanpa torso    : 13
#   Rata-rata titik torso/frame: 42.77
#   >> Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso\Afi\torso_Jalan41.csv
#
# === Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Afi\clustering_Jalan42.csv
#   Total frame unik dalam file ini: 107
#   Frame dengan torso   : 98
#   Frame tanpa torso    : 9
#   Rata-rata titik torso/frame: 35.70
#   >> Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso\Afi\torso_Jalan42.csv
#
# === Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Afi\clustering_Jalan43.csv
#   Total frame unik dalam file ini: 165
#   Frame dengan torso   : 145
#   Frame tanpa torso    : 20
#   Rata-rata titik torso/frame: 26.01
#   >> Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso\Afi\torso_Jalan43.csv
#
# === Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Afi\clustering_Jalan44.csv
#   Total frame unik dalam file ini: 135
#   Frame dengan torso   : 125
#   Frame tanpa torso    : 10
#   Rata-rata titik torso/frame: 28.58
#   >> Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso\Afi\torso_Jalan44.csv
#
# === Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Afi\clustering_Jalan45.csv
#   Total frame unik dalam file ini: 120
#   Frame dengan torso   : 112
#   Frame tanpa torso    : 8
#   Rata-rata titik torso/frame: 37.49
#   >> Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso\Afi\torso_Jalan45.csv
#
# === Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Afi\clustering_Jalan46.csv
#   Total frame unik dalam file ini: 77
#   Frame dengan torso   : 70
#   Frame tanpa torso    : 7
#   Rata-rata titik torso/frame: 44.00
#   >> Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso\Afi\torso_Jalan46.csv
#
# === Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Afi\clustering_Jalan47.csv
#   Total frame unik dalam file ini: 290
#   Frame dengan torso   : 263
#   Frame tanpa torso    : 27
#   Rata-rata titik torso/frame: 24.63
#   >> Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso\Afi\torso_Jalan47.csv
#
# === Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Afi\clustering_Jalan48.csv
#   Total frame unik dalam file ini: 274
#   Frame dengan torso   : 241
#   Frame tanpa torso    : 33
#   Rata-rata titik torso/frame: 31.79
#   >> Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso\Afi\torso_Jalan48.csv
#
# === Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Afi\clustering_Jalan49.csv
#   Total frame unik dalam file ini: 92
#   Frame dengan torso   : 88
#   Frame tanpa torso    : 4
#   Rata-rata titik torso/frame: 18.48
#   >> Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso\Afi\torso_Jalan49.csv
#
# === Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Afi\clustering_Jalan5.csv
#   Total frame unik dalam file ini: 87
#   Frame dengan torso   : 82
#   Frame tanpa torso    : 5
#   Rata-rata titik torso/frame: 16.16
#   >> Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso\Afi\torso_Jalan5.csv
#
# === Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Afi\clustering_Jalan50.csv
#   Total frame unik dalam file ini: 89
#   Frame dengan torso   : 76
#   Frame tanpa torso    : 13
#   Rata-rata titik torso/frame: 31.34
#   >> Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso\Afi\torso_Jalan50.csv
#
# === Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Afi\clustering_Jalan51.csv
#   Total frame unik dalam file ini: 88
#   Frame dengan torso   : 79
#   Frame tanpa torso    : 9
#   Rata-rata titik torso/frame: 18.41
#   >> Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso\Afi\torso_Jalan51.csv
#
# === Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Afi\clustering_Jalan52.csv
#   Total frame unik dalam file ini: 91
#   Frame dengan torso   : 87
#   Frame tanpa torso    : 4
#   Rata-rata titik torso/frame: 13.86
#   >> Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso\Afi\torso_Jalan52.csv
#
# === Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Afi\clustering_Jalan53.csv
#   Total frame unik dalam file ini: 102
#   Frame dengan torso   : 94
#   Frame tanpa torso    : 8
#   Rata-rata titik torso/frame: 13.37
#   >> Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso\Afi\torso_Jalan53.csv
#
# === Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Afi\clustering_Jalan54.csv
#   Total frame unik dalam file ini: 90
#   Frame dengan torso   : 84
#   Frame tanpa torso    : 6
#   Rata-rata titik torso/frame: 18.15
#   >> Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso\Afi\torso_Jalan54.csv
#
# === Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Afi\clustering_Jalan55.csv
#   Total frame unik dalam file ini: 101
#   Frame dengan torso   : 92
#   Frame tanpa torso    : 9
#   Rata-rata titik torso/frame: 25.99
#   >> Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso\Afi\torso_Jalan55.csv
#
# === Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Afi\clustering_Jalan56.csv
#   Total frame unik dalam file ini: 115
#   Frame dengan torso   : 104
#   Frame tanpa torso    : 11
#   Rata-rata titik torso/frame: 26.25
#   >> Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso\Afi\torso_Jalan56.csv
#
# === Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Afi\clustering_Jalan57.csv
#   Total frame unik dalam file ini: 115
#   Frame dengan torso   : 99
#   Frame tanpa torso    : 16
#   Rata-rata titik torso/frame: 24.90
#   >> Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso\Afi\torso_Jalan57.csv
#
# === Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Afi\clustering_Jalan58.csv
#   Total frame unik dalam file ini: 121
#   Frame dengan torso   : 114
#   Frame tanpa torso    : 7
#   Rata-rata titik torso/frame: 25.61
#   >> Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso\Afi\torso_Jalan58.csv
#
# === Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Afi\clustering_Jalan59.csv
#   Total frame unik dalam file ini: 120
#   Frame dengan torso   : 83
#   Frame tanpa torso    : 37
#   Rata-rata titik torso/frame: 25.27
#   >> Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso\Afi\torso_Jalan59.csv
#
# === Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Afi\clustering_Jalan6.csv
#   Total frame unik dalam file ini: 101
#   Frame dengan torso   : 90
#   Frame tanpa torso    : 11
#   Rata-rata titik torso/frame: 21.87
#   >> Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso\Afi\torso_Jalan6.csv
#
# === Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Afi\clustering_Jalan60.csv
#   Total frame unik dalam file ini: 108
#   Frame dengan torso   : 101
#   Frame tanpa torso    : 7
#   Rata-rata titik torso/frame: 22.70
#   >> Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso\Afi\torso_Jalan60.csv
#
# === Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Afi\clustering_Jalan61.csv
#   Total frame unik dalam file ini: 136
#   Frame dengan torso   : 126
#   Frame tanpa torso    : 10
#   Rata-rata titik torso/frame: 28.40
#   >> Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso\Afi\torso_Jalan61.csv
#
# === Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Afi\clustering_Jalan62.csv
#   Total frame unik dalam file ini: 97
#   Frame dengan torso   : 84
#   Frame tanpa torso    : 13
#   Rata-rata titik torso/frame: 36.05
#   >> Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso\Afi\torso_Jalan62.csv
#
# === Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Afi\clustering_Jalan63.csv
#   Total frame unik dalam file ini: 209
#   Frame dengan torso   : 188
#   Frame tanpa torso    : 21
#   Rata-rata titik torso/frame: 29.12
#   >> Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso\Afi\torso_Jalan63.csv
#
# === Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Afi\clustering_Jalan64.csv
#   Total frame unik dalam file ini: 155
#   Frame dengan torso   : 137
#   Frame tanpa torso    : 18
#   Rata-rata titik torso/frame: 36.09
#   >> Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso\Afi\torso_Jalan64.csv
#
# === Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Afi\clustering_Jalan65.csv
#   Total frame unik dalam file ini: 146
#   Frame dengan torso   : 126
#   Frame tanpa torso    : 20
#   Rata-rata titik torso/frame: 38.08
#   >> Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso\Afi\torso_Jalan65.csv
#
# === Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Afi\clustering_Jalan66.csv
#   Total frame unik dalam file ini: 139
#   Frame dengan torso   : 125
#   Frame tanpa torso    : 14
#   Rata-rata titik torso/frame: 41.28
#   >> Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso\Afi\torso_Jalan66.csv
#
# === Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Afi\clustering_Jalan67.csv
#   Total frame unik dalam file ini: 193
#   Frame dengan torso   : 167
#   Frame tanpa torso    : 26
#   Rata-rata titik torso/frame: 28.75
#   >> Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso\Afi\torso_Jalan67.csv
#
# === Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Afi\clustering_Jalan68.csv
#   Total frame unik dalam file ini: 160
#   Frame dengan torso   : 143
#   Frame tanpa torso    : 17
#   Rata-rata titik torso/frame: 31.52
#   >> Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso\Afi\torso_Jalan68.csv
#
# === Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Afi\clustering_Jalan69.csv
#   Total frame unik dalam file ini: 131
#   Frame dengan torso   : 116
#   Frame tanpa torso    : 15
#   Rata-rata titik torso/frame: 43.54
#   >> Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso\Afi\torso_Jalan69.csv
#
# === Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Afi\clustering_Jalan7.csv
#   Total frame unik dalam file ini: 95
#   Frame dengan torso   : 90
#   Frame tanpa torso    : 5
#   Rata-rata titik torso/frame: 27.50
#   >> Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso\Afi\torso_Jalan7.csv
#
# === Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Afi\clustering_Jalan70.csv
#   Total frame unik dalam file ini: 111
#   Frame dengan torso   : 105
#   Frame tanpa torso    : 6
#   Rata-rata titik torso/frame: 41.68
#   >> Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso\Afi\torso_Jalan70.csv
#
# === Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Afi\clustering_Jalan71.csv
#   Total frame unik dalam file ini: 354
#   Frame dengan torso   : 325
#   Frame tanpa torso    : 29
#   Rata-rata titik torso/frame: 22.95
#   >> Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso\Afi\torso_Jalan71.csv
#
# === Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Afi\clustering_Jalan72.csv
#   Total frame unik dalam file ini: 308
#   Frame dengan torso   : 284
#   Frame tanpa torso    : 24
#   Rata-rata titik torso/frame: 32.24
#   >> Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso\Afi\torso_Jalan72.csv
#
# === Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Afi\clustering_Jalan8.csv
#   Total frame unik dalam file ini: 126
#   Frame dengan torso   : 110
#   Frame tanpa torso    : 16
#   Rata-rata titik torso/frame: 21.17
#   >> Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso\Afi\torso_Jalan8.csv
#
# === Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Afi\clustering_Jalan9.csv
#   Total frame unik dalam file ini: 98
#   Frame dengan torso   : 94
#   Frame tanpa torso    : 4
#   Rata-rata titik torso/frame: 31.10
#   >> Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso\Afi\torso_Jalan9.csv
#
# ======================================================================
# Subjek: Tsamara
# ======================================================================
#
# === Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Tsamara\clustering_Jalan1.csv
#   Total frame unik dalam file ini: 91
#   Frame dengan torso   : 83
#   Frame tanpa torso    : 8
#   Rata-rata titik torso/frame: 22.47
#   >> Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso\Tsamara\torso_Jalan1.csv
#
# === Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Tsamara\clustering_Jalan10.csv
#   Total frame unik dalam file ini: 137
#   Frame dengan torso   : 129
#   Frame tanpa torso    : 8
#   Rata-rata titik torso/frame: 26.88
#   >> Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso\Tsamara\torso_Jalan10.csv
#
# === Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Tsamara\clustering_Jalan11.csv
#   Total frame unik dalam file ini: 130
#   Frame dengan torso   : 122
#   Frame tanpa torso    : 8
#   Rata-rata titik torso/frame: 27.47
#   >> Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso\Tsamara\torso_Jalan11.csv
#
# === Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Tsamara\clustering_Jalan12.csv
#   Total frame unik dalam file ini: 110
#   Frame dengan torso   : 103
#   Frame tanpa torso    : 7
#   Rata-rata titik torso/frame: 22.46
#   >> Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso\Tsamara\torso_Jalan12.csv
#
# === Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Tsamara\clustering_Jalan13.csv
#   Total frame unik dalam file ini: 139
#   Frame dengan torso   : 127
#   Frame tanpa torso    : 12
#   Rata-rata titik torso/frame: 23.44
#   >> Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso\Tsamara\torso_Jalan13.csv
#
# === Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Tsamara\clustering_Jalan14.csv
#   Total frame unik dalam file ini: 113
#   Frame dengan torso   : 104
#   Frame tanpa torso    : 9
#   Rata-rata titik torso/frame: 32.81
#   >> Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso\Tsamara\torso_Jalan14.csv
#
# === Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Tsamara\clustering_Jalan15.csv
#   Total frame unik dalam file ini: 321
#   Frame dengan torso   : 301
#   Frame tanpa torso    : 20
#   Rata-rata titik torso/frame: 20.44
#   >> Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso\Tsamara\torso_Jalan15.csv
#
# === Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Tsamara\clustering_Jalan16.csv
#   Total frame unik dalam file ini: 249
#   Frame dengan torso   : 228
#   Frame tanpa torso    : 21
#   Rata-rata titik torso/frame: 26.74
#   >> Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso\Tsamara\torso_Jalan16.csv
#
# === Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Tsamara\clustering_Jalan17.csv
#   Total frame unik dalam file ini: 228
#   Frame dengan torso   : 215
#   Frame tanpa torso    : 13
#   Rata-rata titik torso/frame: 26.31
#   >> Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso\Tsamara\torso_Jalan17.csv
#
# === Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Tsamara\clustering_Jalan18.csv
#   Total frame unik dalam file ini: 163
#   Frame dengan torso   : 151
#   Frame tanpa torso    : 12
#   Rata-rata titik torso/frame: 37.09
#   >> Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso\Tsamara\torso_Jalan18.csv
#
# === Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Tsamara\clustering_Jalan19.csv
#   Total frame unik dalam file ini: 274
#   Frame dengan torso   : 240
#   Frame tanpa torso    : 34
#   Rata-rata titik torso/frame: 25.05
#   >> Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso\Tsamara\torso_Jalan19.csv
#
# === Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Tsamara\clustering_Jalan2.csv
#   Total frame unik dalam file ini: 99
#   Frame dengan torso   : 94
#   Frame tanpa torso    : 5
#   Rata-rata titik torso/frame: 39.68
#   >> Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso\Tsamara\torso_Jalan2.csv
#
# === Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Tsamara\clustering_Jalan20.csv
#   Total frame unik dalam file ini: 262
#   Frame dengan torso   : 218
#   Frame tanpa torso    : 44
#   Rata-rata titik torso/frame: 33.70
#   >> Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso\Tsamara\torso_Jalan20.csv
#
# === Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Tsamara\clustering_Jalan21.csv
#   Total frame unik dalam file ini: 194
#   Frame dengan torso   : 183
#   Frame tanpa torso    : 11
#   Rata-rata titik torso/frame: 34.70
#   >> Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso\Tsamara\torso_Jalan21.csv
#
# === Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Tsamara\clustering_Jalan22.csv
#   Total frame unik dalam file ini: 176
#   Frame dengan torso   : 165
#   Frame tanpa torso    : 11
#   Rata-rata titik torso/frame: 32.56
#   >> Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso\Tsamara\torso_Jalan22.csv
#
# === Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Tsamara\clustering_Jalan23.csv
#   Total frame unik dalam file ini: 571
#   Frame dengan torso   : 547
#   Frame tanpa torso    : 24
#   Rata-rata titik torso/frame: 22.78
#   >> Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso\Tsamara\torso_Jalan23.csv
#
# === Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Tsamara\clustering_Jalan24.csv
#   Total frame unik dalam file ini: 489
#   Frame dengan torso   : 455
#   Frame tanpa torso    : 34
#   Rata-rata titik torso/frame: 26.36
#   >> Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso\Tsamara\torso_Jalan24.csv
#
# === Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Tsamara\clustering_Jalan25.csv
#   Total frame unik dalam file ini: 87
#   Frame dengan torso   : 81
#   Frame tanpa torso    : 6
#   Rata-rata titik torso/frame: 16.44
#   >> Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso\Tsamara\torso_Jalan25.csv
#
# === Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Tsamara\clustering_Jalan26.csv
#   Total frame unik dalam file ini: 92
#   Frame dengan torso   : 88
#   Frame tanpa torso    : 4
#   Rata-rata titik torso/frame: 38.57
#   >> Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso\Tsamara\torso_Jalan26.csv
#
# === Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Tsamara\clustering_Jalan27.csv
#   Total frame unik dalam file ini: 100
#   Frame dengan torso   : 90
#   Frame tanpa torso    : 10
#   Rata-rata titik torso/frame: 21.51
#   >> Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso\Tsamara\torso_Jalan27.csv
#
# === Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Tsamara\clustering_Jalan28.csv
#   Total frame unik dalam file ini: 90
#   Frame dengan torso   : 85
#   Frame tanpa torso    : 5
#   Rata-rata titik torso/frame: 24.93
#   >> Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso\Tsamara\torso_Jalan28.csv
#
# === Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Tsamara\clustering_Jalan29.csv
#   Total frame unik dalam file ini: 80
#   Frame dengan torso   : 76
#   Frame tanpa torso    : 4
#   Rata-rata titik torso/frame: 13.78
#   >> Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso\Tsamara\torso_Jalan29.csv
#
# === Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Tsamara\clustering_Jalan3.csv
#   Total frame unik dalam file ini: 89
#   Frame dengan torso   : 83
#   Frame tanpa torso    : 6
#   Rata-rata titik torso/frame: 28.63
#   >> Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso\Tsamara\torso_Jalan3.csv
#
# === Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Tsamara\clustering_Jalan30.csv
#   Total frame unik dalam file ini: 86
#   Frame dengan torso   : 78
#   Frame tanpa torso    : 8
#   Rata-rata titik torso/frame: 18.23
#   >> Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso\Tsamara\torso_Jalan30.csv
#
# === Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Tsamara\clustering_Jalan31.csv
#   Total frame unik dalam file ini: 82
#   Frame dengan torso   : 78
#   Frame tanpa torso    : 4
#   Rata-rata titik torso/frame: 26.53
#   >> Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso\Tsamara\torso_Jalan31.csv
#
# === Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Tsamara\clustering_Jalan32.csv
#   Total frame unik dalam file ini: 96
#   Frame dengan torso   : 90
#   Frame tanpa torso    : 6
#   Rata-rata titik torso/frame: 28.32
#   >> Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso\Tsamara\torso_Jalan32.csv
#
# === Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Tsamara\clustering_Jalan33.csv
#   Total frame unik dalam file ini: 86
#   Frame dengan torso   : 79
#   Frame tanpa torso    : 7
#   Rata-rata titik torso/frame: 27.19
#   >> Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso\Tsamara\torso_Jalan33.csv
#
# === Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Tsamara\clustering_Jalan34.csv
#   Total frame unik dalam file ini: 110
#   Frame dengan torso   : 106
#   Frame tanpa torso    : 4
#   Rata-rata titik torso/frame: 24.40
#   >> Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso\Tsamara\torso_Jalan34.csv
#
# === Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Tsamara\clustering_Jalan35.csv
#   Total frame unik dalam file ini: 87
#   Frame dengan torso   : 83
#   Frame tanpa torso    : 4
#   Rata-rata titik torso/frame: 24.70
#   >> Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso\Tsamara\torso_Jalan35.csv
#
# === Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Tsamara\clustering_Jalan36.csv
#   Total frame unik dalam file ini: 94
#   Frame dengan torso   : 82
#   Frame tanpa torso    : 12
#   Rata-rata titik torso/frame: 19.23
#   >> Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso\Tsamara\torso_Jalan36.csv
#
# === Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Tsamara\clustering_Jalan37.csv
#   Total frame unik dalam file ini: 114
#   Frame dengan torso   : 105
#   Frame tanpa torso    : 9
#   Rata-rata titik torso/frame: 20.97
#   >> Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso\Tsamara\torso_Jalan37.csv
#
# === Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Tsamara\clustering_Jalan38.csv
#   Total frame unik dalam file ini: 105
#   Frame dengan torso   : 84
#   Frame tanpa torso    : 21
#   Rata-rata titik torso/frame: 20.67
#   >> Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso\Tsamara\torso_Jalan38.csv
#
# === Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Tsamara\clustering_Jalan39.csv
#   Total frame unik dalam file ini: 187
#   Frame dengan torso   : 176
#   Frame tanpa torso    : 11
#   Rata-rata titik torso/frame: 23.60
#   >> Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso\Tsamara\torso_Jalan39.csv
#
# === Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Tsamara\clustering_Jalan4.csv
#   Total frame unik dalam file ini: 111
#   Frame dengan torso   : 104
#   Frame tanpa torso    : 7
#   Rata-rata titik torso/frame: 28.31
#   >> Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso\Tsamara\torso_Jalan4.csv
#
# === Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Tsamara\clustering_Jalan40.csv
#   Total frame unik dalam file ini: 182
#   Frame dengan torso   : 153
#   Frame tanpa torso    : 29
#   Rata-rata titik torso/frame: 23.46
#   >> Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso\Tsamara\torso_Jalan40.csv
#
# === Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Tsamara\clustering_Jalan41.csv
#   Total frame unik dalam file ini: 164
#   Frame dengan torso   : 153
#   Frame tanpa torso    : 11
#   Rata-rata titik torso/frame: 28.86
#   >> Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso\Tsamara\torso_Jalan41.csv
#
# === Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Tsamara\clustering_Jalan42.csv
#   Total frame unik dalam file ini: 160
#   Frame dengan torso   : 144
#   Frame tanpa torso    : 16
#   Rata-rata titik torso/frame: 28.57
#   >> Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso\Tsamara\torso_Jalan42.csv
#
# === Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Tsamara\clustering_Jalan43.csv
#   Total frame unik dalam file ini: 160
#   Frame dengan torso   : 144
#   Frame tanpa torso    : 16
#   Rata-rata titik torso/frame: 27.81
#   >> Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso\Tsamara\torso_Jalan43.csv
#
# === Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Tsamara\clustering_Jalan44.csv
#   Total frame unik dalam file ini: 137
#   Frame dengan torso   : 125
#   Frame tanpa torso    : 12
#   Rata-rata titik torso/frame: 33.12
#   >> Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso\Tsamara\torso_Jalan44.csv
#
# === Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Tsamara\clustering_Jalan45.csv
#   Total frame unik dalam file ini: 149
#   Frame dengan torso   : 133
#   Frame tanpa torso    : 16
#   Rata-rata titik torso/frame: 27.97
#   >> Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso\Tsamara\torso_Jalan45.csv
#
# === Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Tsamara\clustering_Jalan46.csv
#   Total frame unik dalam file ini: 140
#   Frame dengan torso   : 122
#   Frame tanpa torso    : 18
#   Rata-rata titik torso/frame: 39.03
#   >> Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso\Tsamara\torso_Jalan46.csv
#
# === Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Tsamara\clustering_Jalan47.csv
#   Total frame unik dalam file ini: 301
#   Frame dengan torso   : 276
#   Frame tanpa torso    : 25
#   Rata-rata titik torso/frame: 24.72
#   >> Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso\Tsamara\torso_Jalan47.csv
#
# === Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Tsamara\clustering_Jalan48.csv
#   Total frame unik dalam file ini: 287
#   Frame dengan torso   : 270
#   Frame tanpa torso    : 17
#   Rata-rata titik torso/frame: 29.70
#   >> Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso\Tsamara\torso_Jalan48.csv
#
# === Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Tsamara\clustering_Jalan49.csv
#   Total frame unik dalam file ini: 155
#   Frame dengan torso   : 140
#   Frame tanpa torso    : 15
#   Rata-rata titik torso/frame: 21.76
#   >> Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso\Tsamara\torso_Jalan49.csv
#
# === Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Tsamara\clustering_Jalan5.csv
#   Total frame unik dalam file ini: 105
#   Frame dengan torso   : 94
#   Frame tanpa torso    : 11
#   Rata-rata titik torso/frame: 15.16
#   >> Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso\Tsamara\torso_Jalan5.csv
#
# === Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Tsamara\clustering_Jalan50.csv
#   Total frame unik dalam file ini: 129
#   Frame dengan torso   : 125
#   Frame tanpa torso    : 4
#   Rata-rata titik torso/frame: 48.48
#   >> Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso\Tsamara\torso_Jalan50.csv
#
# === Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Tsamara\clustering_Jalan51.csv
#   Total frame unik dalam file ini: 152
#   Frame dengan torso   : 131
#   Frame tanpa torso    : 21
#   Rata-rata titik torso/frame: 33.76
#   >> Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso\Tsamara\torso_Jalan51.csv
#
# === Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Tsamara\clustering_Jalan52.csv
#   Total frame unik dalam file ini: 135
#   Frame dengan torso   : 115
#   Frame tanpa torso    : 20
#   Rata-rata titik torso/frame: 27.36
#   >> Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso\Tsamara\torso_Jalan52.csv
#
# === Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Tsamara\clustering_Jalan53.csv
#   Total frame unik dalam file ini: 132
#   Frame dengan torso   : 127
#   Frame tanpa torso    : 5
#   Rata-rata titik torso/frame: 13.35
#   >> Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso\Tsamara\torso_Jalan53.csv
#
# === Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Tsamara\clustering_Jalan54.csv
#   Total frame unik dalam file ini: 149
#   Frame dengan torso   : 139
#   Frame tanpa torso    : 10
#   Rata-rata titik torso/frame: 17.29
#   >> Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso\Tsamara\torso_Jalan54.csv
#
# === Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Tsamara\clustering_Jalan55.csv
#   Total frame unik dalam file ini: 163
#   Frame dengan torso   : 148
#   Frame tanpa torso    : 15
#   Rata-rata titik torso/frame: 25.56
#   >> Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso\Tsamara\torso_Jalan55.csv
#
# === Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Tsamara\clustering_Jalan56.csv
#   Total frame unik dalam file ini: 157
#   Frame dengan torso   : 150
#   Frame tanpa torso    : 7
#   Rata-rata titik torso/frame: 25.43
#   >> Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso\Tsamara\torso_Jalan56.csv
#
# === Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Tsamara\clustering_Jalan57.csv
#   Total frame unik dalam file ini: 120
#   Frame dengan torso   : 114
#   Frame tanpa torso    : 6
#   Rata-rata titik torso/frame: 37.08
#   >> Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso\Tsamara\torso_Jalan57.csv
#
# === Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Tsamara\clustering_Jalan58.csv
#   Total frame unik dalam file ini: 184
#   Frame dengan torso   : 170
#   Frame tanpa torso    : 14
#   Rata-rata titik torso/frame: 22.23
#   >> Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso\Tsamara\torso_Jalan58.csv
#
# === Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Tsamara\clustering_Jalan59.csv
#   Total frame unik dalam file ini: 117
#   Frame dengan torso   : 110
#   Frame tanpa torso    : 7
#   Rata-rata titik torso/frame: 25.94
#   >> Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso\Tsamara\torso_Jalan59.csv
#
# === Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Tsamara\clustering_Jalan6.csv
#   Total frame unik dalam file ini: 117
#   Frame dengan torso   : 104
#   Frame tanpa torso    : 13
#   Rata-rata titik torso/frame: 17.16
#   >> Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso\Tsamara\torso_Jalan6.csv
#
# === Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Tsamara\clustering_Jalan60.csv
#   Total frame unik dalam file ini: 125
#   Frame dengan torso   : 112
#   Frame tanpa torso    : 13
#   Rata-rata titik torso/frame: 17.79
#   >> Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso\Tsamara\torso_Jalan60.csv
#
# === Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Tsamara\clustering_Jalan61.csv
#   Total frame unik dalam file ini: 162
#   Frame dengan torso   : 143
#   Frame tanpa torso    : 19
#   Rata-rata titik torso/frame: 29.22
#   >> Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso\Tsamara\torso_Jalan61.csv
#
# === Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Tsamara\clustering_Jalan62.csv
#   Total frame unik dalam file ini: 132
#   Frame dengan torso   : 116
#   Frame tanpa torso    : 16
#   Rata-rata titik torso/frame: 30.82
#   >> Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso\Tsamara\torso_Jalan62.csv
#
# === Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Tsamara\clustering_Jalan63.csv
#   Total frame unik dalam file ini: 348
#   Frame dengan torso   : 318
#   Frame tanpa torso    : 30
#   Rata-rata titik torso/frame: 21.01
#   >> Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso\Tsamara\torso_Jalan63.csv
#
# === Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Tsamara\clustering_Jalan64.csv
#   Total frame unik dalam file ini: 349
#   Frame dengan torso   : 321
#   Frame tanpa torso    : 28
#   Rata-rata titik torso/frame: 27.69
#   >> Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso\Tsamara\torso_Jalan64.csv
#
# === Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Tsamara\clustering_Jalan65.csv
#   Total frame unik dalam file ini: 215
#   Frame dengan torso   : 207
#   Frame tanpa torso    : 8
#   Rata-rata titik torso/frame: 25.97
#   >> Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso\Tsamara\torso_Jalan65.csv
#
# === Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Tsamara\clustering_Jalan66.csv
#   Total frame unik dalam file ini: 177
#   Frame dengan torso   : 167
#   Frame tanpa torso    : 10
#   Rata-rata titik torso/frame: 34.29
#   >> Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso\Tsamara\torso_Jalan66.csv
#
# === Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Tsamara\clustering_Jalan67.csv
#   Total frame unik dalam file ini: 270
#   Frame dengan torso   : 252
#   Frame tanpa torso    : 18
#   Rata-rata titik torso/frame: 23.44
#   >> Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso\Tsamara\torso_Jalan67.csv
#
# === Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Tsamara\clustering_Jalan68.csv
#   Total frame unik dalam file ini: 255
#   Frame dengan torso   : 234
#   Frame tanpa torso    : 21
#   Rata-rata titik torso/frame: 21.68
#   >> Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso\Tsamara\torso_Jalan68.csv
#
# === Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Tsamara\clustering_Jalan69.csv
#   Total frame unik dalam file ini: 180
#   Frame dengan torso   : 161
#   Frame tanpa torso    : 19
#   Rata-rata titik torso/frame: 27.29
#   >> Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso\Tsamara\torso_Jalan69.csv
#
# === Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Tsamara\clustering_Jalan7.csv
#   Total frame unik dalam file ini: 124
#   Frame dengan torso   : 104
#   Frame tanpa torso    : 20
#   Rata-rata titik torso/frame: 20.67
#   >> Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso\Tsamara\torso_Jalan7.csv
#
# === Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Tsamara\clustering_Jalan70.csv
#   Total frame unik dalam file ini: 162
#   Frame dengan torso   : 150
#   Frame tanpa torso    : 12
#   Rata-rata titik torso/frame: 33.55
#   >> Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso\Tsamara\torso_Jalan70.csv
#
# === Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Tsamara\clustering_Jalan71.csv
#   Total frame unik dalam file ini: 506
#   Frame dengan torso   : 471
#   Frame tanpa torso    : 35
#   Rata-rata titik torso/frame: 22.95
#   >> Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso\Tsamara\torso_Jalan71.csv
#
# === Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Tsamara\clustering_Jalan72.csv
#   Total frame unik dalam file ini: 502
#   Frame dengan torso   : 457
#   Frame tanpa torso    : 45
#   Rata-rata titik torso/frame: 28.47
#   >> Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso\Tsamara\torso_Jalan72.csv
#
# === Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Tsamara\clustering_Jalan8.csv
#   Total frame unik dalam file ini: 130
#   Frame dengan torso   : 118
#   Frame tanpa torso    : 12
#   Rata-rata titik torso/frame: 23.68
#   >> Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso\Tsamara\torso_Jalan8.csv
#
# === Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Tsamara\clustering_Jalan9.csv
#   Total frame unik dalam file ini: 101
#   Frame dengan torso   : 92
#   Frame tanpa torso    : 9
#   Rata-rata titik torso/frame: 35.99
#   >> Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso\Tsamara\torso_Jalan9.csv
#
# ======================================================================
# Subjek: Tsania
# ======================================================================
#
# === Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Tsania\clustering_Jalan1.csv
#   Total frame unik dalam file ini: 82
#   Frame dengan torso   : 67
#   Frame tanpa torso    : 15
#   Rata-rata titik torso/frame: 30.33
#   >> Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso\Tsania\torso_Jalan1.csv
#
# === Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Tsania\clustering_Jalan10.csv
#   Total frame unik dalam file ini: 134
#   Frame dengan torso   : 120
#   Frame tanpa torso    : 14
#   Rata-rata titik torso/frame: 20.94
#   >> Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso\Tsania\torso_Jalan10.csv
#
# === Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Tsania\clustering_Jalan11.csv
#   Total frame unik dalam file ini: 113
#   Frame dengan torso   : 104
#   Frame tanpa torso    : 9
#   Rata-rata titik torso/frame: 50.39
#   >> Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso\Tsania\torso_Jalan11.csv
#
# === Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Tsania\clustering_Jalan12.csv
#   Total frame unik dalam file ini: 101
#   Frame dengan torso   : 85
#   Frame tanpa torso    : 16
#   Rata-rata titik torso/frame: 23.06
#   >> Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso\Tsania\torso_Jalan12.csv
#
# === Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Tsania\clustering_Jalan13.csv
#   Total frame unik dalam file ini: 120
#   Frame dengan torso   : 114
#   Frame tanpa torso    : 6
#   Rata-rata titik torso/frame: 31.69
#   >> Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso\Tsania\torso_Jalan13.csv
#
# === Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Tsania\clustering_Jalan14.csv
#   Total frame unik dalam file ini: 120
#   Frame dengan torso   : 107
#   Frame tanpa torso    : 13
#   Rata-rata titik torso/frame: 27.56
#   >> Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso\Tsania\torso_Jalan14.csv
#
# === Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Tsania\clustering_Jalan15.csv
#   Total frame unik dalam file ini: 256
#   Frame dengan torso   : 237
#   Frame tanpa torso    : 19
#   Rata-rata titik torso/frame: 25.53
#   >> Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso\Tsania\torso_Jalan15.csv
#
# === Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Tsania\clustering_Jalan16.csv
#   Total frame unik dalam file ini: 267
#   Frame dengan torso   : 247
#   Frame tanpa torso    : 20
#   Rata-rata titik torso/frame: 24.49
#   >> Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso\Tsania\torso_Jalan16.csv
#
# === Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Tsania\clustering_Jalan17.csv
#   Total frame unik dalam file ini: 189
# ...
#
# === Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Tsania\clustering_Jalan32.csv
#   Total frame unik dalam file ini: 71
#   Frame dengan torso   : 69
#   Frame tanpa torso    : 2
#   Rata-rata titik torso/frame: 28.35
#   >> Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso\Tsania\torso_Jalan32.csv
#
# === Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Tsania\clustering_Jalan33.csv
#   Total frame unik dalam file ini: 90
#   Frame dengan torso   : 81
#   Frame tanpa torso    : 9
#   Rata-rata titik torso/frame: 24.63
#   >> Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso\Tsania\torso_Jalan33.csv
#
# === Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Tsania\clustering_Jalan34.csv
#   Total frame unik dalam file ini: 97
#   Frame dengan torso   : 92
#   Frame tanpa torso    : 5
#   Rata-rata titik torso/frame: 19.77
#   >> Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso\Tsania\torso_Jalan34.csv
#
# === Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Tsania\clustering_Jalan35.csv
#   Total frame unik dalam file ini: 88
#   Frame dengan torso   : 85
#   Frame tanpa torso    : 3
#   Rata-rata titik torso/frame: 20.26
#   >> Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso\Tsania\torso_Jalan35.csv
#
# === Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Tsania\clustering_Jalan36.csv
#   Total frame unik dalam file ini: 102
#   Frame dengan torso   : 84
#   Frame tanpa torso    : 18
#   Rata-rata titik torso/frame: 23.65
#   >> Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso\Tsania\torso_Jalan36.csv
#
# === Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Tsania\clustering_Jalan37.csv
#   Total frame unik dalam file ini: 107
#   Frame dengan torso   : 99
#   Frame tanpa torso    : 8
#   Rata-rata titik torso/frame: 23.65
#   >> Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso\Tsania\torso_Jalan37.csv
#
# === Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Tsania\clustering_Jalan38.csv
#   Total frame unik dalam file ini: 99
#   Frame dengan torso   : 90
#   Frame tanpa torso    : 9
#   Rata-rata titik torso/frame: 19.91
#   >> Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso\Tsania\torso_Jalan38.csv
#
# === Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Tsania\clustering_Jalan39.csv
#   Total frame unik dalam file ini: 177
#   Frame dengan torso   : 155
#   Frame tanpa torso    : 22
#   Rata-rata titik torso/frame: 22.85
#   >> Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso\Tsania\torso_Jalan39.csv
#
# === Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Tsania\clustering_Jalan4.csv
#   Total frame unik dalam file ini: 93
#   Frame dengan torso   : 89
#   Frame tanpa torso    : 4
#   Rata-rata titik torso/frame: 16.84
#   >> Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso\Tsania\torso_Jalan4.csv
#
# === Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Tsania\clustering_Jalan40.csv
#   Total frame unik dalam file ini: 166
#   Frame dengan torso   : 152
#   Frame tanpa torso    : 14
#   Rata-rata titik torso/frame: 32.10
#   >> Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso\Tsania\torso_Jalan40.csv
#
# === Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Tsania\clustering_Jalan41.csv
#   Total frame unik dalam file ini: 147
#   Frame dengan torso   : 136
#   Frame tanpa torso    : 11
#   Rata-rata titik torso/frame: 37.01
#   >> Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso\Tsania\torso_Jalan41.csv
#
# === Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Tsania\clustering_Jalan42.csv
#   Total frame unik dalam file ini: 111
#   Frame dengan torso   : 106
#   Frame tanpa torso    : 5
#   Rata-rata titik torso/frame: 39.39
#   >> Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso\Tsania\torso_Jalan42.csv
#
# === Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Tsania\clustering_Jalan43.csv
#   Total frame unik dalam file ini: 149
#   Frame dengan torso   : 128
#   Frame tanpa torso    : 21
#   Rata-rata titik torso/frame: 38.25
#   >> Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso\Tsania\torso_Jalan43.csv
#
# === Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Tsania\clustering_Jalan44.csv
#   Total frame unik dalam file ini: 132
#   Frame dengan torso   : 120
#   Frame tanpa torso    : 12
#   Rata-rata titik torso/frame: 41.33
#   >> Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso\Tsania\torso_Jalan44.csv
#
# === Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Tsania\clustering_Jalan45.csv
#   Total frame unik dalam file ini: 122
#   Frame dengan torso   : 114
#   Frame tanpa torso    : 8
#   Rata-rata titik torso/frame: 45.51
#   >> Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso\Tsania\torso_Jalan45.csv
#
# === Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Tsania\clustering_Jalan46.csv
#   Total frame unik dalam file ini: 111
#   Frame dengan torso   : 94
#   Frame tanpa torso    : 17
#   Rata-rata titik torso/frame: 45.96
#   >> Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso\Tsania\torso_Jalan46.csv
#
# === Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Tsania\clustering_Jalan47.csv
#   Total frame unik dalam file ini: 322
#   Frame dengan torso   : 289
#   Frame tanpa torso    : 33
#   Rata-rata titik torso/frame: 24.43
#   >> Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso\Tsania\torso_Jalan47.csv
#
# === Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Tsania\clustering_Jalan48.csv
#   Total frame unik dalam file ini: 278
#   Frame dengan torso   : 256
#   Frame tanpa torso    : 22
#   Rata-rata titik torso/frame: 28.43
#   >> Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso\Tsania\torso_Jalan48.csv
#
# === Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Tsania\clustering_Jalan49.csv
#   Total frame unik dalam file ini: 129
#   Frame dengan torso   : 116
#   Frame tanpa torso    : 13
#   Rata-rata titik torso/frame: 23.96
#   >> Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso\Tsania\torso_Jalan49.csv
#
# === Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Tsania\clustering_Jalan5.csv
#   Total frame unik dalam file ini: 114
#   Frame dengan torso   : 96
#   Frame tanpa torso    : 18
#   Rata-rata titik torso/frame: 16.51
#   >> Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso\Tsania\torso_Jalan5.csv
#
# === Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Tsania\clustering_Jalan50.csv
#   Total frame unik dalam file ini: 106
#   Frame dengan torso   : 95
#   Frame tanpa torso    : 11
#   Rata-rata titik torso/frame: 26.42
#   >> Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso\Tsania\torso_Jalan50.csv
#
# === Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Tsania\clustering_Jalan51.csv
#   Total frame unik dalam file ini: 123
#   Frame dengan torso   : 113
#   Frame tanpa torso    : 10
#   Rata-rata titik torso/frame: 30.77
#   >> Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso\Tsania\torso_Jalan51.csv
#
# === Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Tsania\clustering_Jalan52.csv
#   Total frame unik dalam file ini: 129
#   Frame dengan torso   : 122
#   Frame tanpa torso    : 7
#   Rata-rata titik torso/frame: 17.29
#   >> Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso\Tsania\torso_Jalan52.csv
#
# === Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Tsania\clustering_Jalan53.csv
#   Total frame unik dalam file ini: 118
#   Frame dengan torso   : 108
#   Frame tanpa torso    : 10
#   Rata-rata titik torso/frame: 19.17
#   >> Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso\Tsania\torso_Jalan53.csv
#
# === Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Tsania\clustering_Jalan54.csv
#   Total frame unik dalam file ini: 122
#   Frame dengan torso   : 110
#   Frame tanpa torso    : 12
#   Rata-rata titik torso/frame: 26.68
#   >> Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso\Tsania\torso_Jalan54.csv
#
# === Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Tsania\clustering_Jalan55.csv
#   Total frame unik dalam file ini: 103
#   Frame dengan torso   : 96
#   Frame tanpa torso    : 7
#   Rata-rata titik torso/frame: 29.73
#   >> Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso\Tsania\torso_Jalan55.csv
#
# === Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Tsania\clustering_Jalan56.csv
#   Total frame unik dalam file ini: 129
#   Frame dengan torso   : 119
#   Frame tanpa torso    : 10
#   Rata-rata titik torso/frame: 27.18
#   >> Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso\Tsania\torso_Jalan56.csv
#
# === Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Tsania\clustering_Jalan57.csv
#   Total frame unik dalam file ini: 116
#   Frame dengan torso   : 102
#   Frame tanpa torso    : 14
#   Rata-rata titik torso/frame: 34.42
#   >> Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso\Tsania\torso_Jalan57.csv
#
# === Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Tsania\clustering_Jalan58.csv
#   Total frame unik dalam file ini: 142
#   Frame dengan torso   : 132
#   Frame tanpa torso    : 10
#   Rata-rata titik torso/frame: 27.39
#   >> Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso\Tsania\torso_Jalan58.csv
#
# === Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Tsania\clustering_Jalan59.csv
#   Total frame unik dalam file ini: 110
#   Frame dengan torso   : 101
#   Frame tanpa torso    : 9
#   Rata-rata titik torso/frame: 23.81
#   >> Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso\Tsania\torso_Jalan59.csv
#
# === Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Tsania\clustering_Jalan6.csv
#   Total frame unik dalam file ini: 119
#   Frame dengan torso   : 103
#   Frame tanpa torso    : 16
#   Rata-rata titik torso/frame: 27.77
#   >> Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso\Tsania\torso_Jalan6.csv
#
# === Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Tsania\clustering_Jalan60.csv
#   Total frame unik dalam file ini: 122
#   Frame dengan torso   : 97
#   Frame tanpa torso    : 25
#   Rata-rata titik torso/frame: 26.90
#   >> Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso\Tsania\torso_Jalan60.csv
#
# === Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Tsania\clustering_Jalan61.csv
#   Total frame unik dalam file ini: 144
#   Frame dengan torso   : 137
#   Frame tanpa torso    : 7
#   Rata-rata titik torso/frame: 30.36
#   >> Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso\Tsania\torso_Jalan61.csv
#
# === Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Tsania\clustering_Jalan62.csv
#   Total frame unik dalam file ini: 127
#   Frame dengan torso   : 112
#   Frame tanpa torso    : 15
#   Rata-rata titik torso/frame: 30.26
#   >> Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso\Tsania\torso_Jalan62.csv
#
# === Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Tsania\clustering_Jalan63.csv
#   Total frame unik dalam file ini: 251
#   Frame dengan torso   : 230
#   Frame tanpa torso    : 21
#   Rata-rata titik torso/frame: 31.74
#   >> Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso\Tsania\torso_Jalan63.csv
#
# === Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Tsania\clustering_Jalan64.csv
#   Total frame unik dalam file ini: 212
#   Frame dengan torso   : 186
#   Frame tanpa torso    : 26
#   Rata-rata titik torso/frame: 37.33
#   >> Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso\Tsania\torso_Jalan64.csv
#
# === Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Tsania\clustering_Jalan65.csv
#   Total frame unik dalam file ini: 136
#   Frame dengan torso   : 128
#   Frame tanpa torso    : 8
#   Rata-rata titik torso/frame: 51.14
#   >> Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso\Tsania\torso_Jalan65.csv
#
# === Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Tsania\clustering_Jalan66.csv
#   Total frame unik dalam file ini: 122
#   Frame dengan torso   : 115
#   Frame tanpa torso    : 7
#   Rata-rata titik torso/frame: 46.75
#   >> Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso\Tsania\torso_Jalan66.csv
#
# === Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Tsania\clustering_Jalan67.csv
#   Total frame unik dalam file ini: 187
#   Frame dengan torso   : 162
#   Frame tanpa torso    : 25
#   Rata-rata titik torso/frame: 37.75
#   >> Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso\Tsania\torso_Jalan67.csv
#
# === Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Tsania\clustering_Jalan68.csv
#   Total frame unik dalam file ini: 162
#   Frame dengan torso   : 154
#   Frame tanpa torso    : 8
#   Rata-rata titik torso/frame: 50.90
#   >> Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso\Tsania\torso_Jalan68.csv
#
# === Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Tsania\clustering_Jalan69.csv
#   Total frame unik dalam file ini: 133
#   Frame dengan torso   : 123
#   Frame tanpa torso    : 10
#   Rata-rata titik torso/frame: 47.14
#   >> Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso\Tsania\torso_Jalan69.csv
#
# === Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Tsania\clustering_Jalan7.csv
#   Total frame unik dalam file ini: 96
#   Frame dengan torso   : 85
#   Frame tanpa torso    : 11
#   Rata-rata titik torso/frame: 27.44
#   >> Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso\Tsania\torso_Jalan7.csv
#
# === Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Tsania\clustering_Jalan70.csv
#   Total frame unik dalam file ini: 122
#   Frame dengan torso   : 115
#   Frame tanpa torso    : 7
#   Rata-rata titik torso/frame: 46.48
#   >> Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso\Tsania\torso_Jalan70.csv
#
# === Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Tsania\clustering_Jalan71.csv
#   Total frame unik dalam file ini: 428
#   Frame dengan torso   : 387
#   Frame tanpa torso    : 41
#   Rata-rata titik torso/frame: 32.70
#   >> Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso\Tsania\torso_Jalan71.csv
#
# === Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Tsania\clustering_Jalan72.csv
#   Total frame unik dalam file ini: 449
#   Frame dengan torso   : 409
#   Frame tanpa torso    : 40
#   Rata-rata titik torso/frame: 33.20
#   >> Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso\Tsania\torso_Jalan72.csv
#
# === Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Tsania\clustering_Jalan8.csv
#   Total frame unik dalam file ini: 119
#   Frame dengan torso   : 107
#   Frame tanpa torso    : 12
#   Rata-rata titik torso/frame: 32.37
#   >> Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso\Tsania\torso_Jalan8.csv
#
# === Proses file clustering: E:\1.Clustering_TA\dataset2\hasil_clustering\Tsania\clustering_Jalan9.csv
#   Total frame unik dalam file ini: 116
#   Frame dengan torso   : 108
#   Frame tanpa torso    : 8
#   Rata-rata titik torso/frame: 31.88
#   >> Disimpan ke: E:\0.TA_Teguh\dataset2\hasil_torso\Tsania\torso_Jalan9.csv
#
# === Ringkasan global torso extraction (head) ===
#                                                 file  \
# 0  E:\1.Clustering_TA\dataset2\hasil_clustering\A...
# 1  E:\1.Clustering_TA\dataset2\hasil_clustering\A...
# 2  E:\1.Clustering_TA\dataset2\hasil_clustering\A...
# 3  E:\1.Clustering_TA\dataset2\hasil_clustering\A...
# 4  E:\1.Clustering_TA\dataset2\hasil_clustering\A...
#
#                                           torso_file  n_frames_total  \
# 0  E:\0.TA_Teguh\dataset2\hasil_torso\Afi\torso_J...              99
# 1  E:\0.TA_Teguh\dataset2\hasil_torso\Afi\torso_J...              94
# 2  E:\0.TA_Teguh\dataset2\hasil_torso\Afi\torso_J...              96
# 3  E:\0.TA_Teguh\dataset2\hasil_torso\Afi\torso_J...              77
# 4  E:\0.TA_Teguh\dataset2\hasil_torso\Afi\torso_J...              99
#
#    n_frames_with_torso  avg_points_per_torso_frame subject
# 0                   91                   20.450549     Afi
# 1                   89                   23.764045     Afi
# 2                   90                   19.855556     Afi
# 3                   71                   29.830986     Afi
# 4                   92                   24.532609     Afi

# %% [markdown]
# 🧩 Cell 6 – Ringkasan agregat per subjek

# %%
# Cell 6: Ringkasan agregat per subjek (opsional tapi sangat berguna)

if df_torso_summary is not None and not df_torso_summary.empty:
    # Hitung persentase frame yang punya torso per file
    df_torso_summary["ratio_frames_with_torso"] = (
        df_torso_summary["n_frames_with_torso"] / df_torso_summary["n_frames_total"]
    )

    print("\n=== Ringkasan agregat per SUBJEK ===")
    df_by_subject = (
        df_torso_summary
        .groupby("subject")
        .agg({
            "n_frames_total": "sum",
            "n_frames_with_torso": "sum",
            "avg_points_per_torso_frame": "mean",
            "ratio_frames_with_torso": "mean"
        })
    )
    print(df_by_subject)
else:
    print("Tidak ada summary torso (df_torso_summary kosong).")
# Out:
# === Ringkasan agregat per SUBJEK ===
#          n_frames_total  n_frames_with_torso  avg_points_per_torso_frame  \
# subject
# Afi                9453                 8540                   27.985436
# Tsamara           12675                11643                   26.461814
# Tsania            10812                 9827                   30.136372
#
#          ratio_frames_with_torso
# subject
# Afi                     0.904585
# Tsamara                 0.917326
# Tsania                  0.906527
